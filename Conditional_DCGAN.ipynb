# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/CT-GAN-mini

# !pwd

# !pip install pydicom
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/CT-GAN-mini
# /content/drive/MyDrive/CT-GAN-mini
# Collecting pydicom
#   Downloading pydicom-3.0.1-py3-none-any.whl.metadata (9.4 kB)
# Downloading pydicom-3.0.1-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 21.5 MB/s eta 0:00:00
# Installing collected packages: pydicom
# Successfully installed pydicom-3.0.1

# %%
import os
import numpy as np
from glob import glob

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader

import torchvision.transforms as transforms

import pydicom
from skimage.transform import resize

# For mixed-precision training
from torch.amp import GradScaler, autocast

# %%
# Training hyperparameters
n_epochs = 50
batch_size = 4  # Reduced batch size to minimize memory usage
lr = 0.0002
b1 = 0.5  # Adam optimizer hyperparameter
b2 = 0.999  # Adam optimizer hyperparameter
img_size = 256  # Keeping original image size
ct_slices = 128  # Keeping original number of CT slices
channels = 1  # Number of image channels (grayscale)

# %%
# Dataset class with updated methods to handle missing data
class XrayCTDataset(Dataset):
    def __init__(self, root_dir):
        self.root_dir = root_dir
        patients = sorted(os.listdir(root_dir))
        # Filter out any files that are not directories
        patients = [p for p in patients if os.path.isdir(os.path.join(root_dir, p))]
        self.patients = []
        for p in patients:
            patient_dir = os.path.join(root_dir, p)
            xray_files = glob(os.path.join(patient_dir, 'Xray', '*.dcm'))
            ct_files = glob(os.path.join(patient_dir, 'CT', '*.dcm'))
            if len(xray_files) > 0 and len(ct_files) > 0:
                self.patients.append(p)
            else:
                print(f"Skipping patient {p} due to missing data.")

    def __len__(self):
        return len(self.patients)

    def __getitem__(self, idx):
        patient_id = self.patients[idx]
        patient_dir = os.path.join(self.root_dir, patient_id)

        # Load and preprocess X-ray image
        xray_path_list = glob(os.path.join(patient_dir, 'Xray', '*.dcm'))
        if len(xray_path_list) == 0:
            print(f"No X-ray data for patient {patient_id}. Skipping.")
            return self.__getitem__((idx + 1) % len(self.patients))
        xray_path = xray_path_list[0]
        xray = self.load_and_preprocess_image(xray_path)

        # Load and preprocess CT slices
        ct_dir = os.path.join(patient_dir, 'CT')
        ct_slice_paths = sorted(glob(os.path.join(ct_dir, '*.dcm')))

        if len(ct_slice_paths) == 0:
            print(f"No CT data for patient {patient_id}. Skipping.")
            return self.__getitem__((idx + 1) % len(self.patients))

        print(f"Processing patient {patient_id}, number of CT slices: {len(ct_slice_paths)}")

        ct_slices_array = self.load_and_preprocess_ct_slices(ct_slice_paths)

        sample = {'xray': xray, 'ct': ct_slices_array}

        return sample

    def load_and_preprocess_image(self, image_path):
        # Load the image
        ds = pydicom.dcmread(image_path)
        image = ds.pixel_array.astype(np.float32)

        # Normalize the image
        image = (image - image.min()) / (image.max() - image.min())

        # Resize the image
        image = resize(image, (img_size, img_size), mode='constant', anti_aliasing=True)

        # Convert to tensor and add channel dimension
        image = torch.tensor(image, dtype=torch.float32).unsqueeze(0)
        return image

    def load_and_preprocess_ct_slices(self, slice_paths):
        num_slices = len(slice_paths)
        desired_slices = ct_slices

        if num_slices == 0:
            raise ValueError("No CT slices found.")

        # Calculate indices to select slices for alignment
        if num_slices >= desired_slices:
            indices = np.linspace(0, num_slices - 1, desired_slices).astype(int)
        else:
            # If fewer slices than desired, repeat slices as needed
            repeats = int(np.ceil(desired_slices / num_slices))
            indices = np.tile(np.arange(num_slices), repeats)[:desired_slices]

        # Preallocate a list for the CT slices
        ct_slices_list = []
        for idx in indices:
            p = slice_paths[idx]
            # Load and preprocess each slice
            slice_ = self.load_and_preprocess_image(p)
            ct_slices_list.append(slice_)

        # Stack slices into a 3D volume
        ct_slices_array = torch.stack(ct_slices_list, dim=0)  # Shape: [ct_slices, 1, img_size, img_size]
        ct_slices_array = ct_slices_array.squeeze(1)  # Shape: [ct_slices, img_size, img_size]
        ct_slices_array = ct_slices_array.unsqueeze(0)  # Shape: [1, ct_slices, img_size, img_size]

        return ct_slices_array  # Return shape: [1, ct_slices, img_size, img_size]

# %%
# Path to the dataset
dataset_root = 'LIDC-IDRI/'

# Create dataset and dataloader
dataset = XrayCTDataset(root_dir=dataset_root)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True)

# %%
# Define the Generator
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()

        # Encoder: From [B, 1, 256, 256] to [B, 256, 16, 16]
        self.encoder = nn.Sequential(
            nn.Conv2d(channels, 32, kernel_size=4, stride=2, padding=1),   # [B, 32, 128, 128]
            nn.BatchNorm2d(32),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(32, 64, kernel_size=4, stride=2, padding=1),         # [B, 64, 64, 64]
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1),        # [B, 128, 32, 32]
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1),       # [B, 256, 16, 16]
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
        )

        # Bridge between encoder and decoder
        self.bridge = nn.Sequential(
            nn.Conv2d(256, 256, kernel_size=3, stride=1, padding=1),       # [B, 256, 16, 16]
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
        )

        # Decoder: Upsamples the features and depth dimension
        self.decoder = nn.Sequential(
            nn.ConvTranspose3d(256, 128, kernel_size=(4,4,4), stride=(2,2,2), padding=(1,1,1)),  # [B, 128, 2, 32, 32]
            nn.BatchNorm3d(128),
            nn.ReLU(inplace=True),

            nn.ConvTranspose3d(128, 64, kernel_size=(4,4,4), stride=(2,2,2), padding=(1,1,1)),   # [B, 64, 4, 64, 64]
            nn.BatchNorm3d(64),
            nn.ReLU(inplace=True),

            nn.ConvTranspose3d(64, 32, kernel_size=(4,4,4), stride=(2,2,2), padding=(1,1,1)),    # [B, 32, 8, 128, 128]
            nn.BatchNorm3d(32),
            nn.ReLU(inplace=True),

            nn.ConvTranspose3d(32, channels, kernel_size=(4,4,4), stride=(2,2,2), padding=(1,1,1)),  # [B, 1, 16, 256, 256]
            nn.Tanh(),
        )

        # Adjust the depth dimension to ct_slices
        # Upsample depth from 16 to ct_slices (128)
        self.depth_adjust = nn.ConvTranspose3d(
            channels, channels, kernel_size=(ct_slices // 16, 1, 1), stride=(ct_slices // 16, 1, 1)
        )

    def forward(self, x):
        x = self.encoder(x)                   # [B, 256, 16, 16]
        x = self.bridge(x)                    # [B, 256, 16, 16]
        x = x.unsqueeze(2)                    # [B, 256, 1, 16, 16]

        # Decoder: Upsample both spatial dimensions and depth
        x = self.decoder(x)                   # [B, 1, 16, 256, 256]
        x = self.depth_adjust(x)              # Upsample depth to ct_slices (128)
        return x

# %%
# Define the Discriminator
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
            nn.Conv3d(channels * 2, 32, kernel_size=4, stride=2, padding=1),    # [B, 32, D/2, 128, 128]
            nn.BatchNorm3d(32),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv3d(32, 64, kernel_size=4, stride=2, padding=1),          # [B, 64, D/4, 64, 64]
            nn.BatchNorm3d(64),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv3d(64, 128, kernel_size=4, stride=2, padding=1),         # [B, 128, D/8, 32, 32]
            nn.BatchNorm3d(128),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv3d(128, 256, kernel_size=4, stride=2, padding=1),        # [B, 256, D/16, 16, 16]
            nn.BatchNorm3d(256),
            nn.LeakyReLU(0.2, inplace=True),
        )

        # Output layers
        self.pool = nn.AdaptiveAvgPool3d((1, 1, 1))                         # [B, 256, 1, 1, 1]
        self.adv_layer = nn.Sequential(
            nn.Flatten(),                                                   # [B, 256]
            nn.Linear(256, 1),                                              # [B, 1]
            # Removed nn.Sigmoid(),
        )

    def forward(self, ct, xray):
        # xray: [B, 1, img_size, img_size]
        # ct: [B, 1, ct_slices, img_size, img_size]
        # Expand xray along depth dimension to match ct_slices
        xray_expanded = xray.unsqueeze(2).repeat(1, 1, ct_slices, 1, 1)  # [B, 1, ct_slices, img_size, img_size]
        # Concatenate along channel dimension
        x = torch.cat([ct, xray_expanded], dim=1)  # [B, 2, ct_slices, img_size, img_size]

        x = self.model(x)
        x = self.pool(x)
        validity = self.adv_layer(x)
        return validity

# %%
# Function to count parameters
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Initialize generator and discriminator
generator = Generator()
discriminator = Discriminator()

# Print the number of parameters
print(f"Generator parameters: {count_parameters(generator)}")
print(f"Discriminator parameters: {count_parameters(discriminator)}")
# Out:
# Generator parameters: 4035914
# Discriminator parameters: 2758305

# %%
# Use GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
generator.to(device)
discriminator.to(device)

# Loss function
adversarial_loss = nn.BCEWithLogitsLoss()

# Optimizers
optimizer_G = optim.Adam(generator.parameters(), lr=lr, betas=(b1, b2))
optimizer_D = optim.Adam(discriminator.parameters(), lr=lr, betas=(b1, b2))

# For mixed-precision training
scaler = GradScaler()
print(device)
# Out:
# cuda

# %%
# Training loop
for epoch in range(n_epochs):
    for i, batch in enumerate(dataloader):
        xray = batch['xray'].to(device, non_blocking=True)
        ct = batch['ct'].to(device, non_blocking=True)

        # Reshape ct to [B, 1, ct_slices, img_size, img_size]
        ct = ct  # Shape already [B, 1, ct_slices, img_size, img_size]

        valid = torch.ones((xray.size(0), 1), requires_grad=False).to(device)
        fake = torch.zeros((xray.size(0), 1), requires_grad=False).to(device)

        # -----------------
        #  Train Generator
        # -----------------
        optimizer_G.zero_grad()

        with autocast(device_type='cuda'):
            # Generate CT scans
            gen_ct = generator(xray)

            # Generator loss
            g_loss = adversarial_loss(discriminator(gen_ct, xray), valid)

        scaler.scale(g_loss).backward()
        scaler.step(optimizer_G)
        scaler.update()

        # ---------------------
        #  Train Discriminator
        # ---------------------
        optimizer_D.zero_grad()

        with autocast(device_type='cuda'):
            # Real CT loss
            real_loss = adversarial_loss(discriminator(ct, xray), valid)
            # Fake CT loss
            fake_loss = adversarial_loss(discriminator(gen_ct.detach(), xray), fake)
            # Total discriminator loss
            d_loss = 0.5 * (real_loss + fake_loss)

        scaler.scale(d_loss).backward()
        scaler.step(optimizer_D)
        scaler.update()

        # Print training progress
        print(f"[Epoch {epoch+1}/{n_epochs}] [Batch {i+1}/{len(dataloader)}] "
              f"[D loss: {d_loss.item():.4f}] [G loss: {g_loss.item():.4f}]")
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# [Epoch 30/50] [Batch 4/48] [D loss: 0.0055] [G loss: 5.1945]
# Processing patient LIDC-IDRI-0113, number of CT slices: 145
# Processing patient LIDC-IDRI-0145, number of CT slices: 139
# Processing patient LIDC-IDRI-0004, number of CT slices: 241
# Processing patient LIDC-IDRI-0114, number of CT slices: 214
# [Epoch 30/50] [Batch 5/48] [D loss: 0.0062] [G loss: 4.9535]
# Processing patient LIDC-IDRI-0155, number of CT slices: 238
# Processing patient LIDC-IDRI-0180, number of CT slices: 238
# Processing patient LIDC-IDRI-0094, number of CT slices: 385
# Processing patient LIDC-IDRI-0202, number of CT slices: 111
# [Epoch 30/50] [Batch 6/48] [D loss: 0.0054] [G loss: 5.2663]
# Processing patient LIDC-IDRI-0037, number of CT slices: 141
# Processing patient LIDC-IDRI-0240, number of CT slices: 125
# Processing patient LIDC-IDRI-0258, number of CT slices: 133
# Processing patient LIDC-IDRI-0054, number of CT slices: 133
# [Epoch 30/50] [Batch 7/48] [D loss: 0.0058] [G loss: 5.0252]
# Processing patient LIDC-IDRI-0070, number of CT slices: 133
# Processing patient LIDC-IDRI-0253, number of CT slices: 133
# Processing patient LIDC-IDRI-0080, number of CT slices: 257
# Processing patient LIDC-IDRI-0165, number of CT slices: 133
# [Epoch 30/50] [Batch 8/48] [D loss: 0.0064] [G loss: 4.9807]
# Processing patient LIDC-IDRI-0127, number of CT slices: 117
# Processing patient LIDC-IDRI-0219, number of CT slices: 133
# Processing patient LIDC-IDRI-0259, number of CT slices: 149
# Processing patient LIDC-IDRI-0139, number of CT slices: 114
# [Epoch 30/50] [Batch 9/48] [D loss: 0.0052] [G loss: 5.3128]
# Processing patient LIDC-IDRI-0061, number of CT slices: 123
# Processing patient LIDC-IDRI-0208, number of CT slices: 109
# Processing patient LIDC-IDRI-0072, number of CT slices: 305
# Processing patient LIDC-IDRI-0107, number of CT slices: 136
# [Epoch 30/50] [Batch 10/48] [D loss: 0.0051] [G loss: 5.1875]
# Processing patient LIDC-IDRI-0069, number of CT slices: 136
# Processing patient LIDC-IDRI-0132, number of CT slices: 127
# Processing patient LIDC-IDRI-0034, number of CT slices: 265
# Processing patient LIDC-IDRI-0115, number of CT slices: 112
# [Epoch 30/50] [Batch 11/48] [D loss: 0.0158] [G loss: 4.8057]
# Processing patient LIDC-IDRI-0195, number of CT slices: 133
# Processing patient LIDC-IDRI-0052, number of CT slices: 272
# Processing patient LIDC-IDRI-0144, number of CT slices: 133
# Processing patient LIDC-IDRI-0029, number of CT slices: 273
# [Epoch 30/50] [Batch 12/48] [D loss: 0.0302] [G loss: 4.6230]
# Processing patient LIDC-IDRI-0147, number of CT slices: 136
# Processing patient LIDC-IDRI-0103, number of CT slices: 111
# Processing patient LIDC-IDRI-0066, number of CT slices: 733
# Processing patient LIDC-IDRI-0243, number of CT slices: 143
# [Epoch 30/50] [Batch 13/48] [D loss: 0.1908] [G loss: 4.0315]
# Processing patient LIDC-IDRI-0035, number of CT slices: 133
# Processing patient LIDC-IDRI-0109, number of CT slices: 223
# Processing patient LIDC-IDRI-0119, number of CT slices: 345
# Processing patient LIDC-IDRI-0101, number of CT slices: 150
# [Epoch 30/50] [Batch 14/48] [D loss: 1.3076] [G loss: 2.7960]
# Processing patient LIDC-IDRI-0027, number of CT slices: 133
# Processing patient LIDC-IDRI-0220, number of CT slices: 232
# Processing patient LIDC-IDRI-0279, number of CT slices: 129
# Processing patient LIDC-IDRI-0047, number of CT slices: 133
# [Epoch 30/50] [Batch 15/48] [D loss: 1.1117] [G loss: 0.1408]
# Processing patient LIDC-IDRI-0256, number of CT slices: 131
# Processing patient LIDC-IDRI-0186, number of CT slices: 137
# Processing patient LIDC-IDRI-0260, number of CT slices: 144
# Processing patient LIDC-IDRI-0246, number of CT slices: 143
# [Epoch 30/50] [Batch 16/48] [D loss: 0.6355] [G loss: 1.1944]
# Processing patient LIDC-IDRI-0010, number of CT slices: 284
# Processing patient LIDC-IDRI-0146, number of CT slices: 310
# Processing patient LIDC-IDRI-0093, number of CT slices: 125
# Processing patient LIDC-IDRI-0030, number of CT slices: 119
# [Epoch 30/50] [Batch 17/48] [D loss: 0.6891] [G loss: 1.3578]
# Processing patient LIDC-IDRI-0058, number of CT slices: 133
# Processing patient LIDC-IDRI-0046, number of CT slices: 128
# Processing patient LIDC-IDRI-0157, number of CT slices: 133
# Processing patient LIDC-IDRI-0042, number of CT slices: 123
# [Epoch 30/50] [Batch 18/48] [D loss: 0.6117] [G loss: 1.3280]
# Processing patient LIDC-IDRI-0188, number of CT slices: 113
# Processing patient LIDC-IDRI-0218, number of CT slices: 217
# Processing patient LIDC-IDRI-0117, number of CT slices: 122
# Processing patient LIDC-IDRI-0257, number of CT slices: 133
# [Epoch 30/50] [Batch 19/48] [D loss: 0.8059] [G loss: 1.2224]
# Processing patient LIDC-IDRI-0105, number of CT slices: 154
# Processing patient LIDC-IDRI-0217, number of CT slices: 135
# Processing patient LIDC-IDRI-0051, number of CT slices: 133
# Processing patient LIDC-IDRI-0266, number of CT slices: 238
# [Epoch 30/50] [Batch 20/48] [D loss: 0.6670] [G loss: 1.0611]
# Processing patient LIDC-IDRI-0138, number of CT slices: 273
# Processing patient LIDC-IDRI-0056, number of CT slices: 249
# Processing patient LIDC-IDRI-0173, number of CT slices: 145
# Processing patient LIDC-IDRI-0163, number of CT slices: 133
# [Epoch 30/50] [Batch 21/48] [D loss: 0.7055] [G loss: 1.2009]
# Processing patient LIDC-IDRI-0091, number of CT slices: 197
# Processing patient LIDC-IDRI-0089, number of CT slices: 147
# Processing patient LIDC-IDRI-0075, number of CT slices: 257
# Processing patient LIDC-IDRI-0099, number of CT slices: 194
# [Epoch 30/50] [Batch 22/48] [D loss: 0.5536] [G loss: 1.2836]
# Processing patient LIDC-IDRI-0078, number of CT slices: 87
# Processing patient LIDC-IDRI-0045, number of CT slices: 133
# Processing patient LIDC-IDRI-0108, number of CT slices: 143
# Processing patient LIDC-IDRI-0282, number of CT slices: 119
# [Epoch 30/50] [Batch 23/48] [D loss: 0.5444] [G loss: 1.2008]
# Processing patient LIDC-IDRI-0228, number of CT slices: 127
# Processing patient LIDC-IDRI-0187, number of CT slices: 143
# Processing patient LIDC-IDRI-0060, number of CT slices: 115
# Processing patient LIDC-IDRI-0183, number of CT slices: 139
# [Epoch 30/50] [Batch 24/48] [D loss: 0.4312] [G loss: 1.4546]
# Processing patient LIDC-IDRI-0252, number of CT slices: 148
# Processing patient LIDC-IDRI-0142, number of CT slices: 333
# Processing patient LIDC-IDRI-0031, number of CT slices: 133
# Processing patient LIDC-IDRI-0007, number of CT slices: 145
# [Epoch 30/50] [Batch 25/48] [D loss: 0.6113] [G loss: 1.7770]
# Processing patient LIDC-IDRI-0150, number of CT slices: 102
# Processing patient LIDC-IDRI-0018, number of CT slices: 127
# Processing patient LIDC-IDRI-0179, number of CT slices: 123
# Processing patient LIDC-IDRI-0227, number of CT slices: 137
# [Epoch 30/50] [Batch 26/48] [D loss: 0.5847] [G loss: 1.4774]
# Processing patient LIDC-IDRI-0063, number of CT slices: 133
# Processing patient LIDC-IDRI-0043, number of CT slices: 113
# Processing patient LIDC-IDRI-0207, number of CT slices: 238
# Processing patient LIDC-IDRI-0205, number of CT slices: 135
# [Epoch 30/50] [Batch 27/48] [D loss: 0.3642] [G loss: 1.3413]
# Processing patient LIDC-IDRI-0001, number of CT slices: 133
# Processing patient LIDC-IDRI-0044, number of CT slices: 147
# Processing patient LIDC-IDRI-0169, number of CT slices: 238
# Processing patient LIDC-IDRI-0024, number of CT slices: 133
# [Epoch 30/50] [Batch 28/48] [D loss: 0.4195] [G loss: 1.0373]
# Processing patient LIDC-IDRI-0185, number of CT slices: 133
# Processing patient LIDC-IDRI-0023, number of CT slices: 137
# Processing patient LIDC-IDRI-0272, number of CT slices: 119
# Processing patient LIDC-IDRI-0049, number of CT slices: 133
# [Epoch 30/50] [Batch 29/48] [D loss: 0.3792] [G loss: 1.1302]
# Processing patient LIDC-IDRI-0087, number of CT slices: 130
# Processing patient LIDC-IDRI-0189, number of CT slices: 117
# Processing patient LIDC-IDRI-0028, number of CT slices: 141
# Processing patient LIDC-IDRI-0134, number of CT slices: 118
# [Epoch 30/50] [Batch 30/48] [D loss: 0.3685] [G loss: 1.1463]
# Processing patient LIDC-IDRI-0090, number of CT slices: 133
# Processing patient LIDC-IDRI-0041, number of CT slices: 149
# Processing patient LIDC-IDRI-0168, number of CT slices: 232
# Processing patient LIDC-IDRI-0120, number of CT slices: 183
# [Epoch 30/50] [Batch 31/48] [D loss: 0.4749] [G loss: 0.8186]
# Processing patient LIDC-IDRI-0059, number of CT slices: 133
# Processing patient LIDC-IDRI-0263, number of CT slices: 137
# Processing patient LIDC-IDRI-0224, number of CT slices: 133
# Processing patient LIDC-IDRI-0121, number of CT slices: 277
# [Epoch 30/50] [Batch 32/48] [D loss: 0.5031] [G loss: 0.9064]
# Processing patient LIDC-IDRI-0081, number of CT slices: 126
# Processing patient LIDC-IDRI-0209, number of CT slices: 141
# Processing patient LIDC-IDRI-0280, number of CT slices: 238
# Processing patient LIDC-IDRI-0130, number of CT slices: 324
# [Epoch 30/50] [Batch 33/48] [D loss: 0.3443] [G loss: 1.4091]
# Processing patient LIDC-IDRI-0084, number of CT slices: 166
# Processing patient LIDC-IDRI-0006, number of CT slices: 133
# Processing patient LIDC-IDRI-0248, number of CT slices: 117
# Processing patient LIDC-IDRI-0079, number of CT slices: 113
# [Epoch 30/50] [Batch 34/48] [D loss: 0.3807] [G loss: 1.6606]
# Processing patient LIDC-IDRI-0233, number of CT slices: 147
# Processing patient LIDC-IDRI-0156, number of CT slices: 127
# Processing patient LIDC-IDRI-0178, number of CT slices: 125
# Processing patient LIDC-IDRI-0062, number of CT slices: 117
# [Epoch 30/50] [Batch 35/48] [D loss: 0.2950] [G loss: 1.6871]
# Processing patient LIDC-IDRI-0160, number of CT slices: 140
# Processing patient LIDC-IDRI-0021, number of CT slices: 149
# Processing patient LIDC-IDRI-0268, number of CT slices: 117
# Processing patient LIDC-IDRI-0154, number of CT slices: 115
# [Epoch 30/50] [Batch 36/48] [D loss: 0.2974] [G loss: 1.5112]
# Processing patient LIDC-IDRI-0083, number of CT slices: 218
# Processing patient LIDC-IDRI-0271, number of CT slices: 117
# Processing patient LIDC-IDRI-0011, number of CT slices: 128
# Processing patient LIDC-IDRI-0036, number of CT slices: 273
# [Epoch 30/50] [Batch 37/48] [D loss: 0.2409] [G loss: 1.5305]
# Processing patient LIDC-IDRI-0104, number of CT slices: 105
# Processing patient LIDC-IDRI-0005, number of CT slices: 132
# Processing patient LIDC-IDRI-0008, number of CT slices: 133
# Processing patient LIDC-IDRI-0191, number of CT slices: 133
# [Epoch 30/50] [Batch 38/48] [D loss: 0.2167] [G loss: 1.6853]
# Processing patient LIDC-IDRI-0019, number of CT slices: 305
# Processing patient LIDC-IDRI-0102, number of CT slices: 143
# Processing patient LIDC-IDRI-0181, number of CT slices: 150
# Processing patient LIDC-IDRI-0022, number of CT slices: 133
# [Epoch 30/50] [Batch 39/48] [D loss: 0.2331] [G loss: 1.6667]
# Processing patient LIDC-IDRI-0133, number of CT slices: 238
# Processing patient LIDC-IDRI-0039, number of CT slices: 281
# Processing patient LIDC-IDRI-0077, number of CT slices: 130
# Processing patient LIDC-IDRI-0040, number of CT slices: 121
# [Epoch 30/50] [Batch 40/48] [D loss: 0.1902] [G loss: 1.8324]
# Processing patient LIDC-IDRI-0148, number of CT slices: 131
# Processing patient LIDC-IDRI-0129, number of CT slices: 253
# Processing patient LIDC-IDRI-0106, number of CT slices: 158
# Processing patient LIDC-IDRI-0167, number of CT slices: 133
# [Epoch 30/50] [Batch 41/48] [D loss: 0.1690] [G loss: 2.1244]
# Processing patient LIDC-IDRI-0194, number of CT slices: 149
# Processing patient LIDC-IDRI-0136, number of CT slices: 153
# Processing patient LIDC-IDRI-0216, number of CT slices: 133
# Processing patient LIDC-IDRI-0050, number of CT slices: 139
# [Epoch 30/50] [Batch 42/48] [D loss: 0.1579] [G loss: 2.1661]
# Processing patient LIDC-IDRI-0267, number of CT slices: 150
# Processing patient LIDC-IDRI-0065, number of CT slices: 237
# Processing patient LIDC-IDRI-0249, number of CT slices: 218
# Processing patient LIDC-IDRI-0264, number of CT slices: 238
# [Epoch 30/50] [Batch 43/48] [D loss: 0.1540] [G loss: 2.2722]
# Processing patient LIDC-IDRI-0086, number of CT slices: 246
# Processing patient LIDC-IDRI-0110, number of CT slices: 125
# Processing patient LIDC-IDRI-0076, number of CT slices: 297
# Processing patient LIDC-IDRI-0073, number of CT slices: 131
# [Epoch 30/50] [Batch 44/48] [D loss: 0.1595] [G loss: 2.5289]
# Processing patient LIDC-IDRI-0025, number of CT slices: 265
# Processing patient LIDC-IDRI-0153, number of CT slices: 139
# Processing patient LIDC-IDRI-0126, number of CT slices: 137
# Processing patient LIDC-IDRI-0095, number of CT slices: 343
# [Epoch 30/50] [Batch 45/48] [D loss: 0.1608] [G loss: 2.2354]
# Processing patient LIDC-IDRI-0135, number of CT slices: 127
# Processing patient LIDC-IDRI-0096, number of CT slices: 127
# Processing patient LIDC-IDRI-0012, number of CT slices: 128
# Processing patient LIDC-IDRI-0014, number of CT slices: 114
# [Epoch 30/50] [Batch 46/48] [D loss: 0.1200] [G loss: 2.2870]
# Processing patient LIDC-IDRI-0064, number of CT slices: 133
# Processing patient LIDC-IDRI-0123, number of CT slices: 236
# Processing patient LIDC-IDRI-0067, number of CT slices: 244
# Processing patient LIDC-IDRI-0013, number of CT slices: 125
# [Epoch 30/50] [Batch 47/48] [D loss: 0.1225] [G loss: 2.1718]
# Processing patient LIDC-IDRI-0033, number of CT slices: 137
# Processing patient LIDC-IDRI-0112, number of CT slices: 123
# Processing patient LIDC-IDRI-0229, number of CT slices: 141
# [Epoch 30/50] [Batch 48/48] [D loss: 0.1394] [G loss: 1.9043]
# Processing patient LIDC-IDRI-0038, number of CT slices: 133
# Processing patient LIDC-IDRI-0138, number of CT slices: 273
# Processing patient LIDC-IDRI-0039, number of CT slices: 281
# Processing patient LIDC-IDRI-0001, number of CT slices: 133
# [Epoch 31/50] [Batch 1/48] [D loss: 0.1292] [G loss: 2.1637]
# Processing patient LIDC-IDRI-0108, number of CT slices: 143
# Processing patient LIDC-IDRI-0060, number of CT slices: 115
# Processing patient LIDC-IDRI-0084, number of CT slices: 166
# Processing patient LIDC-IDRI-0105, number of CT slices: 154
# [Epoch 31/50] [Batch 2/48] [D loss: 0.1427] [G loss: 2.0514]
# Processing patient LIDC-IDRI-0205, number of CT slices: 135
# Processing patient LIDC-IDRI-0180, number of CT slices: 238
# Processing patient LIDC-IDRI-0025, number of CT slices: 265
# Processing patient LIDC-IDRI-0027, number of CT slices: 133
# [Epoch 31/50] [Batch 3/48] [D loss: 0.1050] [G loss: 2.3076]
# Processing patient LIDC-IDRI-0014, number of CT slices: 114
# Processing patient LIDC-IDRI-0040, number of CT slices: 121
# Processing patient LIDC-IDRI-0184, number of CT slices: 140
# Processing patient LIDC-IDRI-0106, number of CT slices: 158
# [Epoch 31/50] [Batch 4/48] [D loss: 0.1340] [G loss: 2.2472]
# Processing patient LIDC-IDRI-0052, number of CT slices: 272
# Processing patient LIDC-IDRI-0089, number of CT slices: 147
# Processing patient LIDC-IDRI-0051, number of CT slices: 133
# Processing patient LIDC-IDRI-0157, number of CT slices: 133
# [Epoch 31/50] [Batch 5/48] [D loss: 0.1283] [G loss: 2.2742]
# Processing patient LIDC-IDRI-0249, number of CT slices: 218
# Processing patient LIDC-IDRI-0187, number of CT slices: 143
# Processing patient LIDC-IDRI-0185, number of CT slices: 133
# Processing patient LIDC-IDRI-0217, number of CT slices: 135
# [Epoch 31/50] [Batch 6/48] [D loss: 0.0963] [G loss: 2.3235]
# Processing patient LIDC-IDRI-0121, number of CT slices: 277
# Processing patient LIDC-IDRI-0050, number of CT slices: 139
# Processing patient LIDC-IDRI-0102, number of CT slices: 143
# Processing patient LIDC-IDRI-0036, number of CT slices: 273
# [Epoch 31/50] [Batch 7/48] [D loss: 0.0747] [G loss: 2.8022]
# Processing patient LIDC-IDRI-0163, number of CT slices: 133
# Processing patient LIDC-IDRI-0022, number of CT slices: 133
# Processing patient LIDC-IDRI-0075, number of CT slices: 257
# Processing patient LIDC-IDRI-0083, number of CT slices: 218
# [Epoch 31/50] [Batch 8/48] [D loss: 0.0889] [G loss: 2.5611]
# Processing patient LIDC-IDRI-0066, number of CT slices: 733
# Processing patient LIDC-IDRI-0012, number of CT slices: 128
# Processing patient LIDC-IDRI-0271, number of CT slices: 117
# Processing patient LIDC-IDRI-0223, number of CT slices: 238
# [Epoch 31/50] [Batch 9/48] [D loss: 0.0938] [G loss: 2.8153]
# Processing patient LIDC-IDRI-0260, number of CT slices: 144
# Processing patient LIDC-IDRI-0139, number of CT slices: 114
# Processing patient LIDC-IDRI-0248, number of CT slices: 117
# Processing patient LIDC-IDRI-0181, number of CT slices: 150
# [Epoch 31/50] [Batch 10/48] [D loss: 0.0889] [G loss: 2.6867]
# Processing patient LIDC-IDRI-0096, number of CT slices: 127
# Processing patient LIDC-IDRI-0259, number of CT slices: 149
# Processing patient LIDC-IDRI-0178, number of CT slices: 125
# Processing patient LIDC-IDRI-0253, number of CT slices: 133
# [Epoch 31/50] [Batch 11/48] [D loss: 0.0784] [G loss: 2.7692]
# Processing patient LIDC-IDRI-0126, number of CT slices: 137
# Processing patient LIDC-IDRI-0099, number of CT slices: 194
# Processing patient LIDC-IDRI-0280, number of CT slices: 238
# Processing patient LIDC-IDRI-0252, number of CT slices: 148
# [Epoch 31/50] [Batch 12/48] [D loss: 0.0708] [G loss: 2.7421]
# Processing patient LIDC-IDRI-0054, number of CT slices: 133
# Processing patient LIDC-IDRI-0235, number of CT slices: 139
# Processing patient LIDC-IDRI-0034, number of CT slices: 265
# Processing patient LIDC-IDRI-0081, number of CT slices: 126
# [Epoch 31/50] [Batch 13/48] [D loss: 0.0668] [G loss: 2.6337]
# Processing patient LIDC-IDRI-0086, number of CT slices: 246
# Processing patient LIDC-IDRI-0043, number of CT slices: 113
# Processing patient LIDC-IDRI-0256, number of CT slices: 131
# Processing patient LIDC-IDRI-0046, number of CT slices: 128
# [Epoch 31/50] [Batch 14/48] [D loss: 0.0737] [G loss: 2.6246]
# Processing patient LIDC-IDRI-0169, number of CT slices: 238
# Processing patient LIDC-IDRI-0127, number of CT slices: 117
# Processing patient LIDC-IDRI-0243, number of CT slices: 143
# Processing patient LIDC-IDRI-0062, number of CT slices: 117
# [Epoch 31/50] [Batch 15/48] [D loss: 0.0740] [G loss: 2.8474]
# Processing patient LIDC-IDRI-0107, number of CT slices: 136
# Processing patient LIDC-IDRI-0065, number of CT slices: 237
# Processing patient LIDC-IDRI-0229, number of CT slices: 141
# Processing patient LIDC-IDRI-0165, number of CT slices: 133
# [Epoch 31/50] [Batch 16/48] [D loss: 0.0734] [G loss: 3.0956]
# Processing patient LIDC-IDRI-0090, number of CT slices: 133
# Processing patient LIDC-IDRI-0005, number of CT slices: 132
# Processing patient LIDC-IDRI-0037, number of CT slices: 141
# Processing patient LIDC-IDRI-0003, number of CT slices: 140
# [Epoch 31/50] [Batch 17/48] [D loss: 0.0686] [G loss: 2.6658]
# Processing patient LIDC-IDRI-0029, number of CT slices: 273
# Processing patient LIDC-IDRI-0219, number of CT slices: 133
# Processing patient LIDC-IDRI-0168, number of CT slices: 232
# Processing patient LIDC-IDRI-0147, number of CT slices: 136
# [Epoch 31/50] [Batch 18/48] [D loss: 0.0635] [G loss: 2.7506]
# Processing patient LIDC-IDRI-0047, number of CT slices: 133
# Processing patient LIDC-IDRI-0123, number of CT slices: 236
# Processing patient LIDC-IDRI-0080, number of CT slices: 257
# Processing patient LIDC-IDRI-0263, number of CT slices: 137
# [Epoch 31/50] [Batch 19/48] [D loss: 0.0551] [G loss: 2.9350]
# Processing patient LIDC-IDRI-0154, number of CT slices: 115
# Processing patient LIDC-IDRI-0053, number of CT slices: 111
# Processing patient LIDC-IDRI-0155, number of CT slices: 238
# Processing patient LIDC-IDRI-0117, number of CT slices: 122
# [Epoch 31/50] [Batch 20/48] [D loss: 0.0716] [G loss: 3.1130]
# Processing patient LIDC-IDRI-0236, number of CT slices: 133
# Processing patient LIDC-IDRI-0246, number of CT slices: 143
# Processing patient LIDC-IDRI-0113, number of CT slices: 145
# Processing patient LIDC-IDRI-0153, number of CT slices: 139
# [Epoch 31/50] [Batch 21/48] [D loss: 0.0525] [G loss: 2.9701]
# Processing patient LIDC-IDRI-0207, number of CT slices: 238
# Processing patient LIDC-IDRI-0093, number of CT slices: 125
# Processing patient LIDC-IDRI-0266, number of CT slices: 238
# Processing patient LIDC-IDRI-0191, number of CT slices: 133
# [Epoch 31/50] [Batch 22/48] [D loss: 0.0545] [G loss: 3.2523]
# Processing patient LIDC-IDRI-0094, number of CT slices: 385
# Processing patient LIDC-IDRI-0019, number of CT slices: 305
# Processing patient LIDC-IDRI-0120, number of CT slices: 183
# Processing patient LIDC-IDRI-0195, number of CT slices: 133
# [Epoch 31/50] [Batch 23/48] [D loss: 0.0608] [G loss: 3.2656]
# Processing patient LIDC-IDRI-0033, number of CT slices: 137
# Processing patient LIDC-IDRI-0189, number of CT slices: 117
# Processing patient LIDC-IDRI-0074, number of CT slices: 109
# Processing patient LIDC-IDRI-0150, number of CT slices: 102
# [Epoch 31/50] [Batch 24/48] [D loss: 0.0541] [G loss: 3.2858]
# Processing patient LIDC-IDRI-0258, number of CT slices: 133
# Processing patient LIDC-IDRI-0023, number of CT slices: 137
# Processing patient LIDC-IDRI-0024, number of CT slices: 133
# Processing patient LIDC-IDRI-0130, number of CT slices: 324
# [Epoch 31/50] [Batch 25/48] [D loss: 0.0569] [G loss: 2.8880]
# Processing patient LIDC-IDRI-0156, number of CT slices: 127
# Processing patient LIDC-IDRI-0197, number of CT slices: 127
# Processing patient LIDC-IDRI-0103, number of CT slices: 111
# Processing patient LIDC-IDRI-0136, number of CT slices: 153
# [Epoch 31/50] [Batch 26/48] [D loss: 0.0657] [G loss: 3.1965]
# Processing patient LIDC-IDRI-0209, number of CT slices: 141
# Processing patient LIDC-IDRI-0030, number of CT slices: 119
# Processing patient LIDC-IDRI-0031, number of CT slices: 133
# Processing patient LIDC-IDRI-0044, number of CT slices: 147
# [Epoch 31/50] [Batch 27/48] [D loss: 0.0520] [G loss: 2.9026]
# Processing patient LIDC-IDRI-0179, number of CT slices: 123
# Processing patient LIDC-IDRI-0173, number of CT slices: 145
# Processing patient LIDC-IDRI-0079, number of CT slices: 113
# Processing patient LIDC-IDRI-0049, number of CT slices: 133
# [Epoch 31/50] [Batch 28/48] [D loss: 0.0467] [G loss: 2.9968]
# Processing patient LIDC-IDRI-0145, number of CT slices: 139
# Processing patient LIDC-IDRI-0112, number of CT slices: 123
# Processing patient LIDC-IDRI-0281, number of CT slices: 119
# Processing patient LIDC-IDRI-0007, number of CT slices: 145
# [Epoch 31/50] [Batch 29/48] [D loss: 0.0430] [G loss: 3.1468]
# Processing patient LIDC-IDRI-0240, number of CT slices: 125
# Processing patient LIDC-IDRI-0078, number of CT slices: 87
# Processing patient LIDC-IDRI-0010, number of CT slices: 284
# Processing patient LIDC-IDRI-0183, number of CT slices: 139
# [Epoch 31/50] [Batch 30/48] [D loss: 0.0444] [G loss: 3.1761]
# Processing patient LIDC-IDRI-0129, number of CT slices: 253
# Processing patient LIDC-IDRI-0162, number of CT slices: 133
# Processing patient LIDC-IDRI-0167, number of CT slices: 133
# Processing patient LIDC-IDRI-0045, number of CT slices: 133
# [Epoch 31/50] [Batch 31/48] [D loss: 0.0405] [G loss: 3.1187]
# Processing patient LIDC-IDRI-0095, number of CT slices: 343
# Processing patient LIDC-IDRI-0067, number of CT slices: 244
# Processing patient LIDC-IDRI-0204, number of CT slices: 133
# Processing patient LIDC-IDRI-0072, number of CT slices: 305
# [Epoch 31/50] [Batch 32/48] [D loss: 0.0514] [G loss: 3.4164]
# Processing patient LIDC-IDRI-0061, number of CT slices: 123
# Processing patient LIDC-IDRI-0148, number of CT slices: 131
# Processing patient LIDC-IDRI-0073, number of CT slices: 131
# Processing patient LIDC-IDRI-0104, number of CT slices: 105
# [Epoch 31/50] [Batch 33/48] [D loss: 0.0417] [G loss: 3.1954]
# Processing patient LIDC-IDRI-0101, number of CT slices: 150
# Processing patient LIDC-IDRI-0186, number of CT slices: 137
# Processing patient LIDC-IDRI-0076, number of CT slices: 297
# Processing patient LIDC-IDRI-0115, number of CT slices: 112
# [Epoch 31/50] [Batch 34/48] [D loss: 0.0564] [G loss: 3.2752]
# Processing patient LIDC-IDRI-0011, number of CT slices: 128
# Processing patient LIDC-IDRI-0272, number of CT slices: 119
# Processing patient LIDC-IDRI-0077, number of CT slices: 130
# Processing patient LIDC-IDRI-0004, number of CT slices: 241
# [Epoch 31/50] [Batch 35/48] [D loss: 0.0361] [G loss: 3.2619]
# Processing patient LIDC-IDRI-0069, number of CT slices: 136
# Processing patient LIDC-IDRI-0143, number of CT slices: 133
# Processing patient LIDC-IDRI-0188, number of CT slices: 113
# Processing patient LIDC-IDRI-0233, number of CT slices: 147
# [Epoch 31/50] [Batch 36/48] [D loss: 0.0557] [G loss: 3.2616]
# Processing patient LIDC-IDRI-0059, number of CT slices: 133
# Processing patient LIDC-IDRI-0021, number of CT slices: 149
# Processing patient LIDC-IDRI-0279, number of CT slices: 129
# Processing patient LIDC-IDRI-0224, number of CT slices: 133
# [Epoch 31/50] [Batch 37/48] [D loss: 0.0339] [G loss: 3.4372]
# Processing patient LIDC-IDRI-0228, number of CT slices: 127
# Processing patient LIDC-IDRI-0064, number of CT slices: 133
# Processing patient LIDC-IDRI-0220, number of CT slices: 232
# Processing patient LIDC-IDRI-0070, number of CT slices: 133
# [Epoch 31/50] [Batch 38/48] [D loss: 0.0370] [G loss: 3.2458]
# Processing patient LIDC-IDRI-0018, number of CT slices: 127
# Processing patient LIDC-IDRI-0135, number of CT slices: 127
# Processing patient LIDC-IDRI-0268, number of CT slices: 117
# Processing patient LIDC-IDRI-0134, number of CT slices: 118
# [Epoch 31/50] [Batch 39/48] [D loss: 0.0611] [G loss: 3.1789]
# Processing patient LIDC-IDRI-0144, number of CT slices: 133
# Processing patient LIDC-IDRI-0091, number of CT slices: 197
# Processing patient LIDC-IDRI-0194, number of CT slices: 149
# Processing patient LIDC-IDRI-0008, number of CT slices: 133
# [Epoch 31/50] [Batch 40/48] [D loss: 0.0365] [G loss: 3.5182]
# Processing patient LIDC-IDRI-0087, number of CT slices: 130
# Processing patient LIDC-IDRI-0142, number of CT slices: 333
# Processing patient LIDC-IDRI-0257, number of CT slices: 133
# Processing patient LIDC-IDRI-0058, number of CT slices: 133
# [Epoch 31/50] [Batch 41/48] [D loss: 0.0646] [G loss: 3.5150]
# Processing patient LIDC-IDRI-0216, number of CT slices: 133
# Processing patient LIDC-IDRI-0035, number of CT slices: 133
# Processing patient LIDC-IDRI-0028, number of CT slices: 141
# Processing patient LIDC-IDRI-0013, number of CT slices: 125
# [Epoch 31/50] [Batch 42/48] [D loss: 0.0616] [G loss: 3.3126]
# Processing patient LIDC-IDRI-0267, number of CT slices: 150
# Processing patient LIDC-IDRI-0202, number of CT slices: 111
# Processing patient LIDC-IDRI-0119, number of CT slices: 345
# Processing patient LIDC-IDRI-0208, number of CT slices: 109
# [Epoch 31/50] [Batch 43/48] [D loss: 0.0606] [G loss: 3.1263]
# Processing patient LIDC-IDRI-0125, number of CT slices: 238
# Processing patient LIDC-IDRI-0063, number of CT slices: 133
# Processing patient LIDC-IDRI-0146, number of CT slices: 310
# Processing patient LIDC-IDRI-0262, number of CT slices: 197
# [Epoch 31/50] [Batch 44/48] [D loss: 0.0433] [G loss: 3.1406]
# Processing patient LIDC-IDRI-0109, number of CT slices: 223
# Processing patient LIDC-IDRI-0133, number of CT slices: 238
# Processing patient LIDC-IDRI-0041, number of CT slices: 149
# Processing patient LIDC-IDRI-0056, number of CT slices: 249
# [Epoch 31/50] [Batch 45/48] [D loss: 0.0455] [G loss: 3.2703]
# Processing patient LIDC-IDRI-0042, number of CT slices: 123
# Processing patient LIDC-IDRI-0114, number of CT slices: 214
# Processing patient LIDC-IDRI-0264, number of CT slices: 238
# Processing patient LIDC-IDRI-0006, number of CT slices: 133
# [Epoch 31/50] [Batch 46/48] [D loss: 0.0350] [G loss: 3.3246]
# Processing patient LIDC-IDRI-0218, number of CT slices: 217
# Processing patient LIDC-IDRI-0227, number of CT slices: 137
# Processing patient LIDC-IDRI-0110, number of CT slices: 125
# Processing patient LIDC-IDRI-0160, number of CT slices: 140
# [Epoch 31/50] [Batch 47/48] [D loss: 0.0580] [G loss: 3.3288]
# Processing patient LIDC-IDRI-0132, number of CT slices: 127
# Processing patient LIDC-IDRI-0282, number of CT slices: 119
# Processing patient LIDC-IDRI-0016, number of CT slices: 141
# [Epoch 31/50] [Batch 48/48] [D loss: 0.0410] [G loss: 3.5415]
# Processing patient LIDC-IDRI-0142, number of CT slices: 333
# Processing patient LIDC-IDRI-0180, number of CT slices: 238
# Processing patient LIDC-IDRI-0235, number of CT slices: 139
# Processing patient LIDC-IDRI-0028, number of CT slices: 141
# [Epoch 32/50] [Batch 1/48] [D loss: 0.0336] [G loss: 3.4969]
# Processing patient LIDC-IDRI-0262, number of CT slices: 197
# Processing patient LIDC-IDRI-0130, number of CT slices: 324
# Processing patient LIDC-IDRI-0089, number of CT slices: 147
# Processing patient LIDC-IDRI-0249, number of CT slices: 218
# [Epoch 32/50] [Batch 2/48] [D loss: 0.0385] [G loss: 3.1658]
# Processing patient LIDC-IDRI-0195, number of CT slices: 133
# Processing patient LIDC-IDRI-0223, number of CT slices: 238
# Processing patient LIDC-IDRI-0074, number of CT slices: 109
# Processing patient LIDC-IDRI-0112, number of CT slices: 123
# [Epoch 32/50] [Batch 3/48] [D loss: 0.0389] [G loss: 3.2105]
# Processing patient LIDC-IDRI-0202, number of CT slices: 111
# Processing patient LIDC-IDRI-0271, number of CT slices: 117
# Processing patient LIDC-IDRI-0086, number of CT slices: 246
# Processing patient LIDC-IDRI-0039, number of CT slices: 281
# [Epoch 32/50] [Batch 4/48] [D loss: 0.0318] [G loss: 3.6708]
# Processing patient LIDC-IDRI-0021, number of CT slices: 149
# Processing patient LIDC-IDRI-0012, number of CT slices: 128
# Processing patient LIDC-IDRI-0134, number of CT slices: 118
# Processing patient LIDC-IDRI-0266, number of CT slices: 238
# [Epoch 32/50] [Batch 5/48] [D loss: 0.0359] [G loss: 3.6037]
# Processing patient LIDC-IDRI-0077, number of CT slices: 130
# Processing patient LIDC-IDRI-0025, number of CT slices: 265
# Processing patient LIDC-IDRI-0016, number of CT slices: 141
# Processing patient LIDC-IDRI-0146, number of CT slices: 310
# [Epoch 32/50] [Batch 6/48] [D loss: 0.0327] [G loss: 3.2687]
# Processing patient LIDC-IDRI-0058, number of CT slices: 133
# Processing patient LIDC-IDRI-0007, number of CT slices: 145
# Processing patient LIDC-IDRI-0127, number of CT slices: 117
# Processing patient LIDC-IDRI-0105, number of CT slices: 154
# [Epoch 32/50] [Batch 7/48] [D loss: 0.0319] [G loss: 3.4715]
# Processing patient LIDC-IDRI-0049, number of CT slices: 133
# Processing patient LIDC-IDRI-0217, number of CT slices: 135
# Processing patient LIDC-IDRI-0253, number of CT slices: 133
# Processing patient LIDC-IDRI-0022, number of CT slices: 133
# [Epoch 32/50] [Batch 8/48] [D loss: 0.0297] [G loss: 3.3216]
# Processing patient LIDC-IDRI-0227, number of CT slices: 137
# Processing patient LIDC-IDRI-0043, number of CT slices: 113
# Processing patient LIDC-IDRI-0018, number of CT slices: 127
# Processing patient LIDC-IDRI-0260, number of CT slices: 144
# [Epoch 32/50] [Batch 9/48] [D loss: 0.0304] [G loss: 3.3626]
# Processing patient LIDC-IDRI-0160, number of CT slices: 140
# Processing patient LIDC-IDRI-0084, number of CT slices: 166
# Processing patient LIDC-IDRI-0248, number of CT slices: 117
# Processing patient LIDC-IDRI-0263, number of CT slices: 137
# [Epoch 32/50] [Batch 10/48] [D loss: 0.0353] [G loss: 3.5405]
# Processing patient LIDC-IDRI-0036, number of CT slices: 273
# Processing patient LIDC-IDRI-0104, number of CT slices: 105
# Processing patient LIDC-IDRI-0145, number of CT slices: 139
# Processing patient LIDC-IDRI-0033, number of CT slices: 137
# [Epoch 32/50] [Batch 11/48] [D loss: 0.0293] [G loss: 3.2386]
# Processing patient LIDC-IDRI-0027, number of CT slices: 133
# Processing patient LIDC-IDRI-0121, number of CT slices: 277
# Processing patient LIDC-IDRI-0282, number of CT slices: 119
# Processing patient LIDC-IDRI-0224, number of CT slices: 133
# [Epoch 32/50] [Batch 12/48] [D loss: 0.0289] [G loss: 3.3760]
# Processing patient LIDC-IDRI-0090, number of CT slices: 133
# Processing patient LIDC-IDRI-0038, number of CT slices: 133
# Processing patient LIDC-IDRI-0256, number of CT slices: 131
# Processing patient LIDC-IDRI-0051, number of CT slices: 133
# [Epoch 32/50] [Batch 13/48] [D loss: 0.0254] [G loss: 3.5661]
# Processing patient LIDC-IDRI-0005, number of CT slices: 132
# Processing patient LIDC-IDRI-0129, number of CT slices: 253
# Processing patient LIDC-IDRI-0184, number of CT slices: 140
# Processing patient LIDC-IDRI-0207, number of CT slices: 238
# [Epoch 32/50] [Batch 14/48] [D loss: 0.0240] [G loss: 3.6490]
# Processing patient LIDC-IDRI-0067, number of CT slices: 244
# Processing patient LIDC-IDRI-0150, number of CT slices: 102
# Processing patient LIDC-IDRI-0011, number of CT slices: 128
# Processing patient LIDC-IDRI-0037, number of CT slices: 141
# [Epoch 32/50] [Batch 15/48] [D loss: 0.0301] [G loss: 3.8105]
# Processing patient LIDC-IDRI-0070, number of CT slices: 133
# Processing patient LIDC-IDRI-0102, number of CT slices: 143
# Processing patient LIDC-IDRI-0191, number of CT slices: 133
# Processing patient LIDC-IDRI-0156, number of CT slices: 127
# [Epoch 32/50] [Batch 16/48] [D loss: 0.0242] [G loss: 3.8108]
# Processing patient LIDC-IDRI-0053, number of CT slices: 111
# Processing patient LIDC-IDRI-0094, number of CT slices: 385
# Processing patient LIDC-IDRI-0066, number of CT slices: 733
# Processing patient LIDC-IDRI-0257, number of CT slices: 133
# [Epoch 32/50] [Batch 17/48] [D loss: 0.0341] [G loss: 3.7162]
# Processing patient LIDC-IDRI-0236, number of CT slices: 133
# Processing patient LIDC-IDRI-0268, number of CT slices: 117
# Processing patient LIDC-IDRI-0148, number of CT slices: 131
# Processing patient LIDC-IDRI-0126, number of CT slices: 137
# [Epoch 32/50] [Batch 18/48] [D loss: 0.0236] [G loss: 3.5702]
# Processing patient LIDC-IDRI-0046, number of CT slices: 128
# Processing patient LIDC-IDRI-0041, number of CT slices: 149
# Processing patient LIDC-IDRI-0113, number of CT slices: 145
# Processing patient LIDC-IDRI-0139, number of CT slices: 114
# [Epoch 32/50] [Batch 19/48] [D loss: 0.0263] [G loss: 3.4839]
# Processing patient LIDC-IDRI-0114, number of CT slices: 214
# Processing patient LIDC-IDRI-0279, number of CT slices: 129
# Processing patient LIDC-IDRI-0029, number of CT slices: 273
# Processing patient LIDC-IDRI-0194, number of CT slices: 149
# [Epoch 32/50] [Batch 20/48] [D loss: 0.0259] [G loss: 3.5191]
# Processing patient LIDC-IDRI-0081, number of CT slices: 126
# Processing patient LIDC-IDRI-0060, number of CT slices: 115
# Processing patient LIDC-IDRI-0076, number of CT slices: 297
# Processing patient LIDC-IDRI-0173, number of CT slices: 145
# [Epoch 32/50] [Batch 21/48] [D loss: 0.0262] [G loss: 3.7299]
# Processing patient LIDC-IDRI-0229, number of CT slices: 141
# Processing patient LIDC-IDRI-0216, number of CT slices: 133
# Processing patient LIDC-IDRI-0078, number of CT slices: 87
# Processing patient LIDC-IDRI-0157, number of CT slices: 133
# [Epoch 32/50] [Batch 22/48] [D loss: 0.0240] [G loss: 3.8321]
# Processing patient LIDC-IDRI-0233, number of CT slices: 147
# Processing patient LIDC-IDRI-0178, number of CT slices: 125
# Processing patient LIDC-IDRI-0228, number of CT slices: 127
# Processing patient LIDC-IDRI-0042, number of CT slices: 123
# [Epoch 32/50] [Batch 23/48] [D loss: 0.0215] [G loss: 3.7305]
# Processing patient LIDC-IDRI-0019, number of CT slices: 305
# Processing patient LIDC-IDRI-0267, number of CT slices: 150
# Processing patient LIDC-IDRI-0220, number of CT slices: 232
# Processing patient LIDC-IDRI-0050, number of CT slices: 139
# [Epoch 32/50] [Batch 24/48] [D loss: 0.0266] [G loss: 3.8155]
# Processing patient LIDC-IDRI-0240, number of CT slices: 125
# Processing patient LIDC-IDRI-0120, number of CT slices: 183
# Processing patient LIDC-IDRI-0101, number of CT slices: 150
# Processing patient LIDC-IDRI-0008, number of CT slices: 133
# [Epoch 32/50] [Batch 25/48] [D loss: 0.0333] [G loss: 4.0429]
# Processing patient LIDC-IDRI-0143, number of CT slices: 133
# Processing patient LIDC-IDRI-0006, number of CT slices: 133
# Processing patient LIDC-IDRI-0044, number of CT slices: 147
# Processing patient LIDC-IDRI-0208, number of CT slices: 109
# [Epoch 32/50] [Batch 26/48] [D loss: 0.0280] [G loss: 3.7481]
# Processing patient LIDC-IDRI-0087, number of CT slices: 130
# Processing patient LIDC-IDRI-0281, number of CT slices: 119
# Processing patient LIDC-IDRI-0264, number of CT slices: 238
# Processing patient LIDC-IDRI-0169, number of CT slices: 238
# [Epoch 32/50] [Batch 27/48] [D loss: 0.0235] [G loss: 3.9269]
# Processing patient LIDC-IDRI-0259, number of CT slices: 149
# Processing patient LIDC-IDRI-0155, number of CT slices: 238
# Processing patient LIDC-IDRI-0163, number of CT slices: 133
# Processing patient LIDC-IDRI-0162, number of CT slices: 133
# [Epoch 32/50] [Batch 28/48] [D loss: 0.0224] [G loss: 3.8019]
# Processing patient LIDC-IDRI-0040, number of CT slices: 121
# Processing patient LIDC-IDRI-0133, number of CT slices: 238
# Processing patient LIDC-IDRI-0061, number of CT slices: 123
# Processing patient LIDC-IDRI-0069, number of CT slices: 136
# [Epoch 32/50] [Batch 29/48] [D loss: 0.0236] [G loss: 3.9616]
# Processing patient LIDC-IDRI-0095, number of CT slices: 343
# Processing patient LIDC-IDRI-0096, number of CT slices: 127
# Processing patient LIDC-IDRI-0135, number of CT slices: 127
# Processing patient LIDC-IDRI-0205, number of CT slices: 135
# [Epoch 32/50] [Batch 30/48] [D loss: 0.0266] [G loss: 3.6390]
# Processing patient LIDC-IDRI-0034, number of CT slices: 265
# Processing patient LIDC-IDRI-0197, number of CT slices: 127
# Processing patient LIDC-IDRI-0108, number of CT slices: 143
# Processing patient LIDC-IDRI-0075, number of CT slices: 257
# [Epoch 32/50] [Batch 31/48] [D loss: 0.0405] [G loss: 3.5740]
# Processing patient LIDC-IDRI-0243, number of CT slices: 143
# Processing patient LIDC-IDRI-0183, number of CT slices: 139
# Processing patient LIDC-IDRI-0023, number of CT slices: 137
# Processing patient LIDC-IDRI-0187, number of CT slices: 143
# [Epoch 32/50] [Batch 32/48] [D loss: 0.0274] [G loss: 3.7535]
# Processing patient LIDC-IDRI-0123, number of CT slices: 236
# Processing patient LIDC-IDRI-0110, number of CT slices: 125
# Processing patient LIDC-IDRI-0186, number of CT slices: 137
# Processing patient LIDC-IDRI-0167, number of CT slices: 133
# [Epoch 32/50] [Batch 33/48] [D loss: 0.0282] [G loss: 3.9017]
# Processing patient LIDC-IDRI-0258, number of CT slices: 133
# Processing patient LIDC-IDRI-0218, number of CT slices: 217
# Processing patient LIDC-IDRI-0181, number of CT slices: 150
# Processing patient LIDC-IDRI-0024, number of CT slices: 133
# [Epoch 32/50] [Batch 34/48] [D loss: 0.0246] [G loss: 3.6359]
# Processing patient LIDC-IDRI-0047, number of CT slices: 133
# Processing patient LIDC-IDRI-0272, number of CT slices: 119
# Processing patient LIDC-IDRI-0179, number of CT slices: 123
# Processing patient LIDC-IDRI-0125, number of CT slices: 238
# [Epoch 32/50] [Batch 35/48] [D loss: 0.0200] [G loss: 3.7451]
# Processing patient LIDC-IDRI-0147, number of CT slices: 136
# Processing patient LIDC-IDRI-0056, number of CT slices: 249
# Processing patient LIDC-IDRI-0064, number of CT slices: 133
# Processing patient LIDC-IDRI-0136, number of CT slices: 153
# [Epoch 32/50] [Batch 36/48] [D loss: 0.0299] [G loss: 3.8598]
# Processing patient LIDC-IDRI-0109, number of CT slices: 223
# Processing patient LIDC-IDRI-0107, number of CT slices: 136
# Processing patient LIDC-IDRI-0091, number of CT slices: 197
# Processing patient LIDC-IDRI-0185, number of CT slices: 133
# [Epoch 32/50] [Batch 37/48] [D loss: 0.0175] [G loss: 4.1312]
# Processing patient LIDC-IDRI-0103, number of CT slices: 111
# Processing patient LIDC-IDRI-0168, number of CT slices: 232
# Processing patient LIDC-IDRI-0154, number of CT slices: 115
# Processing patient LIDC-IDRI-0144, number of CT slices: 133
# [Epoch 32/50] [Batch 38/48] [D loss: 0.0206] [G loss: 4.0841]
# Processing patient LIDC-IDRI-0219, number of CT slices: 133
# Processing patient LIDC-IDRI-0045, number of CT slices: 133
# Processing patient LIDC-IDRI-0001, number of CT slices: 133
# Processing patient LIDC-IDRI-0280, number of CT slices: 238
# [Epoch 32/50] [Batch 39/48] [D loss: 0.0200] [G loss: 3.8986]
# Processing patient LIDC-IDRI-0073, number of CT slices: 131
# Processing patient LIDC-IDRI-0035, number of CT slices: 133
# Processing patient LIDC-IDRI-0054, number of CT slices: 133
# Processing patient LIDC-IDRI-0204, number of CT slices: 133
# [Epoch 32/50] [Batch 40/48] [D loss: 0.0198] [G loss: 3.7125]
# Processing patient LIDC-IDRI-0115, number of CT slices: 112
# Processing patient LIDC-IDRI-0062, number of CT slices: 117
# Processing patient LIDC-IDRI-0132, number of CT slices: 127
# Processing patient LIDC-IDRI-0003, number of CT slices: 140
# [Epoch 32/50] [Batch 41/48] [D loss: 0.0404] [G loss: 3.5876]
# Processing patient LIDC-IDRI-0052, number of CT slices: 272
# Processing patient LIDC-IDRI-0072, number of CT slices: 305
# Processing patient LIDC-IDRI-0117, number of CT slices: 122
# Processing patient LIDC-IDRI-0079, number of CT slices: 113
# [Epoch 32/50] [Batch 42/48] [D loss: 0.0207] [G loss: 4.2029]
# Processing patient LIDC-IDRI-0014, number of CT slices: 114
# Processing patient LIDC-IDRI-0010, number of CT slices: 284
# Processing patient LIDC-IDRI-0138, number of CT slices: 273
# Processing patient LIDC-IDRI-0059, number of CT slices: 133
# [Epoch 32/50] [Batch 43/48] [D loss: 0.0310] [G loss: 3.7661]
# Processing patient LIDC-IDRI-0083, number of CT slices: 218
# Processing patient LIDC-IDRI-0209, number of CT slices: 141
# Processing patient LIDC-IDRI-0093, number of CT slices: 125
# Processing patient LIDC-IDRI-0004, number of CT slices: 241
# [Epoch 32/50] [Batch 44/48] [D loss: 0.0235] [G loss: 3.7881]
# Processing patient LIDC-IDRI-0013, number of CT slices: 125
# Processing patient LIDC-IDRI-0189, number of CT slices: 117
# Processing patient LIDC-IDRI-0252, number of CT slices: 148
# Processing patient LIDC-IDRI-0246, number of CT slices: 143
# [Epoch 32/50] [Batch 45/48] [D loss: 0.0204] [G loss: 3.8175]
# Processing patient LIDC-IDRI-0106, number of CT slices: 158
# Processing patient LIDC-IDRI-0188, number of CT slices: 113
# Processing patient LIDC-IDRI-0065, number of CT slices: 237
# Processing patient LIDC-IDRI-0031, number of CT slices: 133
# [Epoch 32/50] [Batch 46/48] [D loss: 0.0198] [G loss: 4.1474]
# Processing patient LIDC-IDRI-0063, number of CT slices: 133
# Processing patient LIDC-IDRI-0099, number of CT slices: 194
# Processing patient LIDC-IDRI-0030, number of CT slices: 119
# Processing patient LIDC-IDRI-0165, number of CT slices: 133
# [Epoch 32/50] [Batch 47/48] [D loss: 0.0205] [G loss: 3.8149]
# Processing patient LIDC-IDRI-0119, number of CT slices: 345
# Processing patient LIDC-IDRI-0080, number of CT slices: 257
# Processing patient LIDC-IDRI-0153, number of CT slices: 139
# [Epoch 32/50] [Batch 48/48] [D loss: 0.0316] [G loss: 3.9570]
# Processing patient LIDC-IDRI-0023, number of CT slices: 137
# Processing patient LIDC-IDRI-0108, number of CT slices: 143
# Processing patient LIDC-IDRI-0157, number of CT slices: 133
# Processing patient LIDC-IDRI-0089, number of CT slices: 147
# [Epoch 33/50] [Batch 1/48] [D loss: 0.0239] [G loss: 3.9366]
# Processing patient LIDC-IDRI-0033, number of CT slices: 137
# Processing patient LIDC-IDRI-0246, number of CT slices: 143
# Processing patient LIDC-IDRI-0113, number of CT slices: 145
# Processing patient LIDC-IDRI-0191, number of CT slices: 133
# [Epoch 33/50] [Batch 2/48] [D loss: 0.0254] [G loss: 3.7345]
# Processing patient LIDC-IDRI-0204, number of CT slices: 133
# Processing patient LIDC-IDRI-0233, number of CT slices: 147
# Processing patient LIDC-IDRI-0052, number of CT slices: 272
# Processing patient LIDC-IDRI-0180, number of CT slices: 238
# [Epoch 33/50] [Batch 3/48] [D loss: 0.0217] [G loss: 3.8636]
# Processing patient LIDC-IDRI-0209, number of CT slices: 141
# Processing patient LIDC-IDRI-0147, number of CT slices: 136
# Processing patient LIDC-IDRI-0259, number of CT slices: 149
# Processing patient LIDC-IDRI-0034, number of CT slices: 265
# [Epoch 33/50] [Batch 4/48] [D loss: 0.0194] [G loss: 4.1430]
# Processing patient LIDC-IDRI-0248, number of CT slices: 117
# Processing patient LIDC-IDRI-0081, number of CT slices: 126
# Processing patient LIDC-IDRI-0120, number of CT slices: 183
# Processing patient LIDC-IDRI-0028, number of CT slices: 141
# [Epoch 33/50] [Batch 5/48] [D loss: 0.0217] [G loss: 4.0958]
# Processing patient LIDC-IDRI-0062, number of CT slices: 117
# Processing patient LIDC-IDRI-0011, number of CT slices: 128
# Processing patient LIDC-IDRI-0127, number of CT slices: 117
# Processing patient LIDC-IDRI-0205, number of CT slices: 135
# [Epoch 33/50] [Batch 6/48] [D loss: 0.0310] [G loss: 3.8709]
# Processing patient LIDC-IDRI-0079, number of CT slices: 113
# Processing patient LIDC-IDRI-0107, number of CT slices: 136
# Processing patient LIDC-IDRI-0139, number of CT slices: 114
# Processing patient LIDC-IDRI-0282, number of CT slices: 119
# [Epoch 33/50] [Batch 7/48] [D loss: 0.0224] [G loss: 4.1599]
# Processing patient LIDC-IDRI-0258, number of CT slices: 133
# Processing patient LIDC-IDRI-0224, number of CT slices: 133
# Processing patient LIDC-IDRI-0130, number of CT slices: 324
# Processing patient LIDC-IDRI-0016, number of CT slices: 141
# [Epoch 33/50] [Batch 8/48] [D loss: 0.0253] [G loss: 3.6955]
# Processing patient LIDC-IDRI-0134, number of CT slices: 118
# Processing patient LIDC-IDRI-0160, number of CT slices: 140
# Processing patient LIDC-IDRI-0047, number of CT slices: 133
# Processing patient LIDC-IDRI-0059, number of CT slices: 133
# [Epoch 33/50] [Batch 9/48] [D loss: 0.0227] [G loss: 3.8004]
# Processing patient LIDC-IDRI-0178, number of CT slices: 125
# Processing patient LIDC-IDRI-0194, number of CT slices: 149
# Processing patient LIDC-IDRI-0013, number of CT slices: 125
# Processing patient LIDC-IDRI-0223, number of CT slices: 238
# [Epoch 33/50] [Batch 10/48] [D loss: 0.0264] [G loss: 3.5589]
# Processing patient LIDC-IDRI-0053, number of CT slices: 111
# Processing patient LIDC-IDRI-0065, number of CT slices: 237
# Processing patient LIDC-IDRI-0153, number of CT slices: 139
# Processing patient LIDC-IDRI-0054, number of CT slices: 133
# [Epoch 33/50] [Batch 11/48] [D loss: 0.0317] [G loss: 3.5028]
# Processing patient LIDC-IDRI-0038, number of CT slices: 133
# Processing patient LIDC-IDRI-0046, number of CT slices: 128
# Processing patient LIDC-IDRI-0165, number of CT slices: 133
# Processing patient LIDC-IDRI-0106, number of CT slices: 158
# [Epoch 33/50] [Batch 12/48] [D loss: 0.0201] [G loss: 3.6956]
# Processing patient LIDC-IDRI-0076, number of CT slices: 297
# Processing patient LIDC-IDRI-0262, number of CT slices: 197
# Processing patient LIDC-IDRI-0083, number of CT slices: 218
# Processing patient LIDC-IDRI-0105, number of CT slices: 154
# [Epoch 33/50] [Batch 13/48] [D loss: 0.0264] [G loss: 3.7200]
# Processing patient LIDC-IDRI-0264, number of CT slices: 238
# Processing patient LIDC-IDRI-0035, number of CT slices: 133
# Processing patient LIDC-IDRI-0179, number of CT slices: 123
# Processing patient LIDC-IDRI-0094, number of CT slices: 385
# [Epoch 33/50] [Batch 14/48] [D loss: 0.0335] [G loss: 3.7472]
# Processing patient LIDC-IDRI-0184, number of CT slices: 140
# Processing patient LIDC-IDRI-0229, number of CT slices: 141
# Processing patient LIDC-IDRI-0018, number of CT slices: 127
# Processing patient LIDC-IDRI-0078, number of CT slices: 87
# [Epoch 33/50] [Batch 15/48] [D loss: 0.0271] [G loss: 3.4387]
# Processing patient LIDC-IDRI-0181, number of CT slices: 150
# Processing patient LIDC-IDRI-0281, number of CT slices: 119
# Processing patient LIDC-IDRI-0103, number of CT slices: 111
# Processing patient LIDC-IDRI-0236, number of CT slices: 133
# [Epoch 33/50] [Batch 16/48] [D loss: 0.0259] [G loss: 3.4880]
# Processing patient LIDC-IDRI-0101, number of CT slices: 150
# Processing patient LIDC-IDRI-0169, number of CT slices: 238
# Processing patient LIDC-IDRI-0058, number of CT slices: 133
# Processing patient LIDC-IDRI-0271, number of CT slices: 117
# [Epoch 33/50] [Batch 17/48] [D loss: 0.0263] [G loss: 3.9072]
# Processing patient LIDC-IDRI-0186, number of CT slices: 137
# Processing patient LIDC-IDRI-0093, number of CT slices: 125
# Processing patient LIDC-IDRI-0121, number of CT slices: 277
# Processing patient LIDC-IDRI-0123, number of CT slices: 236
# [Epoch 33/50] [Batch 18/48] [D loss: 0.0226] [G loss: 3.6426]
# Processing patient LIDC-IDRI-0129, number of CT slices: 253
# Processing patient LIDC-IDRI-0049, number of CT slices: 133
# Processing patient LIDC-IDRI-0227, number of CT slices: 137
# Processing patient LIDC-IDRI-0066, number of CT slices: 733
# [Epoch 33/50] [Batch 19/48] [D loss: 0.0217] [G loss: 3.7501]
# Processing patient LIDC-IDRI-0253, number of CT slices: 133
# ...
# Processing patient LIDC-IDRI-0050, number of CT slices: 139
# [Epoch 49/50] [Batch 43/48] [D loss: 0.0050] [G loss: 5.8625]
# Processing patient LIDC-IDRI-0219, number of CT slices: 133
# Processing patient LIDC-IDRI-0067, number of CT slices: 244
# Processing patient LIDC-IDRI-0069, number of CT slices: 136
# Processing patient LIDC-IDRI-0045, number of CT slices: 133
# [Epoch 49/50] [Batch 44/48] [D loss: 0.0031] [G loss: 5.8135]
# Processing patient LIDC-IDRI-0040, number of CT slices: 121
# Processing patient LIDC-IDRI-0262, number of CT slices: 197
# Processing patient LIDC-IDRI-0004, number of CT slices: 241
# Processing patient LIDC-IDRI-0146, number of CT slices: 310
# [Epoch 49/50] [Batch 45/48] [D loss: 0.0040] [G loss: 5.4337]
# Processing patient LIDC-IDRI-0058, number of CT slices: 133
# Processing patient LIDC-IDRI-0217, number of CT slices: 135
# Processing patient LIDC-IDRI-0047, number of CT slices: 133
# Processing patient LIDC-IDRI-0117, number of CT slices: 122
# [Epoch 49/50] [Batch 46/48] [D loss: 0.0032] [G loss: 5.6335]
# Processing patient LIDC-IDRI-0218, number of CT slices: 217
# Processing patient LIDC-IDRI-0019, number of CT slices: 305
# Processing patient LIDC-IDRI-0280, number of CT slices: 238
# Processing patient LIDC-IDRI-0112, number of CT slices: 123
# [Epoch 49/50] [Batch 47/48] [D loss: 0.0044] [G loss: 5.3863]
# Processing patient LIDC-IDRI-0091, number of CT slices: 197
# Processing patient LIDC-IDRI-0240, number of CT slices: 125
# Processing patient LIDC-IDRI-0181, number of CT slices: 150
# [Epoch 49/50] [Batch 48/48] [D loss: 0.0033] [G loss: 5.7260]
# Processing patient LIDC-IDRI-0078, number of CT slices: 87
# Processing patient LIDC-IDRI-0042, number of CT slices: 123
# Processing patient LIDC-IDRI-0012, number of CT slices: 128
# Processing patient LIDC-IDRI-0194, number of CT slices: 149
# [Epoch 50/50] [Batch 1/48] [D loss: 0.0030] [G loss: 5.7077]
# Processing patient LIDC-IDRI-0268, number of CT slices: 117
# Processing patient LIDC-IDRI-0061, number of CT slices: 123
# Processing patient LIDC-IDRI-0179, number of CT slices: 123
# Processing patient LIDC-IDRI-0090, number of CT slices: 133
# [Epoch 50/50] [Batch 2/48] [D loss: 0.0034] [G loss: 5.4585]
# Processing patient LIDC-IDRI-0101, number of CT slices: 150
# Processing patient LIDC-IDRI-0079, number of CT slices: 113
# Processing patient LIDC-IDRI-0156, number of CT slices: 127
# Processing patient LIDC-IDRI-0197, number of CT slices: 127
# [Epoch 50/50] [Batch 3/48] [D loss: 0.0039] [G loss: 5.6180]
# Processing patient LIDC-IDRI-0271, number of CT slices: 117
# Processing patient LIDC-IDRI-0030, number of CT slices: 119
# Processing patient LIDC-IDRI-0114, number of CT slices: 214
# Processing patient LIDC-IDRI-0202, number of CT slices: 111
# [Epoch 50/50] [Batch 4/48] [D loss: 0.0035] [G loss: 5.4224]
# Processing patient LIDC-IDRI-0229, number of CT slices: 141
# Processing patient LIDC-IDRI-0157, number of CT slices: 133
# Processing patient LIDC-IDRI-0150, number of CT slices: 102
# Processing patient LIDC-IDRI-0113, number of CT slices: 145
# [Epoch 50/50] [Batch 5/48] [D loss: 0.0031] [G loss: 5.8285]
# Processing patient LIDC-IDRI-0134, number of CT slices: 118
# Processing patient LIDC-IDRI-0070, number of CT slices: 133
# Processing patient LIDC-IDRI-0043, number of CT slices: 113
# Processing patient LIDC-IDRI-0243, number of CT slices: 143
# [Epoch 50/50] [Batch 6/48] [D loss: 0.0028] [G loss: 5.7417]
# Processing patient LIDC-IDRI-0233, number of CT slices: 147
# Processing patient LIDC-IDRI-0154, number of CT slices: 115
# Processing patient LIDC-IDRI-0105, number of CT slices: 154
# Processing patient LIDC-IDRI-0077, number of CT slices: 130
# [Epoch 50/50] [Batch 7/48] [D loss: 0.0027] [G loss: 5.8020]
# Processing patient LIDC-IDRI-0067, number of CT slices: 244
# Processing patient LIDC-IDRI-0252, number of CT slices: 148
# Processing patient LIDC-IDRI-0208, number of CT slices: 109
# Processing patient LIDC-IDRI-0138, number of CT slices: 273
# [Epoch 50/50] [Batch 8/48] [D loss: 0.0036] [G loss: 5.4449]
# Processing patient LIDC-IDRI-0006, number of CT slices: 133
# Processing patient LIDC-IDRI-0008, number of CT slices: 133
# Processing patient LIDC-IDRI-0162, number of CT slices: 133
# Processing patient LIDC-IDRI-0059, number of CT slices: 133
# [Epoch 50/50] [Batch 9/48] [D loss: 0.0037] [G loss: 5.3826]
# Processing patient LIDC-IDRI-0187, number of CT slices: 143
# Processing patient LIDC-IDRI-0266, number of CT slices: 238
# Processing patient LIDC-IDRI-0072, number of CT slices: 305
# Processing patient LIDC-IDRI-0205, number of CT slices: 135
# [Epoch 50/50] [Batch 10/48] [D loss: 0.0032] [G loss: 5.5372]
# Processing patient LIDC-IDRI-0173, number of CT slices: 145
# Processing patient LIDC-IDRI-0256, number of CT slices: 131
# Processing patient LIDC-IDRI-0027, number of CT slices: 133
# Processing patient LIDC-IDRI-0132, number of CT slices: 127
# [Epoch 50/50] [Batch 11/48] [D loss: 0.0043] [G loss: 5.7349]
# Processing patient LIDC-IDRI-0089, number of CT slices: 147
# Processing patient LIDC-IDRI-0016, number of CT slices: 141
# Processing patient LIDC-IDRI-0282, number of CT slices: 119
# Processing patient LIDC-IDRI-0240, number of CT slices: 125
# [Epoch 50/50] [Batch 12/48] [D loss: 0.0038] [G loss: 5.3495]
# Processing patient LIDC-IDRI-0093, number of CT slices: 125
# Processing patient LIDC-IDRI-0153, number of CT slices: 139
# Processing patient LIDC-IDRI-0216, number of CT slices: 133
# Processing patient LIDC-IDRI-0123, number of CT slices: 236
# [Epoch 50/50] [Batch 13/48] [D loss: 0.0034] [G loss: 5.5600]
# Processing patient LIDC-IDRI-0099, number of CT slices: 194
# Processing patient LIDC-IDRI-0262, number of CT slices: 197
# Processing patient LIDC-IDRI-0147, number of CT slices: 136
# Processing patient LIDC-IDRI-0005, number of CT slices: 132
# [Epoch 50/50] [Batch 14/48] [D loss: 0.0042] [G loss: 5.1429]
# Processing patient LIDC-IDRI-0013, number of CT slices: 125
# Processing patient LIDC-IDRI-0074, number of CT slices: 109
# Processing patient LIDC-IDRI-0054, number of CT slices: 133
# Processing patient LIDC-IDRI-0236, number of CT slices: 133
# [Epoch 50/50] [Batch 15/48] [D loss: 0.0034] [G loss: 5.4559]
# Processing patient LIDC-IDRI-0129, number of CT slices: 253
# Processing patient LIDC-IDRI-0186, number of CT slices: 137
# Processing patient LIDC-IDRI-0267, number of CT slices: 150
# Processing patient LIDC-IDRI-0155, number of CT slices: 238
# [Epoch 50/50] [Batch 16/48] [D loss: 0.0033] [G loss: 5.4478]
# Processing patient LIDC-IDRI-0024, number of CT slices: 133
# Processing patient LIDC-IDRI-0040, number of CT slices: 121
# Processing patient LIDC-IDRI-0184, number of CT slices: 140
# Processing patient LIDC-IDRI-0056, number of CT slices: 249
# [Epoch 50/50] [Batch 17/48] [D loss: 0.0052] [G loss: 5.2624]
# Processing patient LIDC-IDRI-0049, number of CT slices: 133
# Processing patient LIDC-IDRI-0130, number of CT slices: 324
# Processing patient LIDC-IDRI-0023, number of CT slices: 137
# Processing patient LIDC-IDRI-0083, number of CT slices: 218
# [Epoch 50/50] [Batch 18/48] [D loss: 0.0048] [G loss: 5.4537]
# Processing patient LIDC-IDRI-0160, number of CT slices: 140
# Processing patient LIDC-IDRI-0249, number of CT slices: 218
# Processing patient LIDC-IDRI-0063, number of CT slices: 133
# Processing patient LIDC-IDRI-0044, number of CT slices: 147
# [Epoch 50/50] [Batch 19/48] [D loss: 0.0036] [G loss: 5.4614]
# Processing patient LIDC-IDRI-0073, number of CT slices: 131
# Processing patient LIDC-IDRI-0258, number of CT slices: 133
# Processing patient LIDC-IDRI-0046, number of CT slices: 128
# Processing patient LIDC-IDRI-0112, number of CT slices: 123
# [Epoch 50/50] [Batch 20/48] [D loss: 0.0034] [G loss: 5.4993]
# Processing patient LIDC-IDRI-0036, number of CT slices: 273
# Processing patient LIDC-IDRI-0038, number of CT slices: 133
# Processing patient LIDC-IDRI-0102, number of CT slices: 143
# Processing patient LIDC-IDRI-0195, number of CT slices: 133
# [Epoch 50/50] [Batch 21/48] [D loss: 0.0039] [G loss: 5.4227]
# Processing patient LIDC-IDRI-0272, number of CT slices: 119
# Processing patient LIDC-IDRI-0086, number of CT slices: 246
# Processing patient LIDC-IDRI-0125, number of CT slices: 238
# Processing patient LIDC-IDRI-0028, number of CT slices: 141
# [Epoch 50/50] [Batch 22/48] [D loss: 0.0041] [G loss: 5.8079]
# Processing patient LIDC-IDRI-0119, number of CT slices: 345
# Processing patient LIDC-IDRI-0126, number of CT slices: 137
# Processing patient LIDC-IDRI-0037, number of CT slices: 141
# Processing patient LIDC-IDRI-0109, number of CT slices: 223
# [Epoch 50/50] [Batch 23/48] [D loss: 0.0037] [G loss: 5.4988]
# Processing patient LIDC-IDRI-0223, number of CT slices: 238
# Processing patient LIDC-IDRI-0191, number of CT slices: 133
# Processing patient LIDC-IDRI-0018, number of CT slices: 127
# Processing patient LIDC-IDRI-0135, number of CT slices: 127
# [Epoch 50/50] [Batch 24/48] [D loss: 0.0034] [G loss: 5.6533]
# Processing patient LIDC-IDRI-0087, number of CT slices: 130
# Processing patient LIDC-IDRI-0257, number of CT slices: 133
# Processing patient LIDC-IDRI-0136, number of CT slices: 153
# Processing patient LIDC-IDRI-0133, number of CT slices: 238
# [Epoch 50/50] [Batch 25/48] [D loss: 0.0040] [G loss: 6.1334]
# Processing patient LIDC-IDRI-0107, number of CT slices: 136
# Processing patient LIDC-IDRI-0279, number of CT slices: 129
# Processing patient LIDC-IDRI-0007, number of CT slices: 145
# Processing patient LIDC-IDRI-0253, number of CT slices: 133
# [Epoch 50/50] [Batch 26/48] [D loss: 0.0035] [G loss: 5.6161]
# Processing patient LIDC-IDRI-0075, number of CT slices: 257
# Processing patient LIDC-IDRI-0104, number of CT slices: 105
# Processing patient LIDC-IDRI-0045, number of CT slices: 133
# Processing patient LIDC-IDRI-0096, number of CT slices: 127
# [Epoch 50/50] [Batch 27/48] [D loss: 0.0040] [G loss: 5.3653]
# Processing patient LIDC-IDRI-0011, number of CT slices: 128
# Processing patient LIDC-IDRI-0188, number of CT slices: 113
# Processing patient LIDC-IDRI-0050, number of CT slices: 139
# Processing patient LIDC-IDRI-0035, number of CT slices: 133
# [Epoch 50/50] [Batch 28/48] [D loss: 0.0033] [G loss: 5.6711]
# Processing patient LIDC-IDRI-0207, number of CT slices: 238
# Processing patient LIDC-IDRI-0081, number of CT slices: 126
# Processing patient LIDC-IDRI-0058, number of CT slices: 133
# Processing patient LIDC-IDRI-0106, number of CT slices: 158
# [Epoch 50/50] [Batch 29/48] [D loss: 0.0041] [G loss: 5.5834]
# Processing patient LIDC-IDRI-0181, number of CT slices: 150
# Processing patient LIDC-IDRI-0031, number of CT slices: 133
# Processing patient LIDC-IDRI-0227, number of CT slices: 137
# Processing patient LIDC-IDRI-0224, number of CT slices: 133
# [Epoch 50/50] [Batch 30/48] [D loss: 0.0036] [G loss: 5.4914]
# Processing patient LIDC-IDRI-0062, number of CT slices: 117
# Processing patient LIDC-IDRI-0117, number of CT slices: 122
# Processing patient LIDC-IDRI-0121, number of CT slices: 277
# Processing patient LIDC-IDRI-0189, number of CT slices: 117
# [Epoch 50/50] [Batch 31/48] [D loss: 0.0030] [G loss: 5.9019]
# Processing patient LIDC-IDRI-0052, number of CT slices: 272
# Processing patient LIDC-IDRI-0003, number of CT slices: 140
# Processing patient LIDC-IDRI-0281, number of CT slices: 119
# Processing patient LIDC-IDRI-0091, number of CT slices: 197
# [Epoch 50/50] [Batch 32/48] [D loss: 0.0028] [G loss: 5.8877]
# Processing patient LIDC-IDRI-0204, number of CT slices: 133
# Processing patient LIDC-IDRI-0217, number of CT slices: 135
# Processing patient LIDC-IDRI-0065, number of CT slices: 237
# Processing patient LIDC-IDRI-0021, number of CT slices: 149
# [Epoch 50/50] [Batch 33/48] [D loss: 0.0036] [G loss: 5.5106]
# Processing patient LIDC-IDRI-0144, number of CT slices: 133
# Processing patient LIDC-IDRI-0103, number of CT slices: 111
# Processing patient LIDC-IDRI-0259, number of CT slices: 149
# Processing patient LIDC-IDRI-0264, number of CT slices: 238
# [Epoch 50/50] [Batch 34/48] [D loss: 0.0052] [G loss: 5.6239]
# Processing patient LIDC-IDRI-0120, number of CT slices: 183
# Processing patient LIDC-IDRI-0178, number of CT slices: 125
# Processing patient LIDC-IDRI-0039, number of CT slices: 281
# Processing patient LIDC-IDRI-0246, number of CT slices: 143
# [Epoch 50/50] [Batch 35/48] [D loss: 0.0036] [G loss: 6.1256]
# Processing patient LIDC-IDRI-0001, number of CT slices: 133
# Processing patient LIDC-IDRI-0180, number of CT slices: 238
# Processing patient LIDC-IDRI-0095, number of CT slices: 343
# Processing patient LIDC-IDRI-0280, number of CT slices: 238
# [Epoch 50/50] [Batch 36/48] [D loss: 0.0055] [G loss: 5.6738]
# Processing patient LIDC-IDRI-0025, number of CT slices: 265
# Processing patient LIDC-IDRI-0034, number of CT slices: 265
# Processing patient LIDC-IDRI-0165, number of CT slices: 133
# Processing patient LIDC-IDRI-0185, number of CT slices: 133
# [Epoch 50/50] [Batch 37/48] [D loss: 0.0035] [G loss: 5.7018]
# Processing patient LIDC-IDRI-0143, number of CT slices: 133
# Processing patient LIDC-IDRI-0235, number of CT slices: 139
# Processing patient LIDC-IDRI-0183, number of CT slices: 139
# Processing patient LIDC-IDRI-0066, number of CT slices: 733
# [Epoch 50/50] [Batch 38/48] [D loss: 0.0040] [G loss: 5.4190]
# Processing patient LIDC-IDRI-0127, number of CT slices: 117
# Processing patient LIDC-IDRI-0080, number of CT slices: 257
# Processing patient LIDC-IDRI-0029, number of CT slices: 273
# Processing patient LIDC-IDRI-0167, number of CT slices: 133
# [Epoch 50/50] [Batch 39/48] [D loss: 0.0045] [G loss: 5.4128]
# Processing patient LIDC-IDRI-0053, number of CT slices: 111
# Processing patient LIDC-IDRI-0019, number of CT slices: 305
# Processing patient LIDC-IDRI-0041, number of CT slices: 149
# Processing patient LIDC-IDRI-0010, number of CT slices: 284
# [Epoch 50/50] [Batch 40/48] [D loss: 0.0041] [G loss: 5.1659]
# Processing patient LIDC-IDRI-0163, number of CT slices: 133
# Processing patient LIDC-IDRI-0169, number of CT slices: 238
# Processing patient LIDC-IDRI-0146, number of CT slices: 310
# Processing patient LIDC-IDRI-0094, number of CT slices: 385
# [Epoch 50/50] [Batch 41/48] [D loss: 0.0045] [G loss: 5.6601]
# Processing patient LIDC-IDRI-0033, number of CT slices: 137
# Processing patient LIDC-IDRI-0115, number of CT slices: 112
# Processing patient LIDC-IDRI-0209, number of CT slices: 141
# Processing patient LIDC-IDRI-0064, number of CT slices: 133
# [Epoch 50/50] [Batch 42/48] [D loss: 0.0039] [G loss: 5.4110]
# Processing patient LIDC-IDRI-0220, number of CT slices: 232
# Processing patient LIDC-IDRI-0076, number of CT slices: 297
# Processing patient LIDC-IDRI-0228, number of CT slices: 127
# Processing patient LIDC-IDRI-0069, number of CT slices: 136
# [Epoch 50/50] [Batch 43/48] [D loss: 0.0033] [G loss: 5.8677]
# Processing patient LIDC-IDRI-0168, number of CT slices: 232
# Processing patient LIDC-IDRI-0084, number of CT slices: 166
# Processing patient LIDC-IDRI-0142, number of CT slices: 333
# Processing patient LIDC-IDRI-0108, number of CT slices: 143
# [Epoch 50/50] [Batch 44/48] [D loss: 0.0048] [G loss: 6.0445]
# Processing patient LIDC-IDRI-0263, number of CT slices: 137
# Processing patient LIDC-IDRI-0014, number of CT slices: 114
# Processing patient LIDC-IDRI-0139, number of CT slices: 114
# Processing patient LIDC-IDRI-0145, number of CT slices: 139
# [Epoch 50/50] [Batch 45/48] [D loss: 0.0039] [G loss: 5.3817]
# Processing patient LIDC-IDRI-0219, number of CT slices: 133
# Processing patient LIDC-IDRI-0004, number of CT slices: 241
# Processing patient LIDC-IDRI-0248, number of CT slices: 117
# Processing patient LIDC-IDRI-0148, number of CT slices: 131
# [Epoch 50/50] [Batch 46/48] [D loss: 0.0040] [G loss: 5.3903]
# Processing patient LIDC-IDRI-0051, number of CT slices: 133
# Processing patient LIDC-IDRI-0260, number of CT slices: 144
# Processing patient LIDC-IDRI-0060, number of CT slices: 115
# Processing patient LIDC-IDRI-0022, number of CT slices: 133
# [Epoch 50/50] [Batch 47/48] [D loss: 0.0032] [G loss: 5.4604]
# Processing patient LIDC-IDRI-0218, number of CT slices: 217
# Processing patient LIDC-IDRI-0110, number of CT slices: 125
# Processing patient LIDC-IDRI-0047, number of CT slices: 133
# [Epoch 50/50] [Batch 48/48] [D loss: 0.0070] [G loss: 5.5875]

# %%
# After training is done, save the models and optimizers
torch.save({
    'epoch': n_epochs,
    'generator_state_dict': generator.state_dict(),
    'discriminator_state_dict': discriminator.state_dict(),
    'optimizer_G_state_dict': optimizer_G.state_dict(),
    'optimizer_D_state_dict': optimizer_D.state_dict(),
    'scaler_state_dict': scaler.state_dict(),
}, 'conddcgan_model_checkpoint.pth')

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from skimage.metrics import structural_similarity as ssim, peak_signal_noise_ratio as psnr

def visualize_results(generator, dataloader, device):
    generator.eval()
    with torch.no_grad():
        for i, batch in enumerate(dataloader):
            xray = batch['xray'].to(device, non_blocking=True)
            ct_real = batch['ct'].to(device, non_blocking=True)

            # Generate CT scans
            gen_ct = generator(xray)

            # Select the first sample from the batch
            xray_np = xray[0].squeeze().cpu().numpy()        # Shape: [img_size, img_size]
            ct_real_np = ct_real[0].squeeze().cpu().numpy()  # Shape: [ct_slices, img_size, img_size]
            gen_ct_np = gen_ct[0].squeeze().cpu().numpy()    # Shape: [ct_slices, img_size, img_size]

            # Print shapes for debugging
            print(f"xray_np.shape: {xray_np.shape}")
            print(f"ct_real_np.shape: {ct_real_np.shape}")
            print(f"gen_ct_np.shape: {gen_ct_np.shape}")

            # Select a slice to visualize (e.g., middle slice)
            slice_idx = ct_slices // 2
            ct_real_slice = ct_real_np[slice_idx]
            gen_ct_slice = gen_ct_np[slice_idx]

            # Calculate PSNR and SSIM for the selected slice
            psnr_value = psnr(ct_real_slice, gen_ct_slice, data_range=gen_ct_slice.max() - gen_ct_slice.min())
            ssim_value = ssim(ct_real_slice, gen_ct_slice, data_range=gen_ct_slice.max() - gen_ct_slice.min())

            # Plot X-ray, real CT slice, and generated CT slice
            fig, axs = plt.subplots(1, 3, figsize=(15, 5))
            axs[0].imshow(xray_np, cmap='gray')
            axs[0].set_title('Input X-ray')
            axs[0].axis('off')

            axs[1].imshow(ct_real_slice, cmap='gray')
            axs[1].set_title('Real CT Slice')
            axs[1].axis('off')

            axs[2].imshow(gen_ct_slice, cmap='gray')
            axs[2].set_title(f'Generated CT Slice\nPSNR: {psnr_value:.2f}, SSIM: {ssim_value:.4f}')
            axs[2].axis('off')

            plt.show()

            # Visualize only one sample
            break

# %%
def calculate_metrics(generator, dataloader, device):
    generator.eval()
    mse_total = 0.0
    psnr_total = 0.0
    ssim_total = 0.0
    num_slices = 0

    with torch.no_grad():
        for batch in dataloader:
            xray = batch['xray'].to(device, non_blocking=True)
            ct_real = batch['ct'].to(device, non_blocking=True)

            # Generate CT scans
            gen_ct = generator(xray)

            # Convert to numpy arrays
            ct_real_np = ct_real.cpu().numpy()  # Shape: [batch_size, 1, ct_slices, img_size, img_size]
            gen_ct_np = gen_ct.cpu().numpy()    # Shape: [batch_size, 1, ct_slices, img_size, img_size]

            # Remove singleton channel dimension
            ct_real_np = np.squeeze(ct_real_np, axis=1)  # Shape: [batch_size, ct_slices, img_size, img_size]
            gen_ct_np = np.squeeze(gen_ct_np, axis=1)    # Shape: [batch_size, ct_slices, img_size, img_size]

            # Loop over batch and slices
            batch_size = ct_real_np.shape[0]

            for b in range(batch_size):
                for s in range(ct_slices):
                    real_slice = ct_real_np[b, s]
                    gen_slice = gen_ct_np[b, s]

                    mse = np.mean((real_slice - gen_slice) ** 2)
                    psnr_value = psnr(real_slice, gen_slice, data_range=gen_slice.max() - gen_slice.min())
                    ssim_value = ssim(real_slice, gen_slice, data_range=gen_slice.max() - gen_slice.min())

                    mse_total += mse
                    psnr_total += psnr_value
                    ssim_total += ssim_value
                    num_slices += 1

    # Average the metrics
    mse_avg = mse_total / num_slices
    psnr_avg = psnr_total / num_slices
    ssim_avg = ssim_total / num_slices

    print(f"Average MSE: {mse_avg:.4f}")
    print(f"Average PSNR: {psnr_avg:.2f} dB")
    print(f"Average SSIM: {ssim_avg:.4f}")

# %%
# Visualize results
visualize_results(generator, dataloader, device)

# Calculate metrics
calculate_metrics(generator, dataloader, device)
# Out:
# Processing patient LIDC-IDRI-0178, number of CT slices: 125
# Processing patient LIDC-IDRI-0110, number of CT slices: 125
# Processing patient LIDC-IDRI-0119, number of CT slices: 345
# Processing patient LIDC-IDRI-0114, number of CT slices: 214
# xray_np.shape: (256, 256)
# ct_real_np.shape: (128, 256, 256)
# gen_ct_np.shape: (128, 256, 256)
# Processing patient LIDC-IDRI-0070, number of CT slices: 133
# Processing patient LIDC-IDRI-0263, number of CT slices: 137
# Processing patient LIDC-IDRI-0012, number of CT slices: 128
# Processing patient LIDC-IDRI-0129, number of CT slices: 253
# Processing patient LIDC-IDRI-0233, number of CT slices: 147
# Processing patient LIDC-IDRI-0008, number of CT slices: 133
# Processing patient LIDC-IDRI-0209, number of CT slices: 141
# Processing patient LIDC-IDRI-0084, number of CT slices: 166
# Processing patient LIDC-IDRI-0229, number of CT slices: 141
# Processing patient LIDC-IDRI-0220, number of CT slices: 232
# Processing patient LIDC-IDRI-0040, number of CT slices: 121
# Processing patient LIDC-IDRI-0267, number of CT slices: 150
# Processing patient LIDC-IDRI-0029, number of CT slices: 273
# Processing patient LIDC-IDRI-0204, number of CT slices: 133
# Processing patient LIDC-IDRI-0217, number of CT slices: 135
# Processing patient LIDC-IDRI-0011, number of CT slices: 128
# Processing patient LIDC-IDRI-0081, number of CT slices: 126
# Processing patient LIDC-IDRI-0045, number of CT slices: 133
# Processing patient LIDC-IDRI-0027, number of CT slices: 133
# Processing patient LIDC-IDRI-0246, number of CT slices: 143
# Processing patient LIDC-IDRI-0194, number of CT slices: 149
# Processing patient LIDC-IDRI-0047, number of CT slices: 133
# Processing patient LIDC-IDRI-0079, number of CT slices: 113
# Processing patient LIDC-IDRI-0228, number of CT slices: 127
# Processing patient LIDC-IDRI-0189, number of CT slices: 117
# Processing patient LIDC-IDRI-0064, number of CT slices: 133
# Processing patient LIDC-IDRI-0125, number of CT slices: 238
# Processing patient LIDC-IDRI-0072, number of CT slices: 305
# Processing patient LIDC-IDRI-0132, number of CT slices: 127
# Processing patient LIDC-IDRI-0280, number of CT slices: 238
# Processing patient LIDC-IDRI-0074, number of CT slices: 109
# Processing patient LIDC-IDRI-0096, number of CT slices: 127
# Processing patient LIDC-IDRI-0195, number of CT slices: 133
# Processing patient LIDC-IDRI-0083, number of CT slices: 218
# Processing patient LIDC-IDRI-0178, number of CT slices: 125
# Processing patient LIDC-IDRI-0208, number of CT slices: 109
# Processing patient LIDC-IDRI-0039, number of CT slices: 281
# Processing patient LIDC-IDRI-0037, number of CT slices: 141
# Processing patient LIDC-IDRI-0157, number of CT slices: 133
# Processing patient LIDC-IDRI-0102, number of CT slices: 143
# Processing patient LIDC-IDRI-0146, number of CT slices: 310
# Processing patient LIDC-IDRI-0001, number of CT slices: 133
# Processing patient LIDC-IDRI-0089, number of CT slices: 147
# Processing patient LIDC-IDRI-0168, number of CT slices: 232
# Processing patient LIDC-IDRI-0154, number of CT slices: 115
# Processing patient LIDC-IDRI-0253, number of CT slices: 133
# Processing patient LIDC-IDRI-0188, number of CT slices: 113
# Processing patient LIDC-IDRI-0224, number of CT slices: 133
# Processing patient LIDC-IDRI-0268, number of CT slices: 117
# Processing patient LIDC-IDRI-0180, number of CT slices: 238
# Processing patient LIDC-IDRI-0094, number of CT slices: 385
# Processing patient LIDC-IDRI-0006, number of CT slices: 133
# Processing patient LIDC-IDRI-0038, number of CT slices: 133
# Processing patient LIDC-IDRI-0259, number of CT slices: 149
# Processing patient LIDC-IDRI-0258, number of CT slices: 133
# Processing patient LIDC-IDRI-0087, number of CT slices: 130
# Processing patient LIDC-IDRI-0108, number of CT slices: 143
# Processing patient LIDC-IDRI-0281, number of CT slices: 119
# Processing patient LIDC-IDRI-0167, number of CT slices: 133
# Processing patient LIDC-IDRI-0059, number of CT slices: 133
# Processing patient LIDC-IDRI-0054, number of CT slices: 133
# Processing patient LIDC-IDRI-0134, number of CT slices: 118
# Processing patient LIDC-IDRI-0018, number of CT slices: 127
# Processing patient LIDC-IDRI-0143, number of CT slices: 133
# Processing patient LIDC-IDRI-0186, number of CT slices: 137
# Processing patient LIDC-IDRI-0105, number of CT slices: 154
# Processing patient LIDC-IDRI-0262, number of CT slices: 197
# Processing patient LIDC-IDRI-0207, number of CT slices: 238
# Processing patient LIDC-IDRI-0107, number of CT slices: 136
# Processing patient LIDC-IDRI-0121, number of CT slices: 277
# Processing patient LIDC-IDRI-0025, number of CT slices: 265
# Processing patient LIDC-IDRI-0150, number of CT slices: 102
# Processing patient LIDC-IDRI-0256, number of CT slices: 131
# Processing patient LIDC-IDRI-0014, number of CT slices: 114
# Processing patient LIDC-IDRI-0028, number of CT slices: 141
# Processing patient LIDC-IDRI-0086, number of CT slices: 246
# Processing patient LIDC-IDRI-0133, number of CT slices: 238
# Processing patient LIDC-IDRI-0058, number of CT slices: 133
# Processing patient LIDC-IDRI-0021, number of CT slices: 149
# Processing patient LIDC-IDRI-0279, number of CT slices: 129
# Processing patient LIDC-IDRI-0042, number of CT slices: 123
# Processing patient LIDC-IDRI-0179, number of CT slices: 123
# Processing patient LIDC-IDRI-0031, number of CT slices: 133
# Processing patient LIDC-IDRI-0127, number of CT slices: 117
# Processing patient LIDC-IDRI-0162, number of CT slices: 133
# Processing patient LIDC-IDRI-0013, number of CT slices: 125
# Processing patient LIDC-IDRI-0099, number of CT slices: 194
# Processing patient LIDC-IDRI-0264, number of CT slices: 238
# Processing patient LIDC-IDRI-0173, number of CT slices: 145
# Processing patient LIDC-IDRI-0101, number of CT slices: 150
# Processing patient LIDC-IDRI-0160, number of CT slices: 140
# Processing patient LIDC-IDRI-0202, number of CT slices: 111
# Processing patient LIDC-IDRI-0183, number of CT slices: 139
# Processing patient LIDC-IDRI-0205, number of CT slices: 135
# Processing patient LIDC-IDRI-0115, number of CT slices: 112
# Processing patient LIDC-IDRI-0030, number of CT slices: 119
# Processing patient LIDC-IDRI-0043, number of CT slices: 113
# Processing patient LIDC-IDRI-0095, number of CT slices: 343
# Processing patient LIDC-IDRI-0093, number of CT slices: 125
# Processing patient LIDC-IDRI-0249, number of CT slices: 218
# Processing patient LIDC-IDRI-0169, number of CT slices: 238
# Processing patient LIDC-IDRI-0272, number of CT slices: 119
# Processing patient LIDC-IDRI-0223, number of CT slices: 238
# Processing patient LIDC-IDRI-0052, number of CT slices: 272
# Processing patient LIDC-IDRI-0066, number of CT slices: 733
# Processing patient LIDC-IDRI-0112, number of CT slices: 123
# Processing patient LIDC-IDRI-0067, number of CT slices: 244
# Processing patient LIDC-IDRI-0007, number of CT slices: 145
# Processing patient LIDC-IDRI-0136, number of CT slices: 153
# Processing patient LIDC-IDRI-0156, number of CT slices: 127
# Processing patient LIDC-IDRI-0119, number of CT slices: 345
# Processing patient LIDC-IDRI-0069, number of CT slices: 136
# Processing patient LIDC-IDRI-0049, number of CT slices: 133
# Processing patient LIDC-IDRI-0126, number of CT slices: 137
# Processing patient LIDC-IDRI-0016, number of CT slices: 141
# Processing patient LIDC-IDRI-0155, number of CT slices: 238
# Processing patient LIDC-IDRI-0073, number of CT slices: 131
# Processing patient LIDC-IDRI-0153, number of CT slices: 139
# Processing patient LIDC-IDRI-0078, number of CT slices: 87
# Processing patient LIDC-IDRI-0240, number of CT slices: 125
# Processing patient LIDC-IDRI-0197, number of CT slices: 127
# Processing patient LIDC-IDRI-0022, number of CT slices: 133
# Processing patient LIDC-IDRI-0041, number of CT slices: 149
# Processing patient LIDC-IDRI-0044, number of CT slices: 147
# Processing patient LIDC-IDRI-0076, number of CT slices: 297
# Processing patient LIDC-IDRI-0109, number of CT slices: 223
# Processing patient LIDC-IDRI-0035, number of CT slices: 133
# Processing patient LIDC-IDRI-0187, number of CT slices: 143
# Processing patient LIDC-IDRI-0181, number of CT slices: 150
# Processing patient LIDC-IDRI-0243, number of CT slices: 143
# Processing patient LIDC-IDRI-0077, number of CT slices: 130
# Processing patient LIDC-IDRI-0091, number of CT slices: 197
# Processing patient LIDC-IDRI-0010, number of CT slices: 284
# Processing patient LIDC-IDRI-0260, number of CT slices: 144
# Processing patient LIDC-IDRI-0130, number of CT slices: 324
# Processing patient LIDC-IDRI-0003, number of CT slices: 140
# Processing patient LIDC-IDRI-0147, number of CT slices: 136
# Processing patient LIDC-IDRI-0005, number of CT slices: 132
# Processing patient LIDC-IDRI-0117, number of CT slices: 122
# Processing patient LIDC-IDRI-0053, number of CT slices: 111
# Processing patient LIDC-IDRI-0216, number of CT slices: 133
# Processing patient LIDC-IDRI-0034, number of CT slices: 265
# Processing patient LIDC-IDRI-0145, number of CT slices: 139
# Processing patient LIDC-IDRI-0110, number of CT slices: 125
# Processing patient LIDC-IDRI-0138, number of CT slices: 273
# Processing patient LIDC-IDRI-0165, number of CT slices: 133
# Processing patient LIDC-IDRI-0236, number of CT slices: 133
# Processing patient LIDC-IDRI-0046, number of CT slices: 128
# Processing patient LIDC-IDRI-0135, number of CT slices: 127
# Processing patient LIDC-IDRI-0218, number of CT slices: 217
# Processing patient LIDC-IDRI-0103, number of CT slices: 111
# Processing patient LIDC-IDRI-0235, number of CT slices: 139
# Processing patient LIDC-IDRI-0051, number of CT slices: 133
# Processing patient LIDC-IDRI-0004, number of CT slices: 241
# Processing patient LIDC-IDRI-0123, number of CT slices: 236
# Processing patient LIDC-IDRI-0114, number of CT slices: 214
# Processing patient LIDC-IDRI-0142, number of CT slices: 333
# Processing patient LIDC-IDRI-0061, number of CT slices: 123
# Processing patient LIDC-IDRI-0184, number of CT slices: 140
# Processing patient LIDC-IDRI-0090, number of CT slices: 133
# Processing patient LIDC-IDRI-0266, number of CT slices: 238
# Processing patient LIDC-IDRI-0163, number of CT slices: 133
# Processing patient LIDC-IDRI-0075, number of CT slices: 257
# Processing patient LIDC-IDRI-0065, number of CT slices: 237
# Processing patient LIDC-IDRI-0191, number of CT slices: 133
# Processing patient LIDC-IDRI-0104, number of CT slices: 105
# Processing patient LIDC-IDRI-0257, number of CT slices: 133
# Processing patient LIDC-IDRI-0080, number of CT slices: 257
# Processing patient LIDC-IDRI-0252, number of CT slices: 148
# Processing patient LIDC-IDRI-0033, number of CT slices: 137
# Processing patient LIDC-IDRI-0139, number of CT slices: 114
# Processing patient LIDC-IDRI-0120, number of CT slices: 183
# Processing patient LIDC-IDRI-0113, number of CT slices: 145
# Processing patient LIDC-IDRI-0227, number of CT slices: 137
# Processing patient LIDC-IDRI-0144, number of CT slices: 133
# Processing patient LIDC-IDRI-0185, number of CT slices: 133
# Processing patient LIDC-IDRI-0063, number of CT slices: 133
# Processing patient LIDC-IDRI-0282, number of CT slices: 119
# Processing patient LIDC-IDRI-0271, number of CT slices: 117
# Processing patient LIDC-IDRI-0148, number of CT slices: 131
# Processing patient LIDC-IDRI-0024, number of CT slices: 133
# Processing patient LIDC-IDRI-0056, number of CT slices: 249
# Processing patient LIDC-IDRI-0036, number of CT slices: 273
# Processing patient LIDC-IDRI-0062, number of CT slices: 117
# Processing patient LIDC-IDRI-0248, number of CT slices: 117
# Processing patient LIDC-IDRI-0050, number of CT slices: 139
# Processing patient LIDC-IDRI-0023, number of CT slices: 137
# Processing patient LIDC-IDRI-0060, number of CT slices: 115
# Processing patient LIDC-IDRI-0106, number of CT slices: 158
# Processing patient LIDC-IDRI-0019, number of CT slices: 305
# Processing patient LIDC-IDRI-0219, number of CT slices: 133
# Average MSE: 0.3014
# Average PSNR: 0.71 dB
# Average SSIM: 0.0724

# %% [markdown]
# # Semi-supervised Learning with ChestX-ray14

# %%
# Initialize generator and discriminator
generator = Generator()
discriminator = Discriminator()

# Use GPU if available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
generator.to(device)
discriminator.to(device)

# Loss function
adversarial_loss = nn.BCEWithLogitsLoss()

# Optimizers
optimizer_G = optim.Adam(generator.parameters(), lr=lr, betas=(b1, b2))
optimizer_D = optim.Adam(discriminator.parameters(), lr=lr, betas=(b1, b2))

# For mixed-precision training
scaler = GradScaler()

# Load the checkpoint
checkpoint = torch.load('conddcgan_model_checkpoint.pth')

# Load state dictionaries
generator.load_state_dict(checkpoint['generator_state_dict'])
discriminator.load_state_dict(checkpoint['discriminator_state_dict'])
optimizer_G.load_state_dict(checkpoint['optimizer_G_state_dict'])
optimizer_D.load_state_dict(checkpoint['optimizer_D_state_dict'])
scaler.load_state_dict(checkpoint['scaler_state_dict'])

# Set the starting epoch
start_epoch = checkpoint['epoch']

import os
import numpy as np
from glob import glob
from skimage.transform import resize
from PIL import Image
from tqdm import tqdm  # For progress bar
from torch.utils.data import Dataset, DataLoader

# Ensure the generator is in evaluation mode for inference
generator.eval()

# Path to the ChestX-ray14 dataset
chest_xray14_root = 'ChestX-ray14/'

# Directory to save the generated data
generated_data_root = 'Cond_DCGAN_Generated_LIDC-IDRI/'

# Create the root directory if it doesn't exist
os.makedirs(generated_data_root, exist_ok=True)

# Get the list of X-ray images
xray_image_paths = [os.path.join(chest_xray14_root, fname)
                    for fname in os.listdir(chest_xray14_root) if fname.endswith('.png')]

# Function to load and preprocess ChestX-ray14 images
def load_and_preprocess_chest_xray(image_path):
    # Load the image
    image = Image.open(image_path).convert('L')  # Convert to grayscale
    image = np.array(image).astype(np.float32)

    # Normalize the image
    image = (image - image.min()) / (image.max() - image.min())

    # Resize the image
    image = resize(image, (img_size, img_size), mode='constant', anti_aliasing=True)

    # Convert to tensor and add channel dimension
    image_tensor = torch.tensor(image, dtype=torch.float32).unsqueeze(0).unsqueeze(0)
    return image_tensor

# Iterate over the ChestX-ray14 images and generate CT slices
for idx, xray_image_path in tqdm(enumerate(xray_image_paths), total=len(xray_image_paths)):
    # Create a unique patient ID
    patient_id = f'ChestXray14_{idx+1:05d}'
    patient_dir = os.path.join(generated_data_root, patient_id)
    ct_dir = os.path.join(patient_dir, 'CT')
    xray_dir = os.path.join(patient_dir, 'Xray')
    os.makedirs(ct_dir, exist_ok=True)
    os.makedirs(xray_dir, exist_ok=True)

    # Load and preprocess the X-ray image
    xray_tensor = load_and_preprocess_chest_xray(xray_image_path).to(device)

    # Generate CT slices
    with torch.no_grad():
        gen_ct = generator(xray_tensor)

    # Convert generated CT to numpy array
    gen_ct_np = gen_ct.squeeze().cpu().numpy()  # Shape: [ct_slices, img_size, img_size]

    # Save generated CT slices
    for i in range(ct_slices):
        slice_image = gen_ct_np[i]  # Shape: [img_size, img_size]
        # Normalize and convert to uint16
        slice_image = (slice_image - slice_image.min()) / (slice_image.max() - slice_image.min())
        slice_image_uint16 = (slice_image * 65535).astype(np.uint16)
        # Save as PNG
        slice_filename = os.path.join(ct_dir, f'slice_{i:03d}.png')
        Image.fromarray(slice_image_uint16).save(slice_filename)

    # Save the preprocessed X-ray image
    xray_np = xray_tensor.squeeze().cpu().numpy()  # Shape: [img_size, img_size]
    xray_uint16 = (xray_np * 65535).astype(np.uint16)
    xray_filename = os.path.join(xray_dir, 'xray.png')
    Image.fromarray(xray_uint16).save(xray_filename)

# Switch models back to training mode
generator.train()
discriminator.train()
# Out:
# <ipython-input-12-98557ad4bc18>:21: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load('conddcgan_model_checkpoint.pth')
# 100%|██████████| 200/200 [09:06<00:00,  2.73s/it]
# Discriminator(
#   (model): Sequential(
#     (0): Conv3d(2, 32, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#     (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     (3): Conv3d(32, 64, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#     (4): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): LeakyReLU(negative_slope=0.2, inplace=True)
#     (6): Conv3d(64, 128, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#     (7): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): LeakyReLU(negative_slope=0.2, inplace=True)
#     (9): Conv3d(128, 256, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#     (10): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (11): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (pool): AdaptiveAvgPool3d(output_size=(1, 1, 1))
#   (adv_layer): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=256, out_features=1, bias=True)
#   )
# )

# %%
# Modified Dataset class
class XrayCTDataset(Dataset):
    def __init__(self, root_dirs):
        self.patient_dirs = []
        for root_dir in root_dirs:
            patients = sorted(os.listdir(root_dir))
            patients = [p for p in patients if os.path.isdir(os.path.join(root_dir, p))]
            self.patient_dirs.extend([os.path.join(root_dir, p) for p in patients])

    def __len__(self):
        return len(self.patient_dirs)

    def __getitem__(self, idx):
        patient_dir = self.patient_dirs[idx]

        # Load and preprocess X-ray image
        xray_path = glob(os.path.join(patient_dir, 'Xray', '*'))[0]
        xray = self.load_and_preprocess_image(xray_path)

        # Load and preprocess CT slices
        ct_dir = os.path.join(patient_dir, 'CT')
        ct_slice_paths = sorted(glob(os.path.join(ct_dir, '*')))
        ct_slices_array = self.load_and_preprocess_ct_slices(ct_slice_paths)

        sample = {'xray': xray, 'ct': ct_slices_array}

        return sample

    def load_and_preprocess_image(self, image_path):
        # Check if the image is DICOM or PNG
        if image_path.endswith('.dcm'):
            # Load DICOM image
            ds = pydicom.dcmread(image_path)
            image = ds.pixel_array.astype(np.float32)
        else:
            # Load PNG image
            image = Image.open(image_path).convert('L')
            image = np.array(image).astype(np.float32)

        # Normalize the image
        image = (image - image.min()) / (image.max() - image.min())

        # Resize the image
        image = resize(image, (img_size, img_size), mode='constant', anti_aliasing=True)

        # Convert to tensor and add channel dimension
        image = torch.tensor(image, dtype=torch.float32).unsqueeze(0)
        return image

    def load_and_preprocess_ct_slices(self, slice_paths):
        num_slices = len(slice_paths)
        desired_slices = ct_slices

        # Calculate indices to select slices for alignment
        indices = np.linspace(0, num_slices - 1, desired_slices).astype(int)

        # Preallocate a list for the CT slices
        ct_slices_list = []
        for idx in indices:
            p = slice_paths[idx]
            # Load and preprocess each slice
            slice_ = self.load_and_preprocess_image(p)
            ct_slices_list.append(slice_)

        # Stack slices into a 3D volume
        ct_slices_array = torch.stack(ct_slices_list, dim=0)  # Shape: [ct_slices, 1, img_size, img_size]
        ct_slices_array = ct_slices_array.squeeze(1)  # Shape: [ct_slices, img_size, img_size]
        ct_slices_array = ct_slices_array.unsqueeze(0)  # Shape: [1, ct_slices, img_size, img_size]

        return ct_slices_array  # Return shape: [1, ct_slices, img_size, img_size]

# %%
# Paths to the datasets
original_dataset_root = 'LIDC-IDRI/'
generated_dataset_root = 'Cond_DCGAN_Generated_LIDC-IDRI/'

# Create dataset and dataloader with both datasets
combined_dataset = XrayCTDataset(root_dirs=[original_dataset_root, generated_dataset_root])
combined_dataloader = DataLoader(combined_dataset, batch_size=batch_size, shuffle=True, num_workers=0, pin_memory=True)

# %%
n_epochs = 70

# Training loop with the combined dataset
for epoch in range(start_epoch, n_epochs):
    for i, batch in enumerate(combined_dataloader):
        xray = batch['xray'].to(device, non_blocking=True)
        ct = batch['ct'].to(device, non_blocking=True)

        # Reshape ct to [B, 1, ct_slices, img_size, img_size]
        # (Already in correct shape)

        valid = torch.ones((xray.size(0), 1), requires_grad=False).to(device)
        fake = torch.zeros((xray.size(0), 1), requires_grad=False).to(device)

        # -----------------
        #  Train Generator
        # -----------------
        optimizer_G.zero_grad()

        with autocast(device_type='cuda' if device.type == 'cuda' else 'cpu'):
            # Generate CT scans
            gen_ct = generator(xray)

            # Generator loss
            g_loss = adversarial_loss(discriminator(gen_ct, xray), valid)

        scaler.scale(g_loss).backward()
        scaler.step(optimizer_G)
        scaler.update()

        # ---------------------
        #  Train Discriminator
        # ---------------------
        optimizer_D.zero_grad()

        with autocast(device_type='cuda' if device.type == 'cuda' else 'cpu'):
            # Real CT loss
            real_loss = adversarial_loss(discriminator(ct, xray), valid)
            # Fake CT loss
            fake_loss = adversarial_loss(discriminator(gen_ct.detach(), xray), fake)
            # Total discriminator loss
            d_loss = 0.5 * (real_loss + fake_loss)

        scaler.scale(d_loss).backward()
        scaler.step(optimizer_D)
        scaler.update()

        # Print training progress
        print(f"[Epoch {epoch+1}/{n_epochs}] [Batch {i+1}/{len(combined_dataloader)}] "
              f"[D loss: {d_loss.item():.4f}] [G loss: {g_loss.item():.4f}]")

    # Save the checkpoint after each epoch
    torch.save({
        'epoch': epoch + 1,  # Save the next epoch number
        'generator_state_dict': generator.state_dict(),
        'discriminator_state_dict': discriminator.state_dict(),
        'optimizer_G_state_dict': optimizer_G.state_dict(),
        'optimizer_D_state_dict': optimizer_D.state_dict(),
        'scaler_state_dict': scaler.state_dict(),
    }, 'semi_sup_conddcgan_model_checkpoint.pth')
# Out:
# [Epoch 51/70] [Batch 1/98] [D loss: 0.0984] [G loss: 6.3587]
# <ipython-input-13-4552ba6c9bc3>:41: RuntimeWarning: invalid value encountered in divide
#   image = (image - image.min()) / (image.max() - image.min())
# /usr/local/lib/python3.10/dist-packages/skimage/transform/_warps.py:738: RuntimeWarning: All-NaN slice encountered
#   min_val = min_func(input_image)
# /usr/local/lib/python3.10/dist-packages/skimage/transform/_warps.py:742: RuntimeWarning: All-NaN slice encountered
#   max_val = max_func(input_image)
# /usr/local/lib/python3.10/dist-packages/skimage/transform/_warps.py:749: RuntimeWarning: All-NaN slice encountered
#   and min_func(output_image) <= cval <= max_func(output_image)
# [Epoch 51/70] [Batch 2/98] [D loss: nan] [G loss: nan]
# [Epoch 51/70] [Batch 3/98] [D loss: 0.3627] [G loss: 3.5459]
# [Epoch 51/70] [Batch 4/98] [D loss: 0.1235] [G loss: 4.4688]
# [Epoch 51/70] [Batch 5/98] [D loss: 0.6498] [G loss: 4.7717]
# [Epoch 51/70] [Batch 6/98] [D loss: 1.7565] [G loss: 0.5607]
# [Epoch 51/70] [Batch 7/98] [D loss: 1.3024] [G loss: 0.9841]
# [Epoch 51/70] [Batch 8/98] [D loss: 0.8609] [G loss: 0.4611]
# [Epoch 51/70] [Batch 9/98] [D loss: 0.7545] [G loss: 0.3960]
# [Epoch 51/70] [Batch 10/98] [D loss: 0.7330] [G loss: 0.4244]
# [Epoch 51/70] [Batch 11/98] [D loss: 0.7070] [G loss: 0.4946]
# [Epoch 51/70] [Batch 12/98] [D loss: 0.5932] [G loss: 0.6338]
# [Epoch 51/70] [Batch 13/98] [D loss: 0.5138] [G loss: 0.9513]
# [Epoch 51/70] [Batch 14/98] [D loss: 0.5339] [G loss: 1.3609]
# [Epoch 51/70] [Batch 15/98] [D loss: 0.5966] [G loss: 0.8086]
# [Epoch 51/70] [Batch 16/98] [D loss: 0.6590] [G loss: 0.9986]
# [Epoch 51/70] [Batch 17/98] [D loss: 0.5073] [G loss: 1.1901]
# [Epoch 51/70] [Batch 18/98] [D loss: nan] [G loss: nan]
# [Epoch 51/70] [Batch 19/98] [D loss: 0.5706] [G loss: 0.9342]
# [Epoch 51/70] [Batch 20/98] [D loss: nan] [G loss: nan]
# [Epoch 51/70] [Batch 21/98] [D loss: 0.5795] [G loss: 0.9270]
# [Epoch 51/70] [Batch 22/98] [D loss: 0.5272] [G loss: 0.8338]
# [Epoch 51/70] [Batch 23/98] [D loss: 0.5921] [G loss: 0.8271]
# [Epoch 51/70] [Batch 24/98] [D loss: 0.7335] [G loss: 0.4415]
# [Epoch 51/70] [Batch 25/98] [D loss: 0.5328] [G loss: 0.9527]
# [Epoch 51/70] [Batch 26/98] [D loss: 0.5411] [G loss: 0.8816]
# [Epoch 51/70] [Batch 27/98] [D loss: 0.4912] [G loss: 1.1090]
# [Epoch 51/70] [Batch 28/98] [D loss: 0.5394] [G loss: 0.9135]
# [Epoch 51/70] [Batch 29/98] [D loss: 0.4951] [G loss: 1.1739]
# [Epoch 51/70] [Batch 30/98] [D loss: 0.5962] [G loss: 0.7917]
# [Epoch 51/70] [Batch 31/98] [D loss: 0.4539] [G loss: 0.9733]
# [Epoch 51/70] [Batch 32/98] [D loss: 0.5743] [G loss: 0.6952]
# [Epoch 51/70] [Batch 33/98] [D loss: 0.5561] [G loss: 0.7648]
# [Epoch 51/70] [Batch 34/98] [D loss: 0.5504] [G loss: 0.9990]
# [Epoch 51/70] [Batch 35/98] [D loss: 1.2286] [G loss: 1.9745]
# [Epoch 51/70] [Batch 36/98] [D loss: nan] [G loss: nan]
# [Epoch 51/70] [Batch 37/98] [D loss: 1.3867] [G loss: 2.0848]
# [Epoch 51/70] [Batch 38/98] [D loss: 0.6039] [G loss: 0.7781]
# [Epoch 51/70] [Batch 39/98] [D loss: 0.5624] [G loss: 0.7591]
# [Epoch 51/70] [Batch 40/98] [D loss: 0.5341] [G loss: 0.9170]
# [Epoch 51/70] [Batch 41/98] [D loss: 0.5065] [G loss: 0.9644]
# [Epoch 51/70] [Batch 42/98] [D loss: 0.4626] [G loss: 1.0635]
# [Epoch 51/70] [Batch 43/98] [D loss: 0.5870] [G loss: 0.9502]
# [Epoch 51/70] [Batch 44/98] [D loss: 0.5157] [G loss: 1.0222]
# [Epoch 51/70] [Batch 45/98] [D loss: nan] [G loss: nan]
# [Epoch 51/70] [Batch 46/98] [D loss: 0.4941] [G loss: 1.1256]
# [Epoch 51/70] [Batch 47/98] [D loss: 0.4344] [G loss: 1.1125]
# [Epoch 51/70] [Batch 48/98] [D loss: 0.5850] [G loss: 0.8549]
# [Epoch 51/70] [Batch 49/98] [D loss: 0.3684] [G loss: 1.3383]
# [Epoch 51/70] [Batch 50/98] [D loss: 0.4747] [G loss: 1.1804]
# [Epoch 51/70] [Batch 51/98] [D loss: 0.3883] [G loss: 1.0745]
# [Epoch 51/70] [Batch 52/98] [D loss: 0.3674] [G loss: 1.2284]
# [Epoch 51/70] [Batch 53/98] [D loss: 0.5444] [G loss: 0.9400]
# [Epoch 51/70] [Batch 54/98] [D loss: 0.4355] [G loss: 1.1608]
# [Epoch 51/70] [Batch 55/98] [D loss: 0.3971] [G loss: 1.1237]
# [Epoch 51/70] [Batch 56/98] [D loss: 0.4981] [G loss: 1.0587]
# [Epoch 51/70] [Batch 57/98] [D loss: 0.4668] [G loss: 0.8625]
# [Epoch 51/70] [Batch 58/98] [D loss: 0.4868] [G loss: 1.0704]
# [Epoch 51/70] [Batch 59/98] [D loss: 0.4299] [G loss: 1.1881]
# [Epoch 51/70] [Batch 60/98] [D loss: 0.4480] [G loss: 0.9429]
# [Epoch 51/70] [Batch 61/98] [D loss: 0.4522] [G loss: 0.9632]
# [Epoch 51/70] [Batch 62/98] [D loss: 0.4091] [G loss: 1.1572]
# [Epoch 51/70] [Batch 63/98] [D loss: 0.3842] [G loss: 1.1556]
# [Epoch 51/70] [Batch 64/98] [D loss: 0.3642] [G loss: 1.2557]
# [Epoch 51/70] [Batch 65/98] [D loss: 0.3871] [G loss: 1.2756]
# [Epoch 51/70] [Batch 66/98] [D loss: 0.3597] [G loss: 1.2754]
# [Epoch 51/70] [Batch 67/98] [D loss: 0.3101] [G loss: 1.3121]
# [Epoch 51/70] [Batch 68/98] [D loss: 0.2831] [G loss: 1.3425]
# [Epoch 51/70] [Batch 69/98] [D loss: 0.3406] [G loss: 1.3792]
# [Epoch 51/70] [Batch 70/98] [D loss: 0.2871] [G loss: 1.3606]
# [Epoch 51/70] [Batch 71/98] [D loss: 0.3282] [G loss: 1.3739]
# [Epoch 51/70] [Batch 72/98] [D loss: 0.3798] [G loss: 1.4218]
# [Epoch 51/70] [Batch 73/98] [D loss: 0.2800] [G loss: 1.6442]
# [Epoch 51/70] [Batch 74/98] [D loss: 0.4012] [G loss: 1.8279]
# [Epoch 51/70] [Batch 75/98] [D loss: nan] [G loss: nan]
# [Epoch 51/70] [Batch 76/98] [D loss: 0.4469] [G loss: 1.6105]
# [Epoch 51/70] [Batch 77/98] [D loss: 0.2854] [G loss: 1.5094]
# [Epoch 51/70] [Batch 78/98] [D loss: 0.3233] [G loss: 1.3567]
# [Epoch 51/70] [Batch 79/98] [D loss: 0.2813] [G loss: 1.4841]
# [Epoch 51/70] [Batch 80/98] [D loss: 0.2531] [G loss: 1.4278]
# [Epoch 51/70] [Batch 81/98] [D loss: 0.2556] [G loss: 1.5140]
# [Epoch 51/70] [Batch 82/98] [D loss: 0.3175] [G loss: 1.5496]
# [Epoch 51/70] [Batch 83/98] [D loss: 0.2995] [G loss: 1.5149]
# [Epoch 51/70] [Batch 84/98] [D loss: 0.2200] [G loss: 1.5605]
# [Epoch 51/70] [Batch 85/98] [D loss: 0.2464] [G loss: 1.5547]
# [Epoch 51/70] [Batch 86/98] [D loss: nan] [G loss: nan]
# [Epoch 51/70] [Batch 87/98] [D loss: nan] [G loss: nan]
# [Epoch 51/70] [Batch 88/98] [D loss: 0.2445] [G loss: 1.7426]
# [Epoch 51/70] [Batch 89/98] [D loss: 0.2299] [G loss: 1.6611]
# [Epoch 51/70] [Batch 90/98] [D loss: nan] [G loss: nan]
# [Epoch 51/70] [Batch 91/98] [D loss: 0.2626] [G loss: 1.7075]
# [Epoch 51/70] [Batch 92/98] [D loss: 0.2703] [G loss: 1.5470]
# [Epoch 51/70] [Batch 93/98] [D loss: 0.3071] [G loss: 1.6972]
# [Epoch 51/70] [Batch 94/98] [D loss: 0.2840] [G loss: 1.5105]
# [Epoch 51/70] [Batch 95/98] [D loss: 0.2832] [G loss: 1.5683]
# [Epoch 51/70] [Batch 96/98] [D loss: 0.2599] [G loss: 1.4730]
# [Epoch 51/70] [Batch 97/98] [D loss: 0.2626] [G loss: 1.4631]
# [Epoch 51/70] [Batch 98/98] [D loss: 0.2989] [G loss: 1.5482]
# [Epoch 52/70] [Batch 1/98] [D loss: 0.2566] [G loss: 1.6515]
# [Epoch 52/70] [Batch 2/98] [D loss: 0.2194] [G loss: 1.6159]
# [Epoch 52/70] [Batch 3/98] [D loss: 0.1850] [G loss: 1.7202]
# [Epoch 52/70] [Batch 4/98] [D loss: 0.2773] [G loss: 1.4026]
# [Epoch 52/70] [Batch 5/98] [D loss: 0.3195] [G loss: 1.3777]
# [Epoch 52/70] [Batch 6/98] [D loss: nan] [G loss: nan]
# [Epoch 52/70] [Batch 7/98] [D loss: 0.2972] [G loss: 1.3317]
# [Epoch 52/70] [Batch 8/98] [D loss: 0.2548] [G loss: 1.4512]
# [Epoch 52/70] [Batch 9/98] [D loss: 0.3993] [G loss: 1.9683]
# [Epoch 52/70] [Batch 10/98] [D loss: 0.3065] [G loss: 1.5816]
# [Epoch 52/70] [Batch 11/98] [D loss: 0.2234] [G loss: 1.7322]
# [Epoch 52/70] [Batch 12/98] [D loss: 0.3811] [G loss: 1.0325]
# [Epoch 52/70] [Batch 13/98] [D loss: nan] [G loss: nan]
# [Epoch 52/70] [Batch 14/98] [D loss: 0.3614] [G loss: 1.3527]
# [Epoch 52/70] [Batch 15/98] [D loss: 0.4165] [G loss: 2.0269]
# [Epoch 52/70] [Batch 16/98] [D loss: 0.2534] [G loss: 1.6991]
# [Epoch 52/70] [Batch 17/98] [D loss: 0.3084] [G loss: 1.5410]
# [Epoch 52/70] [Batch 18/98] [D loss: 0.2786] [G loss: 1.5235]
# [Epoch 52/70] [Batch 19/98] [D loss: 0.3238] [G loss: 1.7084]
# [Epoch 52/70] [Batch 20/98] [D loss: 0.2168] [G loss: 1.7455]
# [Epoch 52/70] [Batch 21/98] [D loss: 0.2565] [G loss: 1.6644]
# [Epoch 52/70] [Batch 22/98] [D loss: 0.2335] [G loss: 1.6234]
# [Epoch 52/70] [Batch 23/98] [D loss: nan] [G loss: nan]
# [Epoch 52/70] [Batch 24/98] [D loss: 0.3287] [G loss: 1.4260]
# [Epoch 52/70] [Batch 25/98] [D loss: 0.3537] [G loss: 1.7228]
# [Epoch 52/70] [Batch 26/98] [D loss: 0.3259] [G loss: 1.5074]
# [Epoch 52/70] [Batch 27/98] [D loss: 0.3268] [G loss: 1.5014]
# [Epoch 52/70] [Batch 28/98] [D loss: 0.2571] [G loss: 1.6918]
# [Epoch 52/70] [Batch 29/98] [D loss: nan] [G loss: nan]
# [Epoch 52/70] [Batch 30/98] [D loss: 0.2491] [G loss: 1.6936]
# [Epoch 52/70] [Batch 31/98] [D loss: 0.2351] [G loss: 1.7734]
# [Epoch 52/70] [Batch 32/98] [D loss: 0.2174] [G loss: 1.7662]
# [Epoch 52/70] [Batch 33/98] [D loss: 0.2198] [G loss: 1.6620]
# [Epoch 52/70] [Batch 34/98] [D loss: 0.2389] [G loss: 1.6804]
# [Epoch 52/70] [Batch 35/98] [D loss: 0.2155] [G loss: 1.8186]
# [Epoch 52/70] [Batch 36/98] [D loss: 0.2311] [G loss: 1.6783]
# [Epoch 52/70] [Batch 37/98] [D loss: 0.2794] [G loss: 1.6928]
# [Epoch 52/70] [Batch 38/98] [D loss: 0.2788] [G loss: 1.7617]
# [Epoch 52/70] [Batch 39/98] [D loss: 0.3022] [G loss: 1.4877]
# [Epoch 52/70] [Batch 40/98] [D loss: 0.2376] [G loss: 1.6491]
# [Epoch 52/70] [Batch 41/98] [D loss: 0.2704] [G loss: 1.5233]
# [Epoch 52/70] [Batch 42/98] [D loss: 0.2544] [G loss: 1.6346]
# [Epoch 52/70] [Batch 43/98] [D loss: 0.3156] [G loss: 1.6485]
# [Epoch 52/70] [Batch 44/98] [D loss: 0.2406] [G loss: 1.6426]
# [Epoch 52/70] [Batch 45/98] [D loss: 0.2288] [G loss: 1.5935]
# [Epoch 52/70] [Batch 46/98] [D loss: 0.3352] [G loss: 1.7917]
# [Epoch 52/70] [Batch 47/98] [D loss: 0.2318] [G loss: 1.7063]
# [Epoch 52/70] [Batch 48/98] [D loss: 0.4054] [G loss: 1.1260]
# [Epoch 52/70] [Batch 49/98] [D loss: 0.3237] [G loss: 1.6933]
# [Epoch 52/70] [Batch 50/98] [D loss: 0.2514] [G loss: 1.5461]
# [Epoch 52/70] [Batch 51/98] [D loss: 0.2661] [G loss: 1.5479]
# [Epoch 52/70] [Batch 52/98] [D loss: 0.3619] [G loss: 1.1594]
# [Epoch 52/70] [Batch 53/98] [D loss: 0.2692] [G loss: 1.6691]
# [Epoch 52/70] [Batch 54/98] [D loss: 0.3119] [G loss: 1.7111]
# [Epoch 52/70] [Batch 55/98] [D loss: 0.2463] [G loss: 1.6287]
# [Epoch 52/70] [Batch 56/98] [D loss: 0.2278] [G loss: 1.7549]
# [Epoch 52/70] [Batch 57/98] [D loss: 0.2969] [G loss: 1.2496]
# [Epoch 52/70] [Batch 58/98] [D loss: 0.2123] [G loss: 1.7253]
# [Epoch 52/70] [Batch 59/98] [D loss: 0.1740] [G loss: 1.9066]
# [Epoch 52/70] [Batch 60/98] [D loss: 0.2662] [G loss: 1.5112]
# [Epoch 52/70] [Batch 61/98] [D loss: 0.3383] [G loss: 1.7175]
# [Epoch 52/70] [Batch 62/98] [D loss: 0.2388] [G loss: 1.5290]
# [Epoch 52/70] [Batch 63/98] [D loss: nan] [G loss: nan]
# [Epoch 52/70] [Batch 64/98] [D loss: 0.2868] [G loss: 1.6201]
# [Epoch 52/70] [Batch 65/98] [D loss: 0.2590] [G loss: 1.6762]
# [Epoch 52/70] [Batch 66/98] [D loss: 0.3257] [G loss: 1.5993]
# [Epoch 52/70] [Batch 67/98] [D loss: 0.2355] [G loss: 1.7093]
# [Epoch 52/70] [Batch 68/98] [D loss: 0.2336] [G loss: 1.7034]
# [Epoch 52/70] [Batch 69/98] [D loss: 0.2608] [G loss: 1.7865]
# [Epoch 52/70] [Batch 70/98] [D loss: 0.2334] [G loss: 1.7830]
# [Epoch 52/70] [Batch 71/98] [D loss: 0.2884] [G loss: 1.6254]
# [Epoch 52/70] [Batch 72/98] [D loss: nan] [G loss: nan]
# [Epoch 52/70] [Batch 73/98] [D loss: 0.2450] [G loss: 1.6407]
# [Epoch 52/70] [Batch 74/98] [D loss: 0.2960] [G loss: 1.7350]
# [Epoch 52/70] [Batch 75/98] [D loss: 0.3750] [G loss: 1.8291]
# [Epoch 52/70] [Batch 76/98] [D loss: nan] [G loss: nan]
# [Epoch 52/70] [Batch 77/98] [D loss: 0.2263] [G loss: 1.5425]
# [Epoch 52/70] [Batch 78/98] [D loss: 0.2299] [G loss: 1.6450]
# [Epoch 52/70] [Batch 79/98] [D loss: nan] [G loss: nan]
# [Epoch 52/70] [Batch 80/98] [D loss: 0.2186] [G loss: 1.6838]
# [Epoch 52/70] [Batch 81/98] [D loss: 0.2992] [G loss: 1.6766]
# [Epoch 52/70] [Batch 82/98] [D loss: 0.2399] [G loss: 1.5905]
# [Epoch 52/70] [Batch 83/98] [D loss: nan] [G loss: nan]
# [Epoch 52/70] [Batch 84/98] [D loss: 0.2616] [G loss: 1.5474]
# [Epoch 52/70] [Batch 85/98] [D loss: 0.2108] [G loss: 1.5788]
# [Epoch 52/70] [Batch 86/98] [D loss: 0.2567] [G loss: 1.8120]
# [Epoch 52/70] [Batch 87/98] [D loss: 0.2459] [G loss: 2.0524]
# [Epoch 52/70] [Batch 88/98] [D loss: 0.2451] [G loss: 1.5552]
# [Epoch 52/70] [Batch 89/98] [D loss: 0.2163] [G loss: 1.7481]
# [Epoch 52/70] [Batch 90/98] [D loss: 0.2310] [G loss: 1.5378]
# [Epoch 52/70] [Batch 91/98] [D loss: 0.2763] [G loss: 1.6055]
# [Epoch 52/70] [Batch 92/98] [D loss: 0.2305] [G loss: 1.6300]
# [Epoch 52/70] [Batch 93/98] [D loss: 0.4101] [G loss: 1.8927]
# [Epoch 52/70] [Batch 94/98] [D loss: 0.2216] [G loss: 1.6509]
# [Epoch 52/70] [Batch 95/98] [D loss: 0.2452] [G loss: 1.7426]
# [Epoch 52/70] [Batch 96/98] [D loss: 0.2165] [G loss: 1.6095]
# [Epoch 52/70] [Batch 97/98] [D loss: 0.1987] [G loss: 1.8775]
# [Epoch 52/70] [Batch 98/98] [D loss: 0.2655] [G loss: 1.4390]
# [Epoch 53/70] [Batch 1/98] [D loss: 0.2828] [G loss: 1.7448]
# [Epoch 53/70] [Batch 2/98] [D loss: nan] [G loss: nan]
# [Epoch 53/70] [Batch 3/98] [D loss: 0.2465] [G loss: 1.5868]
# [Epoch 53/70] [Batch 4/98] [D loss: 0.2967] [G loss: 1.5561]
# [Epoch 53/70] [Batch 5/98] [D loss: 0.2433] [G loss: 1.7420]
# [Epoch 53/70] [Batch 6/98] [D loss: 0.2369] [G loss: 1.4683]
# [Epoch 53/70] [Batch 7/98] [D loss: 0.2547] [G loss: 1.4848]
# [Epoch 53/70] [Batch 8/98] [D loss: 0.3019] [G loss: 1.5510]
# [Epoch 53/70] [Batch 9/98] [D loss: nan] [G loss: nan]
# [Epoch 53/70] [Batch 10/98] [D loss: nan] [G loss: nan]
# [Epoch 53/70] [Batch 11/98] [D loss: 0.3621] [G loss: 1.1093]
# [Epoch 53/70] [Batch 12/98] [D loss: 0.2377] [G loss: 1.5263]
# [Epoch 53/70] [Batch 13/98] [D loss: 0.2201] [G loss: 1.7339]
# [Epoch 53/70] [Batch 14/98] [D loss: 0.3077] [G loss: 1.7777]
# [Epoch 53/70] [Batch 15/98] [D loss: 0.1815] [G loss: 1.8502]
# [Epoch 53/70] [Batch 16/98] [D loss: 0.2990] [G loss: 1.4299]
# [Epoch 53/70] [Batch 17/98] [D loss: 0.3202] [G loss: 1.2327]
# [Epoch 53/70] [Batch 18/98] [D loss: 0.2701] [G loss: 1.4530]
# [Epoch 53/70] [Batch 19/98] [D loss: 0.2913] [G loss: 1.4394]
# [Epoch 53/70] [Batch 20/98] [D loss: 0.4115] [G loss: 1.0781]
# [Epoch 53/70] [Batch 21/98] [D loss: 0.2341] [G loss: 1.7753]
# [Epoch 53/70] [Batch 22/98] [D loss: 0.2609] [G loss: 1.4441]
# [Epoch 53/70] [Batch 23/98] [D loss: 0.2331] [G loss: 1.6532]
# [Epoch 53/70] [Batch 24/98] [D loss: 0.3882] [G loss: 1.9700]
# [Epoch 53/70] [Batch 25/98] [D loss: 0.2439] [G loss: 1.7373]
# [Epoch 53/70] [Batch 26/98] [D loss: 0.2901] [G loss: 1.2098]
# [Epoch 53/70] [Batch 27/98] [D loss: 0.2075] [G loss: 1.8063]
# [Epoch 53/70] [Batch 28/98] [D loss: 0.3375] [G loss: 1.6959]
# [Epoch 53/70] [Batch 29/98] [D loss: 0.2417] [G loss: 1.6517]
# [Epoch 53/70] [Batch 30/98] [D loss: 0.1803] [G loss: 1.9074]
# [Epoch 53/70] [Batch 31/98] [D loss: 0.3135] [G loss: 1.5647]
# [Epoch 53/70] [Batch 32/98] [D loss: 0.2437] [G loss: 1.5613]
# [Epoch 53/70] [Batch 33/98] [D loss: 0.2727] [G loss: 1.6774]
# [Epoch 53/70] [Batch 34/98] [D loss: 0.2510] [G loss: 1.5372]
# [Epoch 53/70] [Batch 35/98] [D loss: 0.3345] [G loss: 1.5395]
# [Epoch 53/70] [Batch 36/98] [D loss: 0.1948] [G loss: 1.7341]
# [Epoch 53/70] [Batch 37/98] [D loss: 0.3078] [G loss: 1.4338]
# [Epoch 53/70] [Batch 38/98] [D loss: nan] [G loss: nan]
# [Epoch 53/70] [Batch 39/98] [D loss: 0.2118] [G loss: 1.5977]
# [Epoch 53/70] [Batch 40/98] [D loss: 0.2386] [G loss: 1.5868]
# [Epoch 53/70] [Batch 41/98] [D loss: nan] [G loss: nan]
# [Epoch 53/70] [Batch 42/98] [D loss: 0.1894] [G loss: 1.8211]
# [Epoch 53/70] [Batch 43/98] [D loss: 0.2792] [G loss: 1.5447]
# [Epoch 53/70] [Batch 44/98] [D loss: 0.2786] [G loss: 1.6414]
# [Epoch 53/70] [Batch 45/98] [D loss: 0.2581] [G loss: 1.8031]
# [Epoch 53/70] [Batch 46/98] [D loss: 0.3162] [G loss: 1.5569]
# [Epoch 53/70] [Batch 47/98] [D loss: 0.2481] [G loss: 1.5657]
# [Epoch 53/70] [Batch 48/98] [D loss: nan] [G loss: nan]
# [Epoch 53/70] [Batch 49/98] [D loss: 0.2287] [G loss: 1.5858]
# [Epoch 53/70] [Batch 50/98] [D loss: 0.2332] [G loss: 1.6264]
# [Epoch 53/70] [Batch 51/98] [D loss: 0.2644] [G loss: 1.6156]
# [Epoch 53/70] [Batch 52/98] [D loss: 0.2275] [G loss: 1.7046]
# [Epoch 53/70] [Batch 53/98] [D loss: 0.2718] [G loss: 1.2756]
# [Epoch 53/70] [Batch 54/98] [D loss: 0.2466] [G loss: 1.6796]
# [Epoch 53/70] [Batch 55/98] [D loss: 0.2656] [G loss: 1.4045]
# [Epoch 53/70] [Batch 56/98] [D loss: 0.2535] [G loss: 1.7920]
# [Epoch 53/70] [Batch 57/98] [D loss: 0.2505] [G loss: 1.6861]
# [Epoch 53/70] [Batch 58/98] [D loss: nan] [G loss: nan]
# [Epoch 53/70] [Batch 59/98] [D loss: 0.2465] [G loss: 1.5234]
# [Epoch 53/70] [Batch 60/98] [D loss: 0.2282] [G loss: 1.5859]
# [Epoch 53/70] [Batch 61/98] [D loss: 0.2498] [G loss: 1.5141]
# [Epoch 53/70] [Batch 62/98] [D loss: 0.2761] [G loss: 1.6414]
# [Epoch 53/70] [Batch 63/98] [D loss: 0.3174] [G loss: 1.2802]
# [Epoch 53/70] [Batch 64/98] [D loss: 0.2447] [G loss: 1.9887]
# [Epoch 53/70] [Batch 65/98] [D loss: 0.2479] [G loss: 1.6295]
# [Epoch 53/70] [Batch 66/98] [D loss: 0.2270] [G loss: 1.6911]
# [Epoch 53/70] [Batch 67/98] [D loss: nan] [G loss: nan]
# [Epoch 53/70] [Batch 68/98] [D loss: 0.2995] [G loss: 1.6752]
# [Epoch 53/70] [Batch 69/98] [D loss: 0.2451] [G loss: 1.4371]
# [Epoch 53/70] [Batch 70/98] [D loss: 0.2151] [G loss: 1.7698]
# [Epoch 53/70] [Batch 71/98] [D loss: 0.2661] [G loss: 1.7471]
# [Epoch 53/70] [Batch 72/98] [D loss: 0.2733] [G loss: 1.6505]
# [Epoch 53/70] [Batch 73/98] [D loss: 0.2521] [G loss: 1.6442]
# [Epoch 53/70] [Batch 74/98] [D loss: 0.2494] [G loss: 1.4454]
# [Epoch 53/70] [Batch 75/98] [D loss: 0.2593] [G loss: 1.4588]
# [Epoch 53/70] [Batch 76/98] [D loss: 0.2282] [G loss: 1.7558]
# [Epoch 53/70] [Batch 77/98] [D loss: 0.2622] [G loss: 1.7760]
# [Epoch 53/70] [Batch 78/98] [D loss: 0.3637] [G loss: 1.6496]
# [Epoch 53/70] [Batch 79/98] [D loss: nan] [G loss: nan]
# [Epoch 53/70] [Batch 80/98] [D loss: 0.2355] [G loss: 1.7014]
# [Epoch 53/70] [Batch 81/98] [D loss: 0.3226] [G loss: 1.4775]
# [Epoch 53/70] [Batch 82/98] [D loss: 0.3201] [G loss: 1.7225]
# [Epoch 53/70] [Batch 83/98] [D loss: 0.3033] [G loss: 1.3265]
# [Epoch 53/70] [Batch 84/98] [D loss: 0.2503] [G loss: 1.6234]
# [Epoch 53/70] [Batch 85/98] [D loss: 0.2476] [G loss: 1.7736]
# [Epoch 53/70] [Batch 86/98] [D loss: 0.2539] [G loss: 1.8057]
# [Epoch 53/70] [Batch 87/98] [D loss: 0.2181] [G loss: 1.7633]
# [Epoch 53/70] [Batch 88/98] [D loss: 0.2483] [G loss: 1.9897]
# [Epoch 53/70] [Batch 89/98] [D loss: 0.3007] [G loss: 1.5143]
# [Epoch 53/70] [Batch 90/98] [D loss: 0.3636] [G loss: 1.9039]
# [Epoch 53/70] [Batch 91/98] [D loss: 0.2881] [G loss: 1.8331]
# [Epoch 53/70] [Batch 92/98] [D loss: 0.2567] [G loss: 1.7588]
# [Epoch 53/70] [Batch 93/98] [D loss: 0.3302] [G loss: 1.6364]
# [Epoch 53/70] [Batch 94/98] [D loss: 0.3421] [G loss: 1.1515]
# [Epoch 53/70] [Batch 95/98] [D loss: 0.2218] [G loss: 1.7954]
# [Epoch 53/70] [Batch 96/98] [D loss: 0.2229] [G loss: 1.5335]
# [Epoch 53/70] [Batch 97/98] [D loss: 0.2369] [G loss: 1.6348]
# [Epoch 53/70] [Batch 98/98] [D loss: 0.2309] [G loss: 1.6575]
# [Epoch 54/70] [Batch 1/98] [D loss: 0.2404] [G loss: 1.6960]
# [Epoch 54/70] [Batch 2/98] [D loss: 0.1959] [G loss: 1.7756]
# [Epoch 54/70] [Batch 3/98] [D loss: 0.2780] [G loss: 1.5567]
# [Epoch 54/70] [Batch 4/98] [D loss: 0.1908] [G loss: 1.8603]
# [Epoch 54/70] [Batch 5/98] [D loss: 0.2965] [G loss: 1.5947]
# [Epoch 54/70] [Batch 6/98] [D loss: 0.2060] [G loss: 1.7839]
# [Epoch 54/70] [Batch 7/98] [D loss: 0.2344] [G loss: 1.7120]
# [Epoch 54/70] [Batch 8/98] [D loss: 0.2333] [G loss: 1.7105]
# [Epoch 54/70] [Batch 9/98] [D loss: 0.2914] [G loss: 1.4074]
# [Epoch 54/70] [Batch 10/98] [D loss: 0.2321] [G loss: 1.6840]
# [Epoch 54/70] [Batch 11/98] [D loss: 0.2391] [G loss: 1.6852]
# [Epoch 54/70] [Batch 12/98] [D loss: 0.2420] [G loss: 1.6866]
# [Epoch 54/70] [Batch 13/98] [D loss: 0.2046] [G loss: 1.6649]
# [Epoch 54/70] [Batch 14/98] [D loss: 0.1906] [G loss: 1.7866]
# [Epoch 54/70] [Batch 15/98] [D loss: 0.2859] [G loss: 1.9346]
# [Epoch 54/70] [Batch 16/98] [D loss: 0.2406] [G loss: 1.7742]
# [Epoch 54/70] [Batch 17/98] [D loss: 0.2442] [G loss: 1.4673]
# [Epoch 54/70] [Batch 18/98] [D loss: 0.2789] [G loss: 1.4861]
# [Epoch 54/70] [Batch 19/98] [D loss: 0.2236] [G loss: 1.5796]
# [Epoch 54/70] [Batch 20/98] [D loss: 0.2418] [G loss: 1.8084]
# [Epoch 54/70] [Batch 21/98] [D loss: 0.2642] [G loss: 1.6617]
# [Epoch 54/70] [Batch 22/98] [D loss: 0.3446] [G loss: 1.0554]
# [Epoch 54/70] [Batch 23/98] [D loss: 0.2234] [G loss: 1.5977]
# [Epoch 54/70] [Batch 24/98] [D loss: 0.3304] [G loss: 1.9476]
# [Epoch 54/70] [Batch 25/98] [D loss: 0.2564] [G loss: 1.7816]
# [Epoch 54/70] [Batch 26/98] [D loss: nan] [G loss: nan]
# [Epoch 54/70] [Batch 27/98] [D loss: 0.2345] [G loss: 1.9278]
# [Epoch 54/70] [Batch 28/98] [D loss: 0.3183] [G loss: 1.7254]
# [Epoch 54/70] [Batch 29/98] [D loss: 0.2705] [G loss: 1.5281]
# [Epoch 54/70] [Batch 30/98] [D loss: 0.2837] [G loss: 1.2107]
# [Epoch 54/70] [Batch 31/98] [D loss: 0.2283] [G loss: 1.8758]
# [Epoch 54/70] [Batch 32/98] [D loss: 0.2283] [G loss: 1.6539]
# [Epoch 54/70] [Batch 33/98] [D loss: 0.2076] [G loss: 1.8156]
# [Epoch 54/70] [Batch 34/98] [D loss: 0.3043] [G loss: 1.4520]
# [Epoch 54/70] [Batch 35/98] [D loss: 0.3084] [G loss: 1.4437]
# [Epoch 54/70] [Batch 36/98] [D loss: 0.2370] [G loss: 1.5604]
# [Epoch 54/70] [Batch 37/98] [D loss: 0.4531] [G loss: 1.9760]
# [Epoch 54/70] [Batch 38/98] [D loss: 0.3351] [G loss: 1.5062]
# [Epoch 54/70] [Batch 39/98] [D loss: 0.2827] [G loss: 1.3280]
# [Epoch 54/70] [Batch 40/98] [D loss: 0.2085] [G loss: 1.7445]
# [Epoch 54/70] [Batch 41/98] [D loss: 0.2617] [G loss: 1.6965]
# [Epoch 54/70] [Batch 42/98] [D loss: nan] [G loss: nan]
# [Epoch 54/70] [Batch 43/98] [D loss: 0.3397] [G loss: 1.9803]
# [Epoch 54/70] [Batch 44/98] [D loss: 0.2157] [G loss: 1.6034]
# [Epoch 54/70] [Batch 45/98] [D loss: 0.2914] [G loss: 1.8786]
# [Epoch 54/70] [Batch 46/98] [D loss: 0.2518] [G loss: 1.7934]
# [Epoch 54/70] [Batch 47/98] [D loss: 0.2616] [G loss: 1.6494]
# [Epoch 54/70] [Batch 48/98] [D loss: 0.2763] [G loss: 1.5209]
# [Epoch 54/70] [Batch 49/98] [D loss: 0.2718] [G loss: 1.5157]
# [Epoch 54/70] [Batch 50/98] [D loss: 0.2792] [G loss: 1.6964]
# [Epoch 54/70] [Batch 51/98] [D loss: 0.2554] [G loss: 1.6725]
# [Epoch 54/70] [Batch 52/98] [D loss: nan] [G loss: nan]
# [Epoch 54/70] [Batch 53/98] [D loss: 0.2555] [G loss: 1.6130]
# [Epoch 54/70] [Batch 54/98] [D loss: 0.2390] [G loss: 1.6105]
# [Epoch 54/70] [Batch 55/98] [D loss: 0.2410] [G loss: 1.6146]
# [Epoch 54/70] [Batch 56/98] [D loss: 0.3149] [G loss: 1.0919]
# [Epoch 54/70] [Batch 57/98] [D loss: 0.2270] [G loss: 1.6780]
# [Epoch 54/70] [Batch 58/98] [D loss: 0.2581] [G loss: 1.4385]
# [Epoch 54/70] [Batch 59/98] [D loss: 0.3386] [G loss: 1.5257]
# [Epoch 54/70] [Batch 60/98] [D loss: 0.2543] [G loss: 1.6716]
# [Epoch 54/70] [Batch 61/98] [D loss: 0.2830] [G loss: 1.4789]
# [Epoch 54/70] [Batch 62/98] [D loss: 0.2709] [G loss: 1.6220]
# [Epoch 54/70] [Batch 63/98] [D loss: 0.2380] [G loss: 1.8092]
# [Epoch 54/70] [Batch 64/98] [D loss: 0.2314] [G loss: 1.6442]
# [Epoch 54/70] [Batch 65/98] [D loss: 0.2294] [G loss: 1.7531]
# [Epoch 54/70] [Batch 66/98] [D loss: 0.4475] [G loss: 0.8109]
# [Epoch 54/70] [Batch 67/98] [D loss: 0.2449] [G loss: 1.6817]
# [Epoch 54/70] [Batch 68/98] [D loss: nan] [G loss: nan]
# [Epoch 54/70] [Batch 69/98] [D loss: 0.2885] [G loss: 1.7440]
# [Epoch 54/70] [Batch 70/98] [D loss: 0.2261] [G loss: 1.6175]
# [Epoch 54/70] [Batch 71/98] [D loss: 0.2458] [G loss: 1.5416]
# [Epoch 54/70] [Batch 72/98] [D loss: 0.2572] [G loss: 1.6340]
# [Epoch 54/70] [Batch 73/98] [D loss: 0.2479] [G loss: 1.6587]
# [Epoch 54/70] [Batch 74/98] [D loss: 0.2448] [G loss: 1.6772]
# [Epoch 54/70] [Batch 75/98] [D loss: 0.2405] [G loss: 1.6644]
# [Epoch 54/70] [Batch 76/98] [D loss: nan] [G loss: nan]
# [Epoch 54/70] [Batch 77/98] [D loss: 0.2457] [G loss: 1.6577]
# [Epoch 54/70] [Batch 78/98] [D loss: 0.2486] [G loss: 1.5995]
# [Epoch 54/70] [Batch 79/98] [D loss: 0.2000] [G loss: 1.7215]
# [Epoch 54/70] [Batch 80/98] [D loss: nan] [G loss: nan]
# [Epoch 54/70] [Batch 81/98] [D loss: 0.3851] [G loss: 1.6771]
# [Epoch 54/70] [Batch 82/98] [D loss: 0.2441] [G loss: 1.6093]
# [Epoch 54/70] [Batch 83/98] [D loss: 0.2484] [G loss: 1.6906]
# [Epoch 54/70] [Batch 84/98] [D loss: 0.2558] [G loss: 1.5007]
# [Epoch 54/70] [Batch 85/98] [D loss: 0.3357] [G loss: 1.8332]
# [Epoch 54/70] [Batch 86/98] [D loss: 0.3562] [G loss: 1.6931]
# [Epoch 54/70] [Batch 87/98] [D loss: 0.2595] [G loss: 1.6918]
# [Epoch 54/70] [Batch 88/98] [D loss: 0.2417] [G loss: 1.6560]
# [Epoch 54/70] [Batch 89/98] [D loss: 0.2740] [G loss: 1.6364]
# [Epoch 54/70] [Batch 90/98] [D loss: 0.2367] [G loss: 1.7015]
# [Epoch 54/70] [Batch 91/98] [D loss: 0.2158] [G loss: 1.6375]
# [Epoch 54/70] [Batch 92/98] [D loss: 0.2317] [G loss: 1.6522]
# [Epoch 54/70] [Batch 93/98] [D loss: 0.2405] [G loss: 1.7232]
# [Epoch 54/70] [Batch 94/98] [D loss: 0.2414] [G loss: 1.5173]
# [Epoch 54/70] [Batch 95/98] [D loss: 0.3671] [G loss: 1.0719]
# [Epoch 54/70] [Batch 96/98] [D loss: nan] [G loss: nan]
# [Epoch 54/70] [Batch 97/98] [D loss: 0.2529] [G loss: 1.7037]
# [Epoch 54/70] [Batch 98/98] [D loss: nan] [G loss: nan]
# [Epoch 55/70] [Batch 1/98] [D loss: 0.3017] [G loss: 1.5368]
# [Epoch 55/70] [Batch 2/98] [D loss: 0.2895] [G loss: 1.6972]
# [Epoch 55/70] [Batch 3/98] [D loss: 0.1876] [G loss: 1.7743]
# [Epoch 55/70] [Batch 4/98] [D loss: nan] [G loss: nan]
# [Epoch 55/70] [Batch 5/98] [D loss: 0.2234] [G loss: 1.5309]
# [Epoch 55/70] [Batch 6/98] [D loss: 0.2541] [G loss: 1.4193]
# [Epoch 55/70] [Batch 7/98] [D loss: nan] [G loss: nan]
# [Epoch 55/70] [Batch 8/98] [D loss: 0.2244] [G loss: 1.8146]
# [Epoch 55/70] [Batch 9/98] [D loss: 0.2623] [G loss: 1.6628]
# [Epoch 55/70] [Batch 10/98] [D loss: 0.2282] [G loss: 1.7130]
# [Epoch 55/70] [Batch 11/98] [D loss: nan] [G loss: nan]
# [Epoch 55/70] [Batch 12/98] [D loss: 0.2502] [G loss: 1.6733]
# [Epoch 55/70] [Batch 13/98] [D loss: 0.2332] [G loss: 1.6009]
# [Epoch 55/70] [Batch 14/98] [D loss: 0.3647] [G loss: 1.7419]
# [Epoch 55/70] [Batch 15/98] [D loss: 0.3198] [G loss: 1.2744]
# [Epoch 55/70] [Batch 16/98] [D loss: 0.3314] [G loss: 1.5638]
# [Epoch 55/70] [Batch 17/98] [D loss: 0.2745] [G loss: 1.4924]
# [Epoch 55/70] [Batch 18/98] [D loss: 0.2219] [G loss: 1.5606]
# [Epoch 55/70] [Batch 19/98] [D loss: 0.2434] [G loss: 1.6321]
# [Epoch 55/70] [Batch 20/98] [D loss: 0.1940] [G loss: 1.8880]
# [Epoch 55/70] [Batch 21/98] [D loss: 0.2541] [G loss: 1.7520]
# [Epoch 55/70] [Batch 22/98] [D loss: 0.2727] [G loss: 1.6845]
# [Epoch 55/70] [Batch 23/98] [D loss: 0.2050] [G loss: 1.7376]
# [Epoch 55/70] [Batch 24/98] [D loss: 0.2316] [G loss: 1.6881]
# [Epoch 55/70] [Batch 25/98] [D loss: 0.2971] [G loss: 1.6158]
# [Epoch 55/70] [Batch 26/98] [D loss: nan] [G loss: nan]
# [Epoch 55/70] [Batch 27/98] [D loss: 0.2557] [G loss: 1.6366]
# [Epoch 55/70] [Batch 28/98] [D loss: 0.3263] [G loss: 1.4644]
# [Epoch 55/70] [Batch 29/98] [D loss: 0.2156] [G loss: 1.6755]
# [Epoch 55/70] [Batch 30/98] [D loss: 0.2498] [G loss: 1.5307]
# [Epoch 55/70] [Batch 31/98] [D loss: 0.2777] [G loss: 1.7147]
# [Epoch 55/70] [Batch 32/98] [D loss: 0.2632] [G loss: 1.8417]
# [Epoch 55/70] [Batch 33/98] [D loss: nan] [G loss: nan]
# [Epoch 55/70] [Batch 34/98] [D loss: 0.2434] [G loss: 1.4846]
# [Epoch 55/70] [Batch 35/98] [D loss: 0.2589] [G loss: 1.4259]
# [Epoch 55/70] [Batch 36/98] [D loss: 0.2760] [G loss: 1.6547]
# [Epoch 55/70] [Batch 37/98] [D loss: 0.2581] [G loss: 1.5362]
# [Epoch 55/70] [Batch 38/98] [D loss: 0.2527] [G loss: 1.6332]
# [Epoch 55/70] [Batch 39/98] [D loss: 0.2142] [G loss: 1.7408]
# [Epoch 55/70] [Batch 40/98] [D loss: 0.2382] [G loss: 1.7936]
# [Epoch 55/70] [Batch 41/98] [D loss: 0.3735] [G loss: 1.6059]
# [Epoch 55/70] [Batch 42/98] [D loss: 0.2256] [G loss: 1.7526]
# [Epoch 55/70] [Batch 43/98] [D loss: 0.2469] [G loss: 1.6695]
# [Epoch 55/70] [Batch 44/98] [D loss: nan] [G loss: nan]
# [Epoch 55/70] [Batch 45/98] [D loss: 0.2437] [G loss: 1.5944]
# [Epoch 55/70] [Batch 46/98] [D loss: 0.2472] [G loss: 1.7378]
# [Epoch 55/70] [Batch 47/98] [D loss: 0.1995] [G loss: 1.9327]
# [Epoch 55/70] [Batch 48/98] [D loss: 0.3345] [G loss: 1.5549]
# [Epoch 55/70] [Batch 49/98] [D loss: 0.3379] [G loss: 1.9680]
# [Epoch 55/70] [Batch 50/98] [D loss: 0.2632] [G loss: 1.5957]
# [Epoch 55/70] [Batch 51/98] [D loss: 0.2290] [G loss: 1.5635]
# [Epoch 55/70] [Batch 52/98] [D loss: 0.2360] [G loss: 1.5963]
# [Epoch 55/70] [Batch 53/98] [D loss: 0.2966] [G loss: 1.7281]
# [Epoch 55/70] [Batch 54/98] [D loss: 0.2875] [G loss: 1.4749]
# [Epoch 55/70] [Batch 55/98] [D loss: 0.2362] [G loss: 1.6312]
# [Epoch 55/70] [Batch 56/98] [D loss: 0.2893] [G loss: 1.6912]
# [Epoch 55/70] [Batch 57/98] [D loss: 0.2269] [G loss: 1.6839]
# [Epoch 55/70] [Batch 58/98] [D loss: 0.2324] [G loss: 1.8872]
# [Epoch 55/70] [Batch 59/98] [D loss: 0.2122] [G loss: 1.7423]
# [Epoch 55/70] [Batch 60/98] [D loss: 0.2900] [G loss: 1.5181]
# [Epoch 55/70] [Batch 61/98] [D loss: 0.3976] [G loss: 1.9439]
# [Epoch 55/70] [Batch 62/98] [D loss: 0.2226] [G loss: 1.6286]
# [Epoch 55/70] [Batch 63/98] [D loss: 0.2435] [G loss: 1.7045]
# [Epoch 55/70] [Batch 64/98] [D loss: 0.1958] [G loss: 1.7896]
# [Epoch 55/70] [Batch 65/98] [D loss: 0.2676] [G loss: 1.4848]
# [Epoch 55/70] [Batch 66/98] [D loss: 0.2572] [G loss: 1.6081]
# [Epoch 55/70] [Batch 67/98] [D loss: 0.3562] [G loss: 1.2843]
# [Epoch 55/70] [Batch 68/98] [D loss: nan] [G loss: nan]
# [Epoch 55/70] [Batch 69/98] [D loss: 0.2537] [G loss: 1.5843]
# [Epoch 55/70] [Batch 70/98] [D loss: 0.3026] [G loss: 1.4620]
# [Epoch 55/70] [Batch 71/98] [D loss: nan] [G loss: nan]
# [Epoch 55/70] [Batch 72/98] [D loss: 0.2436] [G loss: 1.7037]
# [Epoch 55/70] [Batch 73/98] [D loss: 0.2640] [G loss: 1.5549]
# [Epoch 55/70] [Batch 74/98] [D loss: 0.2704] [G loss: 1.3844]
# [Epoch 55/70] [Batch 75/98] [D loss: 0.2854] [G loss: 1.4641]
# [Epoch 55/70] [Batch 76/98] [D loss: 0.3369] [G loss: 1.3347]
# [Epoch 55/70] [Batch 77/98] [D loss: 0.2244] [G loss: 1.7645]
# [Epoch 55/70] [Batch 78/98] [D loss: 0.2434] [G loss: 1.7479]
# [Epoch 55/70] [Batch 79/98] [D loss: 0.2906] [G loss: 1.5651]
# [Epoch 55/70] [Batch 80/98] [D loss: 0.2242] [G loss: 1.5307]
# [Epoch 55/70] [Batch 81/98] [D loss: 0.1995] [G loss: 1.7644]
# [Epoch 55/70] [Batch 82/98] [D loss: 0.2871] [G loss: 1.8469]
# [Epoch 55/70] [Batch 83/98] [D loss: 0.2671] [G loss: 1.6854]
# [Epoch 55/70] [Batch 84/98] [D loss: 0.2382] [G loss: 1.6785]
# [Epoch 55/70] [Batch 85/98] [D loss: 0.3126] [G loss: 1.5625]
# [Epoch 55/70] [Batch 86/98] [D loss: 0.3036] [G loss: 1.3535]
# [Epoch 55/70] [Batch 87/98] [D loss: 0.2980] [G loss: 1.6478]
# [Epoch 55/70] [Batch 88/98] [D loss: 0.5733] [G loss: 0.6557]
# [Epoch 55/70] [Batch 89/98] [D loss: 0.2446] [G loss: 1.6968]
# [Epoch 55/70] [Batch 90/98] [D loss: 0.2111] [G loss: 1.7944]
# [Epoch 55/70] [Batch 91/98] [D loss: 0.2392] [G loss: 1.5208]
# [Epoch 55/70] [Batch 92/98] [D loss: 0.2336] [G loss: 1.6755]
# [Epoch 55/70] [Batch 93/98] [D loss: 0.2606] [G loss: 1.5102]
# [Epoch 55/70] [Batch 94/98] [D loss: 0.2123] [G loss: 1.7779]
# [Epoch 55/70] [Batch 95/98] [D loss: nan] [G loss: nan]
# [Epoch 55/70] [Batch 96/98] [D loss: 0.2360] [G loss: 1.7772]
# [Epoch 55/70] [Batch 97/98] [D loss: 0.3857] [G loss: 1.5814]
# [Epoch 55/70] [Batch 98/98] [D loss: 0.2651] [G loss: 1.3713]
# [Epoch 56/70] [Batch 1/98] [D loss: nan] [G loss: nan]
# [Epoch 56/70] [Batch 2/98] [D loss: 0.2712] [G loss: 1.6687]
# [Epoch 56/70] [Batch 3/98] [D loss: 0.2774] [G loss: 1.6709]
# [Epoch 56/70] [Batch 4/98] [D loss: 0.2956] [G loss: 1.6564]
# [Epoch 56/70] [Batch 5/98] [D loss: 0.2297] [G loss: 1.9189]
# [Epoch 56/70] [Batch 6/98] [D loss: 0.3014] [G loss: 1.4680]
# [Epoch 56/70] [Batch 7/98] [D loss: 0.2286] [G loss: 1.7108]
# [Epoch 56/70] [Batch 8/98] [D loss: nan] [G loss: nan]
# [Epoch 56/70] [Batch 9/98] [D loss: 0.2370] [G loss: 1.6447]
# [Epoch 56/70] [Batch 10/98] [D loss: 0.2151] [G loss: 1.8053]
# [Epoch 56/70] [Batch 11/98] [D loss: 0.2416] [G loss: 1.7039]
# [Epoch 56/70] [Batch 12/98] [D loss: 0.2306] [G loss: 1.7081]
# [Epoch 56/70] [Batch 13/98] [D loss: 0.2651] [G loss: 1.6625]
# [Epoch 56/70] [Batch 14/98] [D loss: 0.2526] [G loss: 1.4795]
# [Epoch 56/70] [Batch 15/98] [D loss: 0.2326] [G loss: 1.6204]
# [Epoch 56/70] [Batch 16/98] [D loss: 0.1965] [G loss: 1.9420]
# [Epoch 56/70] [Batch 17/98] [D loss: 0.2547] [G loss: 1.4689]
# [Epoch 56/70] [Batch 18/98] [D loss: 0.2151] [G loss: 1.7156]
# [Epoch 56/70] [Batch 19/98] [D loss: 0.3304] [G loss: 1.6497]
# [Epoch 56/70] [Batch 20/98] [D loss: 0.2322] [G loss: 1.7416]
# [Epoch 56/70] [Batch 21/98] [D loss: 0.2355] [G loss: 1.5990]
# [Epoch 56/70] [Batch 22/98] [D loss: 0.2712] [G loss: 1.4078]
# [Epoch 56/70] [Batch 23/98] [D loss: 0.2654] [G loss: 1.8233]
# [Epoch 56/70] [Batch 24/98] [D loss: 0.2319] [G loss: 1.7511]
# [Epoch 56/70] [Batch 25/98] [D loss: 0.2303] [G loss: 1.5124]
# [Epoch 56/70] [Batch 26/98] [D loss: 0.3270] [G loss: 1.6062]
# [Epoch 56/70] [Batch 27/98] [D loss: 0.3610] [G loss: 1.8874]
# [Epoch 56/70] [Batch 28/98] [D loss: 0.2158] [G loss: 1.6521]
# [Epoch 56/70] [Batch 29/98] [D loss: 0.2719] [G loss: 1.4367]
# [Epoch 56/70] [Batch 30/98] [D loss: nan] [G loss: nan]
# [Epoch 56/70] [Batch 31/98] [D loss: 0.1872] [G loss: 1.8257]
# [Epoch 56/70] [Batch 32/98] [D loss: 0.2767] [G loss: 1.5469]
# [Epoch 56/70] [Batch 33/98] [D loss: 0.2341] [G loss: 1.7027]
# [Epoch 56/70] [Batch 34/98] [D loss: 0.2578] [G loss: 1.6806]
# [Epoch 56/70] [Batch 35/98] [D loss: 0.2220] [G loss: 1.7415]
# [Epoch 56/70] [Batch 36/98] [D loss: 0.2189] [G loss: 1.7461]
# [Epoch 56/70] [Batch 37/98] [D loss: 0.2706] [G loss: 1.7448]
# [Epoch 56/70] [Batch 38/98] [D loss: 0.2158] [G loss: 1.5375]
# [Epoch 56/70] [Batch 39/98] [D loss: 0.2776] [G loss: 1.5892]
# [Epoch 56/70] [Batch 40/98] [D loss: 0.2917] [G loss: 1.5958]
# [Epoch 56/70] [Batch 41/98] [D loss: nan] [G loss: nan]
# [Epoch 56/70] [Batch 42/98] [D loss: 0.2970] [G loss: 1.2493]
# [Epoch 56/70] [Batch 43/98] [D loss: 0.3205] [G loss: 1.5583]
# [Epoch 56/70] [Batch 44/98] [D loss: 0.2625] [G loss: 1.6392]
# [Epoch 56/70] [Batch 45/98] [D loss: 0.2537] [G loss: 1.6691]
# [Epoch 56/70] [Batch 46/98] [D loss: 0.2505] [G loss: 1.6065]
# [Epoch 56/70] [Batch 47/98] [D loss: nan] [G loss: nan]
# [Epoch 56/70] [Batch 48/98] [D loss: 0.2097] [G loss: 1.6389]
# [Epoch 56/70] [Batch 49/98] [D loss: 0.2010] [G loss: 1.7720]
# [Epoch 56/70] [Batch 50/98] [D loss: 0.2351] [G loss: 1.7678]
# [Epoch 56/70] [Batch 51/98] [D loss: 0.2498] [G loss: 1.6109]
# [Epoch 56/70] [Batch 52/98] [D loss: 0.2322] [G loss: 1.5713]
# [Epoch 56/70] [Batch 53/98] [D loss: 0.2847] [G loss: 1.6056]
# [Epoch 56/70] [Batch 54/98] [D loss: 0.2199] [G loss: 1.7627]
# [Epoch 56/70] [Batch 55/98] [D loss: 0.3461] [G loss: 1.5223]
# [Epoch 56/70] [Batch 56/98] [D loss: 0.2969] [G loss: 1.5113]
# [Epoch 56/70] [Batch 57/98] [D loss: 0.2531] [G loss: 1.6586]
# [Epoch 56/70] [Batch 58/98] [D loss: 0.2298] [G loss: 1.7478]
# [Epoch 56/70] [Batch 59/98] [D loss: 0.2414] [G loss: 1.5039]
# [Epoch 56/70] [Batch 60/98] [D loss: 0.4104] [G loss: 1.4688]
# [Epoch 56/70] [Batch 61/98] [D loss: 0.2381] [G loss: 1.5618]
# [Epoch 56/70] [Batch 62/98] [D loss: 0.2969] [G loss: 1.4836]
# [Epoch 56/70] [Batch 63/98] [D loss: nan] [G loss: nan]
# [Epoch 56/70] [Batch 64/98] [D loss: 0.2901] [G loss: 1.4355]
# [Epoch 56/70] [Batch 65/98] [D loss: 0.2624] [G loss: 1.6884]
# [Epoch 56/70] [Batch 66/98] [D loss: nan] [G loss: nan]
# [Epoch 56/70] [Batch 67/98] [D loss: 0.3245] [G loss: 1.6965]
# [Epoch 56/70] [Batch 68/98] [D loss: 0.2011] [G loss: 1.7279]
# [Epoch 56/70] [Batch 69/98] [D loss: 0.2909] [G loss: 1.3773]
# [Epoch 56/70] [Batch 70/98] [D loss: 0.2718] [G loss: 1.2948]
# [Epoch 56/70] [Batch 71/98] [D loss: nan] [G loss: nan]
# [Epoch 56/70] [Batch 72/98] [D loss: 0.2598] [G loss: 1.5937]
# [Epoch 56/70] [Batch 73/98] [D loss: 0.2190] [G loss: 1.5087]
# [Epoch 56/70] [Batch 74/98] [D loss: 0.2480] [G loss: 1.5592]
# [Epoch 56/70] [Batch 75/98] [D loss: 0.2512] [G loss: 1.6571]
# [Epoch 56/70] [Batch 76/98] [D loss: 0.3151] [G loss: 1.8790]
# [Epoch 56/70] [Batch 77/98] [D loss: 0.2836] [G loss: 1.3611]
# [Epoch 56/70] [Batch 78/98] [D loss: 0.3030] [G loss: 1.6926]
# [Epoch 56/70] [Batch 79/98] [D loss: 0.2319] [G loss: 1.7337]
# [Epoch 56/70] [Batch 80/98] [D loss: 0.2255] [G loss: 1.5830]
# [Epoch 56/70] [Batch 81/98] [D loss: 0.2404] [G loss: 1.8363]
# [Epoch 56/70] [Batch 82/98] [D loss: 0.3184] [G loss: 1.5025]
# [Epoch 56/70] [Batch 83/98] [D loss: 0.2376] [G loss: 1.8108]
# [Epoch 56/70] [Batch 84/98] [D loss: 0.2670] [G loss: 1.5994]
# [Epoch 56/70] [Batch 85/98] [D loss: nan] [G loss: nan]
# [Epoch 56/70] [Batch 86/98] [D loss: 0.2668] [G loss: 1.5587]
# [Epoch 56/70] [Batch 87/98] [D loss: 0.2517] [G loss: 1.5800]
# [Epoch 56/70] [Batch 88/98] [D loss: 0.2433] [G loss: 1.4916]
# [Epoch 56/70] [Batch 89/98] [D loss: 0.2648] [G loss: 1.6724]
# [Epoch 56/70] [Batch 90/98] [D loss: 0.1977] [G loss: 1.8224]
# [Epoch 56/70] [Batch 91/98] [D loss: 0.2574] [G loss: 1.6053]
# [Epoch 56/70] [Batch 92/98] [D loss: 0.2196] [G loss: 1.8295]
# [Epoch 56/70] [Batch 93/98] [D loss: 0.2701] [G loss: 1.6828]
# [Epoch 56/70] [Batch 94/98] [D loss: 0.2882] [G loss: 1.4896]
# [Epoch 56/70] [Batch 95/98] [D loss: 0.1928] [G loss: 1.8227]
# [Epoch 56/70] [Batch 96/98] [D loss: 0.2360] [G loss: 1.6674]
# [Epoch 56/70] [Batch 97/98] [D loss: 0.2099] [G loss: 1.6127]
# [Epoch 56/70] [Batch 98/98] [D loss: 0.2118] [G loss: 1.7337]
# [Epoch 57/70] [Batch 1/98] [D loss: 0.2342] [G loss: 1.5898]
# [Epoch 57/70] [Batch 2/98] [D loss: nan] [G loss: nan]
# [Epoch 57/70] [Batch 3/98] [D loss: 0.2437] [G loss: 1.7204]
# [Epoch 57/70] [Batch 4/98] [D loss: 0.2424] [G loss: 1.5808]
# [Epoch 57/70] [Batch 5/98] [D loss: 0.2839] [G loss: 1.6237]
# [Epoch 57/70] [Batch 6/98] [D loss: nan] [G loss: nan]
# [Epoch 57/70] [Batch 7/98] [D loss: 0.3082] [G loss: 1.6480]
# [Epoch 57/70] [Batch 8/98] [D loss: 0.3367] [G loss: 1.5435]
# [Epoch 57/70] [Batch 9/98] [D loss: 0.2119] [G loss: 1.6441]
# [Epoch 57/70] [Batch 10/98] [D loss: 0.2423] [G loss: 1.6797]
# [Epoch 57/70] [Batch 11/98] [D loss: 0.4282] [G loss: 1.5489]
# [Epoch 57/70] [Batch 12/98] [D loss: 0.3178] [G loss: 1.6227]
# [Epoch 57/70] [Batch 13/98] [D loss: 0.2352] [G loss: 1.6920]
# [Epoch 57/70] [Batch 14/98] [D loss: 0.3047] [G loss: 1.2132]
# [Epoch 57/70] [Batch 15/98] [D loss: 0.2086] [G loss: 1.6326]
# [Epoch 57/70] [Batch 16/98] [D loss: 0.3133] [G loss: 1.6953]
# [Epoch 57/70] [Batch 17/98] [D loss: 0.2254] [G loss: 1.8425]
# [Epoch 57/70] [Batch 18/98] [D loss: 0.4211] [G loss: 1.1903]
# [Epoch 57/70] [Batch 19/98] [D loss: 0.2472] [G loss: 1.3772]
# [Epoch 57/70] [Batch 20/98] [D loss: 0.2584] [G loss: 1.6727]
# [Epoch 57/70] [Batch 21/98] [D loss: nan] [G loss: nan]
# [Epoch 57/70] [Batch 22/98] [D loss: 0.2284] [G loss: 1.7078]
# [Epoch 57/70] [Batch 23/98] [D loss: 0.2422] [G loss: 1.8539]
# [Epoch 57/70] [Batch 24/98] [D loss: 0.2203] [G loss: 1.9453]
# [Epoch 57/70] [Batch 25/98] [D loss: 0.2439] [G loss: 1.7181]
# [Epoch 57/70] [Batch 26/98] [D loss: 0.2354] [G loss: 1.6361]
# [Epoch 57/70] [Batch 27/98] [D loss: nan] [G loss: nan]
# [Epoch 57/70] [Batch 28/98] [D loss: 0.2355] [G loss: 1.4142]
# [Epoch 57/70] [Batch 29/98] [D loss: 0.2714] [G loss: 1.6594]
# [Epoch 57/70] [Batch 30/98] [D loss: 0.2699] [G loss: 1.6063]
# [Epoch 57/70] [Batch 31/98] [D loss: 0.2207] [G loss: 1.7137]
# [Epoch 57/70] [Batch 32/98] [D loss: 0.2349] [G loss: 1.6152]
# [Epoch 57/70] [Batch 33/98] [D loss: 0.2905] [G loss: 1.6110]
# [Epoch 57/70] [Batch 34/98] [D loss: 0.2559] [G loss: 1.5093]
# [Epoch 57/70] [Batch 35/98] [D loss: 0.2276] [G loss: 1.5190]
# [Epoch 57/70] [Batch 36/98] [D loss: 0.2448] [G loss: 1.7731]
# [Epoch 57/70] [Batch 37/98] [D loss: 0.3319] [G loss: 1.7243]
# [Epoch 57/70] [Batch 38/98] [D loss: 0.2291] [G loss: 1.6334]
# [Epoch 57/70] [Batch 39/98] [D loss: nan] [G loss: nan]
# [Epoch 57/70] [Batch 40/98] [D loss: nan] [G loss: nan]
# [Epoch 57/70] [Batch 41/98] [D loss: 0.2440] [G loss: 1.6722]
# [Epoch 57/70] [Batch 42/98] [D loss: 0.2634] [G loss: 1.7481]
# [Epoch 57/70] [Batch 43/98] [D loss: 0.2274] [G loss: 1.7758]
# [Epoch 57/70] [Batch 44/98] [D loss: 0.2537] [G loss: 1.5965]
# [Epoch 57/70] [Batch 45/98] [D loss: 0.2423] [G loss: 1.7267]
# [Epoch 57/70] [Batch 46/98] [D loss: 0.3300] [G loss: 1.6042]
# [Epoch 57/70] [Batch 47/98] [D loss: nan] [G loss: nan]
# [Epoch 57/70] [Batch 48/98] [D loss: 0.2578] [G loss: 1.6226]
# [Epoch 57/70] [Batch 49/98] [D loss: 0.2466] [G loss: 1.5216]
# [Epoch 57/70] [Batch 50/98] [D loss: 0.2420] [G loss: 1.5090]
# [Epoch 57/70] [Batch 51/98] [D loss: 0.2781] [G loss: 1.6000]
# [Epoch 57/70] [Batch 52/98] [D loss: 0.2644] [G loss: 1.4376]
# [Epoch 57/70] [Batch 53/98] [D loss: 0.1810] [G loss: 1.8986]
# [Epoch 57/70] [Batch 54/98] [D loss: 0.2737] [G loss: 1.7154]
# [Epoch 57/70] [Batch 55/98] [D loss: 0.2243] [G loss: 1.9032]
# [Epoch 57/70] [Batch 56/98] [D loss: 0.2224] [G loss: 1.8015]
# [Epoch 57/70] [Batch 57/98] [D loss: 0.2040] [G loss: 1.8047]
# [Epoch 57/70] [Batch 58/98] [D loss: 0.2120] [G loss: 1.6724]
# [Epoch 57/70] [Batch 59/98] [D loss: 0.2188] [G loss: 1.5744]
# [Epoch 57/70] [Batch 60/98] [D loss: 0.3991] [G loss: 1.0000]
# [Epoch 57/70] [Batch 61/98] [D loss: 0.2309] [G loss: 1.7176]
# [Epoch 57/70] [Batch 62/98] [D loss: 0.3554] [G loss: 1.7994]
# [Epoch 57/70] [Batch 63/98] [D loss: 0.2592] [G loss: 1.6613]
# [Epoch 57/70] [Batch 64/98] [D loss: 0.2486] [G loss: 1.6046]
# [Epoch 57/70] [Batch 65/98] [D loss: 0.2215] [G loss: 1.5607]
# [Epoch 57/70] [Batch 66/98] [D loss: 0.3201] [G loss: 1.1223]
# [Epoch 57/70] [Batch 67/98] [D loss: 0.1952] [G loss: 1.8325]
# [Epoch 57/70] [Batch 68/98] [D loss: nan] [G loss: nan]
# [Epoch 57/70] [Batch 69/98] [D loss: 0.2263] [G loss: 1.6820]
# [Epoch 57/70] [Batch 70/98] [D loss: 0.2914] [G loss: 1.5246]
# [Epoch 57/70] [Batch 71/98] [D loss: 0.3604] [G loss: 1.5635]
# [Epoch 57/70] [Batch 72/98] [D loss: 0.2626] [G loss: 1.4279]
# [Epoch 57/70] [Batch 73/98] [D loss: 0.2537] [G loss: 1.5759]
# [Epoch 57/70] [Batch 74/98] [D loss: 0.2548] [G loss: 1.5095]
# [Epoch 57/70] [Batch 75/98] [D loss: 0.4155] [G loss: 1.0942]
# [Epoch 57/70] [Batch 76/98] [D loss: nan] [G loss: nan]
# [Epoch 57/70] [Batch 77/98] [D loss: 0.3002] [G loss: 1.4671]
# [Epoch 57/70] [Batch 78/98] [D loss: 0.2769] [G loss: 1.6981]
# [Epoch 57/70] [Batch 79/98] [D loss: 0.3090] [G loss: 1.6898]
# [Epoch 57/70] [Batch 80/98] [D loss: 0.2435] [G loss: 1.6248]
# [Epoch 57/70] [Batch 81/98] [D loss: 0.2314] [G loss: 1.5291]
# [Epoch 57/70] [Batch 82/98] [D loss: 0.2111] [G loss: 1.6840]
# [Epoch 57/70] [Batch 83/98] [D loss: 0.2683] [G loss: 1.4508]
# [Epoch 57/70] [Batch 84/98] [D loss: 0.2857] [G loss: 1.3925]
# [Epoch 57/70] [Batch 85/98] [D loss: 0.3108] [G loss: 1.1067]
# [Epoch 57/70] [Batch 86/98] [D loss: 0.2057] [G loss: 1.6412]
# [Epoch 57/70] [Batch 87/98] [D loss: 0.2520] [G loss: 1.7053]
# [Epoch 57/70] [Batch 88/98] [D loss: 0.2701] [G loss: 1.5809]
# [Epoch 57/70] [Batch 89/98] [D loss: 0.2344] [G loss: 1.6264]
# [Epoch 57/70] [Batch 90/98] [D loss: 0.3129] [G loss: 1.9475]
# [Epoch 57/70] [Batch 91/98] [D loss: 0.2625] [G loss: 1.6578]
# [Epoch 57/70] [Batch 92/98] [D loss: 0.2571] [G loss: 1.7172]
# [Epoch 57/70] [Batch 93/98] [D loss: 0.2607] [G loss: 1.8913]
# [Epoch 57/70] [Batch 94/98] [D loss: 0.2442] [G loss: 1.6442]
# [Epoch 57/70] [Batch 95/98] [D loss: 0.2354] [G loss: 1.5827]
# [Epoch 57/70] [Batch 96/98] [D loss: 0.2380] [G loss: 1.6476]
# [Epoch 57/70] [Batch 97/98] [D loss: 0.2827] [G loss: 1.7274]
# [Epoch 57/70] [Batch 98/98] [D loss: 0.2677] [G loss: 1.8691]
# [Epoch 58/70] [Batch 1/98] [D loss: nan] [G loss: nan]
# [Epoch 58/70] [Batch 2/98] [D loss: nan] [G loss: nan]
# [Epoch 58/70] [Batch 3/98] [D loss: 0.2992] [G loss: 1.6712]
# [Epoch 58/70] [Batch 4/98] [D loss: 0.2428] [G loss: 1.5284]
# [Epoch 58/70] [Batch 5/98] [D loss: 0.2895] [G loss: 1.7150]
# [Epoch 58/70] [Batch 6/98] [D loss: 0.2580] [G loss: 1.6838]
# [Epoch 58/70] [Batch 7/98] [D loss: 0.2591] [G loss: 1.5800]
# [Epoch 58/70] [Batch 8/98] [D loss: 0.2401] [G loss: 1.9684]
# [Epoch 58/70] [Batch 9/98] [D loss: 0.3111] [G loss: 1.7795]
# [Epoch 58/70] [Batch 10/98] [D loss: 0.2752] [G loss: 1.3648]
# [Epoch 58/70] [Batch 11/98] [D loss: nan] [G loss: nan]
# [Epoch 58/70] [Batch 12/98] [D loss: 0.2570] [G loss: 1.7244]
# [Epoch 58/70] [Batch 13/98] [D loss: 0.3006] [G loss: 1.7408]
# [Epoch 58/70] [Batch 14/98] [D loss: 0.2230] [G loss: 1.7665]
# [Epoch 58/70] [Batch 15/98] [D loss: 0.2027] [G loss: 1.8600]
# [Epoch 58/70] [Batch 16/98] [D loss: 0.3124] [G loss: 1.4575]
# [Epoch 58/70] [Batch 17/98] [D loss: 0.2389] [G loss: 1.7089]
# [Epoch 58/70] [Batch 18/98] [D loss: 0.2453] [G loss: 1.7472]
# [Epoch 58/70] [Batch 19/98] [D loss: 0.2718] [G loss: 1.5166]
# [Epoch 58/70] [Batch 20/98] [D loss: 0.7263] [G loss: 0.4715]
# [Epoch 58/70] [Batch 21/98] [D loss: 0.3273] [G loss: 1.5908]
# [Epoch 58/70] [Batch 22/98] [D loss: 0.2299] [G loss: 1.5361]
# [Epoch 58/70] [Batch 23/98] [D loss: 0.2096] [G loss: 1.9379]
# [Epoch 58/70] [Batch 24/98] [D loss: 0.2339] [G loss: 1.6080]
# [Epoch 58/70] [Batch 25/98] [D loss: 0.2558] [G loss: 1.5779]
# [Epoch 58/70] [Batch 26/98] [D loss: nan] [G loss: nan]
# [Epoch 58/70] [Batch 27/98] [D loss: 0.2482] [G loss: 1.5544]
# [Epoch 58/70] [Batch 28/98] [D loss: 0.2323] [G loss: 1.6696]
# [Epoch 58/70] [Batch 29/98] [D loss: 0.2184] [G loss: 1.6582]
# [Epoch 58/70] [Batch 30/98] [D loss: 0.3250] [G loss: 1.3253]
# [Epoch 58/70] [Batch 31/98] [D loss: 0.2135] [G loss: 1.8684]
# [Epoch 58/70] [Batch 32/98] [D loss: 0.2222] [G loss: 2.0534]
# [Epoch 58/70] [Batch 33/98] [D loss: 0.2245] [G loss: 1.5511]
# [Epoch 58/70] [Batch 34/98] [D loss: 0.3549] [G loss: 1.4311]
# [Epoch 58/70] [Batch 35/98] [D loss: 0.2282] [G loss: 1.6517]
# [Epoch 58/70] [Batch 36/98] [D loss: 0.2409] [G loss: 1.7586]
# [Epoch 58/70] [Batch 37/98] [D loss: 0.2110] [G loss: 1.7229]
# [Epoch 58/70] [Batch 38/98] [D loss: 0.2227] [G loss: 1.5971]
# [Epoch 58/70] [Batch 39/98] [D loss: 0.2586] [G loss: 1.5773]
# [Epoch 58/70] [Batch 40/98] [D loss: 0.2288] [G loss: 1.6713]
# [Epoch 58/70] [Batch 41/98] [D loss: 0.2510] [G loss: 1.6667]
# [Epoch 58/70] [Batch 42/98] [D loss: 0.2408] [G loss: 1.6272]
# [Epoch 58/70] [Batch 43/98] [D loss: 0.2598] [G loss: 1.5145]
# [Epoch 58/70] [Batch 44/98] [D loss: 0.3941] [G loss: 2.0640]
# [Epoch 58/70] [Batch 45/98] [D loss: 0.3080] [G loss: 1.6744]
# [Epoch 58/70] [Batch 46/98] [D loss: 0.2508] [G loss: 1.4939]
# [Epoch 58/70] [Batch 47/98] [D loss: 0.2400] [G loss: 1.4814]
# [Epoch 58/70] [Batch 48/98] [D loss: 0.2648] [G loss: 1.7330]
# [Epoch 58/70] [Batch 49/98] [D loss: 0.2168] [G loss: 1.7569]
# [Epoch 58/70] [Batch 50/98] [D loss: 0.2760] [G loss: 1.5609]
# [Epoch 58/70] [Batch 51/98] [D loss: 0.2695] [G loss: 1.5644]
# [Epoch 58/70] [Batch 52/98] [D loss: 0.2139] [G loss: 1.6283]
# [Epoch 58/70] [Batch 53/98] [D loss: 0.2945] [G loss: 1.6180]
# [Epoch 58/70] [Batch 54/98] [D loss: 0.3030] [G loss: 1.4733]
# [Epoch 58/70] [Batch 55/98] [D loss: 0.2466] [G loss: 1.6027]
# [Epoch 58/70] [Batch 56/98] [D loss: 0.2477] [G loss: 1.7294]
# [Epoch 58/70] [Batch 57/98] [D loss: 0.3113] [G loss: 1.6767]
# [Epoch 58/70] [Batch 58/98] [D loss: 0.2285] [G loss: 1.7049]
# [Epoch 58/70] [Batch 59/98] [D loss: 0.2359] [G loss: 1.7448]
# [Epoch 58/70] [Batch 60/98] [D loss: 0.2527] [G loss: 1.6344]
# [Epoch 58/70] [Batch 61/98] [D loss: 0.2513] [G loss: 1.7368]
# [Epoch 58/70] [Batch 62/98] [D loss: 0.2341] [G loss: 1.6111]
# [Epoch 58/70] [Batch 63/98] [D loss: 0.2421] [G loss: 1.5800]
# [Epoch 58/70] [Batch 64/98] [D loss: 0.2340] [G loss: 1.6515]
# [Epoch 58/70] [Batch 65/98] [D loss: 0.2367] [G loss: 1.6602]
# [Epoch 58/70] [Batch 66/98] [D loss: 0.2743] [G loss: 1.8590]
# [Epoch 58/70] [Batch 67/98] [D loss: 0.2756] [G loss: 1.7033]
# [Epoch 58/70] [Batch 68/98] [D loss: 0.2688] [G loss: 1.5812]
# [Epoch 58/70] [Batch 69/98] [D loss: 0.2246] [G loss: 1.6904]
# [Epoch 58/70] [Batch 70/98] [D loss: nan] [G loss: nan]
# [Epoch 58/70] [Batch 71/98] [D loss: 0.2099] [G loss: 1.6790]
# [Epoch 58/70] [Batch 72/98] [D loss: 0.2404] [G loss: 1.6224]
# [Epoch 58/70] [Batch 73/98] [D loss: 0.2589] [G loss: 1.6900]
# [Epoch 58/70] [Batch 74/98] [D loss: 0.2876] [G loss: 1.4531]
# [Epoch 58/70] [Batch 75/98] [D loss: 0.2483] [G loss: 1.4134]
# [Epoch 58/70] [Batch 76/98] [D loss: 0.2440] [G loss: 1.5656]
# [Epoch 58/70] [Batch 77/98] [D loss: 0.2460] [G loss: 1.4847]
# [Epoch 58/70] [Batch 78/98] [D loss: 0.2853] [G loss: 1.6869]
# [Epoch 58/70] [Batch 79/98] [D loss: 0.2339] [G loss: 1.7839]
# [Epoch 58/70] [Batch 80/98] [D loss: 0.2797] [G loss: 1.5999]
# [Epoch 58/70] [Batch 81/98] [D loss: 0.2231] [G loss: 1.5210]
# [Epoch 58/70] [Batch 82/98] [D loss: 0.2355] [G loss: 1.6392]
# [Epoch 58/70] [Batch 83/98] [D loss: nan] [G loss: nan]
# [Epoch 58/70] [Batch 84/98] [D loss: 0.2364] [G loss: 1.6237]
# [Epoch 58/70] [Batch 85/98] [D loss: 0.2659] [G loss: 1.6075]
# ...
# [Epoch 60/70] [Batch 54/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 55/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 56/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 57/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 58/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 59/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 60/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 61/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 62/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 63/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 64/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 65/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 66/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 67/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 68/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 69/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 70/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 71/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 72/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 73/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 74/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 75/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 76/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 77/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 78/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 79/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 80/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 81/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 82/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 83/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 84/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 85/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 86/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 87/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 88/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 89/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 90/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 91/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 92/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 93/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 94/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 95/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 96/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 97/98] [D loss: nan] [G loss: nan]
# [Epoch 60/70] [Batch 98/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 1/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 2/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 3/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 4/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 5/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 6/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 7/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 8/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 9/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 10/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 11/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 12/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 13/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 14/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 15/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 16/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 17/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 18/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 19/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 20/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 21/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 22/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 23/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 24/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 25/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 26/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 27/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 28/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 29/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 30/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 31/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 32/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 33/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 34/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 35/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 36/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 37/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 38/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 39/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 40/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 41/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 42/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 43/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 44/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 45/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 46/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 47/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 48/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 49/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 50/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 51/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 52/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 53/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 54/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 55/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 56/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 57/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 58/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 59/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 60/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 61/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 62/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 63/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 64/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 65/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 66/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 67/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 68/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 69/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 70/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 71/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 72/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 73/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 74/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 75/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 76/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 77/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 78/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 79/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 80/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 81/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 82/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 83/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 84/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 85/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 86/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 87/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 88/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 89/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 90/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 91/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 92/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 93/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 94/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 95/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 96/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 97/98] [D loss: nan] [G loss: nan]
# [Epoch 61/70] [Batch 98/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 1/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 2/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 3/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 4/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 5/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 6/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 7/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 8/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 9/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 10/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 11/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 12/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 13/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 14/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 15/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 16/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 17/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 18/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 19/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 20/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 21/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 22/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 23/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 24/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 25/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 26/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 27/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 28/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 29/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 30/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 31/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 32/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 33/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 34/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 35/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 36/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 37/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 38/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 39/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 40/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 41/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 42/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 43/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 44/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 45/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 46/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 47/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 48/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 49/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 50/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 51/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 52/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 53/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 54/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 55/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 56/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 57/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 58/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 59/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 60/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 61/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 62/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 63/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 64/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 65/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 66/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 67/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 68/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 69/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 70/98] [D loss: nan] [G loss: nan]
# [Epoch 62/70] [Batch 71/98] [D loss: nan] [G loss: nan]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-09be808f737f> in <cell line: 4>()
#       3 # Training loop with the combined dataset
#       4 for epoch in range(start_epoch, n_epochs):
# ----> 5     for i, batch in enumerate(combined_dataloader):
#       6         xray = batch['xray'].to(device, non_blocking=True)
#       7         ct = batch['ct'].to(device, non_blocking=True)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     628                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629                 self._reset()  # type: ignore[call-arg]
# --> 630             data = self._next_data()
#     631             self._num_yielded += 1
#     632             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     671     def _next_data(self):
#     672         index = self._next_index()  # may raise StopIteration
# --> 673         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     674         if self._pin_memory:
#     675             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# <ipython-input-13-4552ba6c9bc3> in __getitem__(self, idx)
#      21         ct_dir = os.path.join(patient_dir, 'CT')
#      22         ct_slice_paths = sorted(glob(os.path.join(ct_dir, '*')))
# ---> 23         ct_slices_array = self.load_and_preprocess_ct_slices(ct_slice_paths)
#      24
#      25         sample = {'xray': xray, 'ct': ct_slices_array}
#
# <ipython-input-13-4552ba6c9bc3> in load_and_preprocess_ct_slices(self, slice_paths)
#      60             p = slice_paths[idx]
#      61             # Load and preprocess each slice
# ---> 62             slice_ = self.load_and_preprocess_image(p)
#      63             ct_slices_list.append(slice_)
#      64
#
# <ipython-input-13-4552ba6c9bc3> in load_and_preprocess_image(self, image_path)
#      31         if image_path.endswith('.dcm'):
#      32             # Load DICOM image
# ---> 33             ds = pydicom.dcmread(image_path)
#      34             image = ds.pixel_array.astype(np.float32)
#      35         else:
#
# /usr/local/lib/python3.10/dist-packages/pydicom/filereader.py in dcmread(fp, defer_size, stop_before_pixels, force, specific_tags)
#    1076         stop_when = _at_pixel_data
#    1077     try:
# -> 1078         dataset = read_partial(
#    1079             fp,
#    1080             stop_when,
#
# /usr/local/lib/python3.10/dist-packages/pydicom/filereader.py in read_partial(fileobj, stop_when, defer_size, force, specific_tags)
#     837
#     838     # Read preamble (if present)
# --> 839     preamble = read_preamble(fileobj, force)
#     840     # Read any File Meta Information group (0002,eeee) elements (if present)
#     841     file_meta = _read_file_meta_info(fileobj)
#
# /usr/local/lib/python3.10/dist-packages/pydicom/filereader.py in read_preamble(fp, force)
#     764     """
#     765     logger.debug("Reading File Meta Information preamble...")
# --> 766     preamble = fp.read(128)
#     767     if config.debugging:
#     768         sample = bytes2hex(preamble[:8]) + "..." + bytes2hex(preamble[-8:])
#
# KeyboardInterrupt:

# %%
# Switch generator to evaluation mode for visualization
generator.eval()

# Assuming you have defined 'visualize_results' and 'calculate_metrics' functions
# You need to create a dataloader for the original dataset
original_dataset = XrayCTDataset(root_dirs=[original_dataset_root])
original_dataloader = DataLoader(original_dataset, batch_size=batch_size, shuffle=False, num_workers=0, pin_memory=True)

visualize_results(generator, original_dataloader, device)
calculate_metrics(generator, original_dataloader, device)
# Out:
# xray_np.shape: (256, 256)
# ct_real_np.shape: (128, 256, 256)
# gen_ct_np.shape: (128, 256, 256)
# Average MSE: nan
# Average PSNR: nan dB
# Average SSIM: nan
